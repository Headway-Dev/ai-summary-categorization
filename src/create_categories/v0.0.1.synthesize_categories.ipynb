# %%
import os
os.chdir('/Users/maksym.konevych/Documents/Projects/HWPersonalization/Categorization/Code/ai_categories_experiment')

# %%
import dotenv
from pathlib import Path

import pandas as pd

from src.core import Book

# %%
dotenv.load_dotenv('secrets/.env')
# Out:
# True

# %%
p_books = Path('data/v0.1.0.books.csv')
df_books = pd.read_csv(p_books, index_col=0)
df_books['categories'] = df_books['categories'].apply(lambda s: s.split('|') if not pd.isna(s) else [])

# %%
df_books.head()
# Out:
#                        firebase_document_path  \
# 0  books/0059543c-a8e5-4615-a78c-69f8e73c19c1
# 1  books/008df3c8-12d8-4386-9b8b-0b1b2cc3771f
# 2  books/00bb4531-5150-44af-9eb1-c160c7d26ed6
# 3                  books/012399fc36f74c489e4e
# 4  books/012d6fde-51e2-4289-822a-1cbb57394bcd
#
#                                      id  \
# 0  0059543c-a8e5-4615-a78c-69f8e73c19c1
# 1  008df3c8-12d8-4386-9b8b-0b1b2cc3771f
# 2  00bb4531-5150-44af-9eb1-c160c7d26ed6
# 3                  012399fc36f74c489e4e
# 4  012d6fde-51e2-4289-822a-1cbb57394bcd
#
#                                                title            author  \
# 0  Parenting the New Teen in the Age of Anxiety: ...        John Duffy
# 1  Make Today Count: The Secret of Your Success I...   John C. Maxwell
# 2  Right Thing, Right Now: Good Values, Good Char...      Ryan Holiday
# 3  Eat Move Sleep: How Small Choices Lead to Big ...          Tom Rath
# 4  From Strength to Strength: Finding Success, Ha...  Arthur C. Brooks
#
#                                             overview  \
# 0  You're looking at a modern parenting guide. Te...
# 1  Make your days less chaotic and more impactful...
# 2  The modern world has many fascinating inventio...
# 3  Discover how inner strength, willpower, and ri...
# 4  Achieving your dreams is fulfilling, but what ...
#
#                                      author_overview                categories
# 0  John Duffy is a successful clinical psychologi...                  [Family]
# 1  Known as an international leadership expert, J...                        []
# 2  Ryan Holiday is known for bringing philosophy ...             [Self-Growth]
# 3  Tom Rath is a renowned author of best-selling ...                  [Health]
# 4  Arthur C. Brooks is a scientist whose research...  [Happiness, Self-Growth]

# %%
books = []
for i, row in df_books.iterrows():
    books.append(Book(
        firebase_document_path=row.firebase_document_path,
        title=row.title,
        author=row.author,
        overview=row.overview,
        author_overview=row.author_overview,
        categories=row.categories,
    ))

# %% [markdown]
# ## Idea
#
# For every book, ask an LLM to generate categories. Traverse through all books, collect data about generated categories, and analyze it to figure out possible final sets of categories.

# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import PromptTemplate
from langchain_community.callbacks import get_openai_callback
from pydantic import BaseModel, Field

from src.statistics_logging import StatisticsLogger

# %%
class OpenAICategoriesSynthesizer:
    class BookCategoriesResponseModel(BaseModel):
        categories: list[str] = Field(description="List of categories")
    
    def __init__(self) -> None:
        self._logger = StatisticsLogger()

        llm_categories_gen = ChatOpenAI(model='gpt-4o-mini', temperature=0).with_structured_output(self.BookCategoriesResponseModel)
        prompt_template_categories_gen = PromptTemplate.from_template(
            "You are an expert in book categorization. Create 1-3 mutually exclusive categories for this book.\n"
            "**Requirements**:\n"
            "1. Make categories broad and generic - users should easily find books without being overwhelmed\n"
            "2. Avoid too specific categories. Imagine that the total number of categories is 15-30 and you have to guess from existing categories."
            "3. Avoid hierarchical relationships - never include both parent and child categories\n"
            "4. Prefer short category names over long ones\n"
            "5. Ensure full independence - categories shouldn't overlap or subsume each other\n"
            "\n"
            "**Example of BAD output**: \n"
            "['Health', 'Physical Health', 'Mental Wellness'] (contains hierarchy)\n"
            "['Social Philosophy', 'Brand Management', 'Consumer Awareness'] (too specific)\n"
            "**Example of GOOD output**: \n"
            "['Nutrition', 'Fitness', 'Self-Growth']\n"
            "\n"
            "### Book Data:\n"
            "**Title**: {title}\n"
            "**Author**: {author}\n"
            "**Overview**:\n"
            "{overview}\n"
            "**Author Overview**:\n"
            "{author_overview}"
        )

        self._categories_gen_chain = prompt_template_categories_gen | llm_categories_gen

    @property
    def logger(self) -> StatisticsLogger:
        return self._logger
    
    def generate_categories(self, book: Book) -> list[str]:
        with get_openai_callback() as cb:
            res = self._categories_gen_chain.invoke({
                'title': book.title,
                'author': book.author,
                'overview': book.overview,
                'author_overview': book.author_overview,
            })

            self._logger.log(
                prompt_tokens=cb.prompt_tokens,
                completion_tokens=cb.completion_tokens,
                cost=cb.total_cost
            )
        return res.categories

# %%
cs = OpenAICategoriesSynthesizer()

# %%
i = 754
print(books[i])
print(cs.generate_categories(books[i]))
# Out:
# Book(id="DnOXwhBHwadUfg3vz7xJ", title="The Universe Has Your Back: Transform Fear to Faith", author="Gabrielle Bernstein", overview="Curious if there's more to life than fear? Venture...", author_overview="​​Gabrielle Bernstein is a renowned motivational s...", categories=['Spirituality', 'Self-Growth'], learning_items=[])
# ['Self-Help', 'Spirituality', 'Personal Development']

# %%
print(cs._logger)
# Out:
# Statistics:
# 	Num inferences: 1
# 	Average Prompt Tokens: 326.0
# 	Average Completion Tokens: 16.0
# 	Average Cost: 5.85e-05
# 	Total Prompt Tokens: 326
# 	Total Completion Tokens: 16
# 	Total Cost: 5.85e-05

# %%
from concurrent.futures import ThreadPoolExecutor
from tqdm import tqdm

def process_book(book):
    return book, cs.generate_categories(book)

with ThreadPoolExecutor(max_workers=100) as executor:
    results = list(tqdm(executor.map(process_book, books), total=len(books), desc="Processing Books"))
# Out:
# Processing Books: 100%|██████████| 1817/1817 [00:39<00:00, 46.46it/s]

# %%
print(cs.logger)
# Out:
# Statistics:
# 	Num inferences: 1818
# 	Average Prompt Tokens: 335.8916391639164
# 	Average Completion Tokens: 14.00935093509351
# 	Average Cost: 5.878935643564354e-05
# 	Total Prompt Tokens: 610651
# 	Total Completion Tokens: 25469
# 	Total Cost: 0.10687904999999996

# %%
all_categories = [cat.lower() for _, cats in results for cat in cats]

# %%
len(all_categories), len(set(all_categories))
# Out:
# (5451, 396)

# %%
from collections import Counter

counter = Counter(all_categories)

# %%
import pandas as pd

# %%
df_categories = pd.DataFrame(sorted(counter.items(), key=lambda i: i[1], reverse=True), columns=['category', 'count'])

# %%
df_categories.head()
# Out:
#                category  count
# 0             self-help    932
# 1  personal development    587
# 2              business    328
# 3            psychology    317
# 4                health    138

# %%
p_data_dest = Path('data/cat_gen')
p_data_dest.mkdir(exist_ok=True)
df_categories.to_csv(p_data_dest / 'v0.0.1.categories.csv')

# %%
results
# Out:
# [(<src.core.Book at 0x113ddcc70>,
#   ['Parenting', 'Mental Health', 'Adolescence']),
#  (<src.core.Book at 0x113ddc310>,
#   ['Self-Help', 'Personal Development', 'Motivation']),
#  (<src.core.Book at 0x113ddfc70>,
#   ['Philosophy', 'Self-Help', 'Personal Development']),
#  (<src.core.Book at 0x113dddc00>, ['Health', 'Wellness', 'Lifestyle']),
#  (<src.core.Book at 0x113ddcd90>,
#   ['Self-Help', 'Personal Development', 'Life Transitions']),
#  (<src.core.Book at 0x113ddff70>,
#   ['Self-Help', 'Motivation', 'Personal Development']),
#  (<src.core.Book at 0x113ddfc40>,
#   ['Self-Help', 'Motivation', 'Personal Development']),
#  (<src.core.Book at 0x113ddcd30>,
#   ['Sustainability', 'Food & Cooking', 'Lifestyle']),
#  (<src.core.Book at 0x113ddffa0>,
#   ['Self-Help', 'Personal Development', 'Business']),
#  (<src.core.Book at 0x113ddce80>, ['Finance', 'Self-Help', 'Business']),
#  (<src.core.Book at 0x113ddcca0>,
#   ['Self-Help', 'Personal Development', 'Mental Health']),
#  (<src.core.Book at 0x117656cb0>,
#   ['Communication', 'Leadership', 'Personal Development']),
#  (<src.core.Book at 0x117654190>,
#   ['Self-Help', 'Personal Development', 'Mental Health']),
#  (<src.core.Book at 0x117655d50>, ['Sports', 'Automotive', 'Biography']),
#  (<src.core.Book at 0x1176554e0>, ['Business', 'Self-Help', 'Politics']),
#  (<src.core.Book at 0x117657700>,
#   ['Productivity', 'Self-Help', 'Time Management']),
#  (<src.core.Book at 0x117655450>,
#   ['Self-Help', 'Personal Development', 'Psychology']),
#  (<src.core.Book at 0x1176574f0>, ['Business', 'Self-Help', 'Psychology']),
#  (<src.core.Book at 0x117655780>, ['Health', 'Science', 'History']),
#  (<src.core.Book at 0x117656680>,
#   ['Psychology', 'Self-Help', 'Personal Development']),
#  (<src.core.Book at 0x117657970>,
#   ['Personal Development', 'Memoir', 'Fashion Industry']),
#  (<src.core.Book at 0x117655a20>,
#   ['Self-Help', 'Psychology', 'Personal Development']),
#  (<src.core.Book at 0x117656110>,
#   ['Self-Help', 'Psychology', 'Personal Development']),
#  (<src.core.Book at 0x117655f90>, ['Self-Help', 'Safety', 'Psychology']),
#  (<src.core.Book at 0x1176558d0>,
#   ['Relationships', 'Psychology', 'Self-Help']),
#  (<src.core.Book at 0x1176573a0>,
#   ['Finance', 'Personal Development', 'Budgeting']),
#  (<src.core.Book at 0x117697460>, ['Business', 'Sales', 'Self-Improvement']),
#  (<src.core.Book at 0x117696770>,
#   ['Psychology', 'Self-Help', 'Social Science']),
#  (<src.core.Book at 0x1176959f0>,
#   ['Self-Help', 'Business', 'Personal Development']),
#  (<src.core.Book at 0x117694730>, ['Psychology', 'Self-Help', 'Philosophy']),
#  (<src.core.Book at 0x1176979d0>,
#   ['Business', 'Politics', 'Entrepreneurship']),
#  (<src.core.Book at 0x117697790>,
#   ['Self-Help', 'Personal Development', 'Success']),
#  (<src.core.Book at 0x117694580>,
#   ['Spirituality', 'Self-Help', 'Personal Development']),
#  (<src.core.Book at 0x117694b20>,
#   ['Economics', 'Political Science', 'Development Studies']),
#  (<src.core.Book at 0x117695510>,
#   ['Real Estate', 'Investing', 'Personal Finance']),
#  (<src.core.Book at 0x117697d60>,
#   ['Relationships', 'Self-Help', 'Psychology']),
#  (<src.core.Book at 0x117696ef0>,
#   ['Social Issues', 'Literature', 'Cultural Critique']),
#  (<src.core.Book at 0x1176964a0>,
#   ['Self-Help', 'Personal Development', 'Leadership']),
#  (<src.core.Book at 0x1176958d0>,
#   ['Business', 'Entrepreneurship', 'Innovation']),
#  (<src.core.Book at 0x117697340>, ['Business', 'Crafts', 'Marketing']),
#  (<src.core.Book at 0x113de02b0>, ['Psychology', 'Politics', 'Self-Help']),
#  (<src.core.Book at 0x1176971c0>,
#   ['Psychology', 'Self-Help', 'Relationships']),
#  (<src.core.Book at 0x117695c00>,
#   ['Self-Help', 'Psychology', 'Personal Development']),
#  (<src.core.Book at 0x113de1f60>,
#   ['Self-Help', 'Mental Health', 'Relationships']),
#  (<src.core.Book at 0x117697e50>,
#   ['Health', 'Psychology', 'Self-Improvement']),
#  (<src.core.Book at 0x117694550>, ['Business', 'Marketing', 'Social Media']),
#  (<src.core.Book at 0x113de01f0>,
#   ['Social Commentary', 'Humor', 'Political Satire']),
#  (<src.core.Book at 0x113de0280>,
#   ['Education', 'Humanitarianism', 'Inspiration']),
#  (<src.core.Book at 0x113de0220>,
#   ['Psychology', 'Self-Help', 'Relationships']),
#  (<src.core.Book at 0x113de3a90>, ['Philosophy', 'Economics', 'Self-Help']),
#  (<src.core.Book at 0x113de02e0>,
#   ['Personal Development', 'Business', 'Science']),
#  (<src.core.Book at 0x113de3970>,
#   ['Self-Help', 'Personal Development', 'Cognitive Science']),
#  (<src.core.Book at 0x113de3730>, ['Science', 'Technology', 'Innovation']),
#  (<src.core.Book at 0x113f98fd0>, ['Self-Help', 'Biography', 'Health']),
#  (<src.core.Book at 0x113f99990>,
#   ['Economics', 'Behavioral Science', 'Social Commentary']),
#  (<src.core.Book at 0x113f99660>,
#   ['Fitness', 'Nutrition', 'Self-Improvement']),
#  (<src.core.Book at 0x113f98760>, ['Health', 'Fitness', 'Self-Improvement']),
#  (<src.core.Book at 0x113f98ac0>,
#   ['Self-Help', 'Productivity', 'Personal Development']),
#  (<src.core.Book at 0x113f98910>, ['Business', 'Technology', 'Biography']),
#  (<src.core.Book at 0x113f9ae00>,
#   ['Self-Help', 'Biography', 'Personal Development']),
#  (<src.core.Book at 0x113f981f0>,
#   ['Marketing', 'Business Strategy', 'Consumer Behavior']),
#  (<src.core.Book at 0x113f99b40>, ['Spirituality', 'Self-Help', 'Meditation']),
#  (<src.core.Book at 0x113f9acb0>, ['Technology', 'Entertainment', 'Business']),
#  (<src.core.Book at 0x113f9b010>,
#   ['Self-Help', 'Psychology', 'Personal Development']),
#  (<src.core.Book at 0x113f9b5b0>,
#   ['Self-Help', 'Spirituality', 'Personal Development']),
#  (<src.core.Book at 0x113f9bf10>,
#   ['Social Science', 'Personal Development', 'Youth Culture']),
#  (<src.core.Book at 0x113f9b430>, ['Self-Help', 'Philosophy', 'Mindfulness']),
#  (<src.core.Book at 0x113f9b2b0>,
#   ['Psychology', 'Self-Help', 'Mental Health']),
#  (<src.core.Book at 0x113f9bc40>, ['Health', 'Fitness', 'Self-Improvement']),
#  (<src.core.Book at 0x113f9b160>, ['Mental Health', 'Parenting', 'Self-Help']),
#  (<src.core.Book at 0x113ff5a80>,
#   ['Technology', 'Business', 'Self-Improvement']),
#  (<src.core.Book at 0x113f98c70>,
#   ['Productivity', 'Self-Help', 'Time Management']),
#  (<src.core.Book at 0x113f9a560>,
#   ['Business', 'Entrepreneurship', 'Personal Finance']),
#  (<src.core.Book at 0x113ff4eb0>,
#   ['Self-Help', 'Psychology', 'Personal Development']),
#  (<src.core.Book at 0x113f98e20>, ['Self-Help', 'Business', 'Psychology']),
#  (<src.core.Book at 0x113f991e0>,
#   ['Self-Help', 'Personal Development', 'Success']),
#  (<src.core.Book at 0x113f99480>,
#   ['Self-Help', 'Psychology', 'Personal Development']),
#  (<src.core.Book at 0x113f9b8b0>, ['Business', 'Writing', 'Communication']),
#  (<src.core.Book at 0x106ca06a0>,
#   ['Mental Health', "Women's Issues", 'Self-Help']),
#  (<src.core.Book at 0x113ff6ad0>, ['Self-Help', 'Motivation', 'Biography']),
#  (<src.core.Book at 0x113ff6290>, ['Self-Improvement', 'Education', 'Health']),
#  (<src.core.Book at 0x106ca0910>,
#   ['Psychology', 'Social Issues', 'Self-Help']),
#  (<src.core.Book at 0x113ff7460>,
#   ['Psychology', 'Non-Fiction', 'Decision Making']),
#  (<src.core.Book at 0x113ff6800>,
#   ['Business', 'Self-Help', 'Conflict Resolution']),
#  (<src.core.Book at 0x106ca0f70>, ['Science', 'Education', 'Popular Science']),
#  (<src.core.Book at 0x113ff6da0>,
#   ['Self-Help', 'Philosophy', 'Personal Development']),
#  (<src.core.Book at 0x106ca0b50>,
#   ['Self-Help', 'Personal Development', 'Motivation']),
#  (<src.core.Book at 0x106ca0a00>,
#   ['Social Justice', 'Race Relations', 'Personal Development']),
#  (<src.core.Book at 0x106ca3490>, ['Health', 'Nutrition', 'Food Science']),
#  (<src.core.Book at 0x106ca03a0>, ['Nutrition', 'Weight Loss', 'Health']),
#  (<src.core.Book at 0x106ca01c0>,
#   ['Career Development', 'Personal Growth', 'Philosophy']),
#  (<src.core.Book at 0x117680070>,
#   ['Sports', 'Philosophy', 'Self-Improvement']),
#  (<src.core.Book at 0x117683c10>,
#   ['Personal Finance', 'Self-Help', 'Wealth Management']),
#  (<src.core.Book at 0x117680100>,
#   ['Family', 'Self-Help', 'Personal Development']),
#  (<src.core.Book at 0x117682a10>,
#   ['Business', 'Entrepreneurship', 'Self-Help']),
#  (<src.core.Book at 0x117683880>, ['Biography', 'Law', 'Feminism']),
#  (<src.core.Book at 0x117680580>, ['Writing', 'Memoir', 'Creativity']),
#  (<src.core.Book at 0x117683eb0>, ['History', 'Communication', 'Inspiration']),
#  (<src.core.Book at 0x117683ca0>, ['Programming', 'Technology', 'Education']),
#  (<src.core.Book at 0x117683b80>,
#   ['Self-Help', 'Creativity', 'Personal Development']),
#  (<src.core.Book at 0x117680490>,
#   ['Self-Help', 'Relationships', 'Personal Development']),
#  (<src.core.Book at 0x117682800>, ['Psychology', 'Technology', 'Self-Help']),
#  (<src.core.Book at 0x117682560>,
#   ['Psychology', 'Self-Help', 'Personal Development']),
#  (<src.core.Book at 0x113f81b40>,
#   ['Data Science', 'Social Science', 'Psychology']),
#  (<src.core.Book at 0x113f81d20>,
#   ['Social Issues', 'Politics', 'Cultural Studies']),
#  (<src.core.Book at 0x113f81930>,
#   ['Self-Help', 'Personal Development', 'Psychology']),
#  (<src.core.Book at 0x113f80d30>,
#   ['Business', 'Technology', 'Entrepreneurship']),
#  (<src.core.Book at 0x113f81f00>, ['Marketing', 'Business', 'Strategy']),
#  (<src.core.Book at 0x113f80a00>, ['Relationships', 'Parenting', 'Self-Help']),
#  (<src.core.Book at 0x113f805e0>, ['Business', 'Self-Help', 'Management']),
#  (<src.core.Book at 0x113f80580>,
#   ['Communication', 'Self-Improvement', 'Social Skills']),
#  (<src.core.Book at 0x113f82860>,
#   ['Relationships', 'Self-Help', 'Psychology']),
#  (<src.core.Book at 0x113f3fc40>,
#   ['Self-Help', 'Personal Development', 'Relationships']),
#  (<src.core.Book at 0x113f3f280>,
#   ['Parenting', 'Self-Help', 'Personal Development']),
#  (<src.core.Book at 0x113f821a0>, ['Religion', 'Science', 'Philosophy']),
#  (<src.core.Book at 0x113f80820>, ['Self-Help', 'Business', 'Psychology']),
#  (<src.core.Book at 0x113f26290>, ['Parenting', 'Pregnancy', 'Fatherhood']),
#  (<src.core.Book at 0x113f26410>,
#   ['Self-Help', 'Business', 'Personal Development']),
#  (<src.core.Book at 0x113f247c0>,
#   ['Management', 'Leadership', 'Professional Development']),
#  (<src.core.Book at 0x113f25870>,
#   ['Business', 'Entrepreneurship', 'Self-Help']),
#  (<src.core.Book at 0x113f819c0>,
#   ['Finance', 'Self-Help', 'Personal Development']),
#  (<src.core.Book at 0x113f83c10>,
#   ['Leadership', 'Personal Development', 'Business']),
#  (<src.core.Book at 0x113f81d80>,
#   ['Finance', 'Self-Help', 'Personal Development']),
#  (<src.core.Book at 0x113f81120>,
#   ['Biography', 'Sports', 'Personal Development']),
#  (<src.core.Book at 0x113f812d0>,
#   ['Communication', 'Self-Help', 'Relationships']),
#  (<src.core.Book at 0x113f825f0>, ['Health', 'Nutrition', 'Self-Help']),
#  (<src.core.Book at 0x113f82380>,
#   ['Self-Help', 'Mental Health', 'Personal Development']),
#  (<src.core.Book at 0x113f81840>,
#   ['Relationships', 'Self-Help', 'Psychology']),
#  (<src.core.Book at 0x113f80f10>,
#   ['Technology', 'Society', 'Personal Development']),
#  (<src.core.Book at 0x113de8160>, ['Creativity', 'Self-Improvement', 'Art']),
#  (<src.core.Book at 0x113de8340>,
#   ['Technology', 'Self-Help', 'Social Issues']),
#  (<src.core.Book at 0x113de8250>,
#   ['Parenting', 'Self-Help', 'Family Relationships']),
#  (<src.core.Book at 0x113de89d0>, ['Business', 'Self-Help', 'Finance']),
#  (<src.core.Book at 0x113de8ac0>,
#   ['Parenting', 'Child Development', 'Family Life']),
#  (<src.core.Book at 0x113de88e0>,
#   ['Psychology', 'Self-Help', 'Personal Development']),
#  (<src.core.Book at 0x113de8be0>, ['Psychology', 'Biography', 'Politics']),
#  (<src.core.Book at 0x113de8cd0>,
#   ['Self-Help', 'Personal Development', 'Motivation']),
#  (<src.core.Book at 0x113de8f70>, ['History', 'Technology', 'Social Science']),
#  (<src.core.Book at 0x113de8e80>, ['Psychology', 'Health', 'Self-Help']),
#  (<src.core.Book at 0x113de9060>, ['Fitness', 'Self-Help', 'Psychology']),
#  (<src.core.Book at 0x113de9150>, ['Business', 'Self-Help', 'Marketing']),
#  (<src.core.Book at 0x113de9240>,
#   ['Memoir', 'Relationships', 'Personal Development']),
#  (<src.core.Book at 0x113de9420>, ['Business', 'Management', 'Leadership']),
#  (<src.core.Book at 0x113de9330>,
#   ['Personal Finance', 'Self-Help', 'Wealth Management']),
#  (<src.core.Book at 0x113de9600>,
#   ['Business', 'Entrepreneurship', 'Self-Help']),
#  (<src.core.Book at 0x113de96f0>,
#   ['Biography', 'Inspiration', 'Social Issues']),
#  (<src.core.Book at 0x113de97e0>, ['Memoir', 'Self-Help', 'Biography']),
#  (<src.core.Book at 0x113de9b40>,
#   ['Self-Help', 'Psychology', 'Grief and Loss']),
#  (<src.core.Book at 0x113de9c30>, ['Self-Help', 'Productivity', 'Psychology']),
#  (<src.core.Book at 0x113de9d20>,
#   ['Environment', 'Activism', 'Personal Development']),
#  (<src.core.Book at 0x113de9510>,
#   ['Career Development', 'Personal Growth', 'Professional Skills']),
#  (<src.core.Book at 0x113de9f60>, ['Business', 'Strategy', 'Economics']),
#  (<src.core.Book at 0x113dea050>, ['Health', 'Self-Improvement', 'Wellness']),
#  (<src.core.Book at 0x113dea140>,
#   ['Self-Help', 'Personal Development', 'Motivation']),
#  (<src.core.Book at 0x113dea260>,
#   ['Self-Care', 'Creativity', 'Work-Life Balance']),
#  (<src.core.Book at 0x113dea650>,
#   ['Communication', 'Self-Help', 'Interpersonal Skills']),
#  (<src.core.Book at 0x113deb250>, ['Psychology', 'Health', 'Self-Help']),
#  (<src.core.Book at 0x113deb280>,
#   ['Business', 'Entrepreneurship', 'Marketing']),
#  (<src.core.Book at 0x113deb2b0>, ['Technology', 'Business', 'Future Trends']),
#  (<src.core.Book at 0x113deb2e0>,
#   ['Parenting', 'Child Development', 'Family Relationships']),
#  (<src.core.Book at 0x113deb310>,
#   ['Finance', 'Self-Help', 'Personal Development']),
#  (<src.core.Book at 0x113deb340>,
#   ['Self-Help', 'Personal Development', 'Mental Health']),
#  (<src.core.Book at 0x113deb370>,
#   ['Psychology', 'Self-Help', 'Personal Development']),
#  (<src.core.Book at 0x113deb3a0>,
#   ['Humanities', 'Social Science', 'Self-Help']),
#  (<src.core.Book at 0x113deb3d0>, ['Communication', 'Business', 'Psychology']),
#  (<src.core.Book at 0x113deb400>,
#   ['Self-Care', 'Personal Development', 'Mental Health']),
#  (<src.core.Book at 0x113deb430>,
#   ['Relationships', 'Self-Help', 'Personal Development']),
#  (<src.core.Book at 0x113deb460>,
#   ['Relationships', 'Psychology', 'Self-Help']),
#  (<src.core.Book at 0x113deb490>, ['Business', 'Self-Help', 'Psychology']),
#  (<src.core.Book at 0x113deb4c0>, ['True Crime', 'Biography', 'Psychology']),
#  (<src.core.Book at 0x113deb520>, ['Leadership', 'Creativity', 'Business']),
#  (<src.core.Book at 0x113deb550>,
#   ['Film Studies', 'Cultural History', 'Art and Design']),
#  (<src.core.Book at 0x113deb4f0>,
#   ['Economics', 'Political Science', 'Social Issues']),
#  (<src.core.Book at 0x113deb580>, ['Sports', 'Biography', 'Health']),
#  (<src.core.Book at 0x113deb5b0>,
#   ['Parenting', 'Personal Development', 'Child Psychology']),
#  (<src.core.Book at 0x113deb5e0>, ['Health', 'Self-Help', 'Nutrition']),
#  (<src.core.Book at 0x113deb610>, ['Self-Help', 'Psychology', 'Sports']),
#  (<src.core.Book at 0x113deb640>, ['Business', 'Self-Help', 'Psychology']),
#  (<src.core.Book at 0x113deb670>, ['Biography', 'Leadership', 'Innovation']),
#  (<src.core.Book at 0x113deb6d0>, ['Sexuality', 'Self-Help', 'Relationships']),
#  (<src.core.Book at 0x113deb6a0>,
#   ['Personal Development', 'Leadership', 'Self-Help']),
#  (<src.core.Book at 0x113deb700>, ['Nature', 'Science', 'Philosophy']),
#  (<src.core.Book at 0x113deb730>, ['Health', 'Fitness', 'Aging']),
#  (<src.core.Book at 0x113deb760>, ['Health', 'Wellness', 'Self-Improvement']),
#  (<src.core.Book at 0x113deb790>, ['Finance', 'Investing', 'Economics']),
#  (<src.core.Book at 0x113deb7c0>,
#   ['Self-Help', 'Personal Development', 'Happiness']),
#  (<src.core.Book at 0x113deb7f0>,
#   ['Self-Help', 'Personal Development', 'Creativity']),
#  (<src.core.Book at 0x113deb850>,
#   ['Psychology', 'Relationships', 'Self-Help']),
#  (<src.core.Book at 0x113deb820>,
#   ['Design', 'Career Development', 'Business Skills']),
#  (<src.core.Book at 0x113deb880>, ['Business', 'Strategy', 'Leadership']),
#  (<src.core.Book at 0x113deb8b0>,
#   ['Self-Help', 'Personal Development', 'Psychology']),
#  (<src.core.Book at 0x113deb8e0>, ['Fitness', 'Health', 'Self-Improvement']),
#  (<src.core.Book at 0x113deb910>, ['Finance', 'Investing', 'Self-Help']),
#  (<src.core.Book at 0x113deb940>, ['Business', 'Innovation', 'Leadership']),
#  (<src.core.Book at 0x113deb970>, ['Technology', 'Safety', 'Health']),
#  (<src.core.Book at 0x113deb9d0>,
#   ['Business', 'Entrepreneurship', 'Customer Insights']),
#  (<src.core.Book at 0x113deb9a0>, ['Psychology', 'Philosophy', 'Self-Help']),
#  (<src.core.Book at 0x113deba00>,
#   ['Self-Help', 'Personal Development', 'Motivation']),
#  (<src.core.Book at 0x113deba30>,
#   ['Communication', 'Self-Improvement', 'Business Skills']),
#  (<src.core.Book at 0x113deba90>,
#   ['Finance', 'Personal Development', 'Economics']),
#  (<src.core.Book at 0x113deba60>,
#   ['Self-Help', 'Personal Development', 'Motivation']),
#  (<src.core.Book at 0x113debac0>,
#   ['Parenting', 'Social Science', 'Mental Health']),
#  (<src.core.Book at 0x113debaf0>,
#   ['Self-Help', 'Personal Development', 'Lifestyle']),
#  (<src.core.Book at 0x113debb20>,
#   ['Parenting', 'Child Development', 'Psychology']),
#  (<src.core.Book at 0x113debbb0>, ['Business', 'Leadership', 'Teamwork']),
#  (<src.core.Book at 0x113debb50>, ['Psychology', 'Sociology', 'Self-Help']),
#  (<src.core.Book at 0x113debb80>, ['Health', 'Self-Help', 'Cancer Awareness']),
#  (<src.core.Book at 0x113debbe0>,
#   ['Relationships', 'Self-Help', 'Personal Development']),
#  (<src.core.Book at 0x113debc40>, ['History', 'Philosophy', 'Social Science']),
#  (<src.core.Book at 0x113debc10>,
#   ['Productivity', 'Personal Development', 'Technology']),
#  (<src.core.Book at 0x113debc70>,
#   ['Social Issues', 'Philosophy', 'Cultural Critique']),
#  (<src.core.Book at 0x113debca0>,
#   ['Self-Help', 'Relationships', 'Personal Development']),
#  (<src.core.Book at 0x113debcd0>, ['Business', 'Strategy', 'Marketing']),
#  (<src.core.Book at 0x113debd00>,
#   ['Career Development', 'Personal Growth', 'Personality']),
#  (<src.core.Book at 0x113debd30>,
#   ['Feminism', 'Evolutionary Biology', 'History']),
#  (<src.core.Book at 0x113debd60>,
#   ['Business', 'Entrepreneurship', 'Innovation']),
#  (<src.core.Book at 0x113debd90>,
#   ['Business', 'Entrepreneurship', 'Craft Brewing']),
#  (<src.core.Book at 0x113de4f10>,
#   ['Communication', 'Self-Improvement', 'Social Skills']),
#  (<src.core.Book at 0x113debdf0>,
#   ['Leadership', 'Women Empowerment', 'Career Development']),
#  (<src.core.Book at 0x113de5000>,
#   ['Leadership', 'Military', 'Personal Development']),
#  (<src.core.Book at 0x113debe50>,
#   ['Self-Help', 'Business', 'Personal Development']),
#  (<src.core.Book at 0x113debe80>, ['Business', 'Biography', 'Finance']),
#  (<src.core.Book at 0x113debdc0>,
#   ['Self-Help', 'Psychology', 'Personal Development']),
#  (<src.core.Book at 0x113debe20>, ['Business', 'Leadership', 'Culture']),
#  (<src.core.Book at 0x113debee0>,
#   ['Finance', 'Self-Help', 'Personal Development']),
#  (<src.core.Book at 0x113debeb0>, ['Psychology', 'Health', 'Non-Fiction']),
#  (<src.core.Book at 0x113debf10>,
#   ['Career Development', 'Business', 'Technology']),
#  (<src.core.Book at 0x113debf40>,
#   ['Finance', 'Self-Help', 'Personal Development']),
#  (<src.core.Book at 0x113debf70>, ['Psychology', 'Sociology', 'Education']),
#  (<src.core.Book at 0x113debfa0>,
#   ['Self-Help', 'Health', 'Personal Development']),
#  (<src.core.Book at 0x113debfd0>,
#   ['Self-Help', 'Personal Development', 'Motivation']),
#  (<src.core.Book at 0x113e01780>,
#   ['Psychology', 'Self-Help', 'Social Issues']),
#  (<src.core.Book at 0x113de8070>,
#   ['Communication', 'Self-Help', 'Social Skills']),
#  (<src.core.Book at 0x113e00310>, ['Leadership', 'Teamwork', 'Business']),
#  (<src.core.Book at 0x113e030a0>, ['Health', 'Fitness', 'Self-Improvement']),
#  (<src.core.Book at 0x113de8430>,
#   ['Public Speaking', 'Communication Skills', 'Personal Development']),
#  (<src.core.Book at 0x113e00460>, ['Productivity', 'Self-Help', 'Business']),
#  (<src.core.Book at 0x113e03100>,
#   ['Business', 'Leadership', 'Self-Improvement']),
#  (<src.core.Book at 0x113e001f0>, ['Finance', 'Self-Help', 'Business']),
#  (<src.core.Book at 0x113dea470>,
#   ['Self-Help', 'Spirituality', 'Personal Development']),
#  (<src.core.Book at 0x113de8610>,
#   ['Education', 'Self-Help', 'Personal Development']),
#  (<src.core.Book at 0x113de9e70>, ['Psychology', 'Self-Help', 'Mindfulness']),
#  (<src.core.Book at 0x113de8700>, ['Marketing', 'Publishing', 'Writing']),
#  (<src.core.Book at 0x113de87f0>, ['Health', 'Nutrition', 'Weight Loss']),
#  (<src.core.Book at 0x113dec100>, ['Finance', 'Self-Help', 'Education']),
#  (<src.core.Book at 0x113deca30>, ['Self-Help', 'Psychology', 'Wellness']),
#  (<src.core.Book at 0x113dec0d0>,
#   ['Personal Development', 'Psychology', 'Business']),
#  (<src.core.Book at 0x113dec1c0>, ['Economics', 'Finance', 'Psychology']),
#  (<src.core.Book at 0x113dec1f0>,
#   ['Cultural Studies', 'History', 'Literature']),
#  (<src.core.Book at 0x113dec220>, ['Fantasy', 'Adventure', 'Fiction']),
#  (<src.core.Book at 0x113dec250>,
#   ['Business', 'Entrepreneurship', 'Inspiration']),
#  (<src.core.Book at 0x113dec280>,
#   ['Self-Help', 'Personal Development', 'Philosophy']),
#  (<src.core.Book at 0x113dec2b0>,
#   ['Self-Improvement', 'Education', 'Personal Development']),
#  (<src.core.Book at 0x113dec2e0>,
#   ['Finance', 'Self-Help', 'Personal Development']),
#  (<src.core.Book at 0x113dec310>,
#   ['Self-Help', 'Personal Finance', 'Spirituality']),
#  (<src.core.Book at 0x113dec340>, ['Business', 'Self-Help', 'Motivation']),
#  (<src.core.Book at 0x113dec370>,
#   ['Communication', 'Personal Development', 'Psychology']),
#  (<src.core.Book at 0x113dec3a0>,
#   ['Self-Help', 'Personal Development', 'Motivation']),
#  (<src.core.Book at 0x113dec3d0>,
#   ['Psychology', 'Self-Help', 'Personal Development']),
#  (<src.core.Book at 0x113dec400>,
#   ['Self-Help', 'Spirituality', 'Personal Development']),
#  (<src.core.Book at 0x113dec430>,
#   ['Self-Help', 'Personal Development', 'Mental Health']),
#  (<src.core.Book at 0x113dec460>,
#   ['Self-Help', 'Psychology', 'Personal Development']),
#  (<src.core.Book at 0x113dec490>, ['Health', 'Nutrition', 'Wellness']),
#  (<src.core.Book at 0x113dec4c0>,
#   ['Education', 'Personal Development', 'Parenting']),
#  (<src.core.Book at 0x113dec4f0>,
#   ['Self-Help', 'Mental Health', 'Personal Development']),
#  (<src.core.Book at 0x113dec520>, ['Psychology', 'Self-Help', 'Health']),
#  (<src.core.Book at 0x113dec550>,
#   ['Business', 'Productivity', 'Workplace Culture']),
#  (<src.core.Book at 0x113dec580>, ['Biography', 'Self-Help', 'Entertainment']),
#  (<src.core.Book at 0x113dec5b0>,
#   ['Self-Care', 'Health', 'Personal Development']),
#  (<src.core.Book at 0x113dec5e0>, ['Psychology', 'Self-Help', 'Health']),
#  (<src.core.Book at 0x113dec610>,
#   ['Business', 'Marketing', 'Self-Improvement']),
#  (<src.core.Book at 0x113dec640>, ['Self-Help', 'Psychology', 'Business']),
#  (<src.core.Book at 0x113dec670>, ['Science', 'Health', 'History']),
#  (<src.core.Book at 0x113dec6a0>,
#   ['Leadership', 'Business', 'Personal Development']),
#  (<src.core.Book at 0x113dec6d0>,
#   ['Mental Health', 'Self-Help', 'Psychology']),
#  (<src.core.Book at 0x113dec700>, ['Self-Help', 'Philosophy', 'Wellness']),
#  (<src.core.Book at 0x113dec730>, ['Self-Help', 'Psychology', 'Productivity']),
#  (<src.core.Book at 0x113dec760>, ['Self-Help', 'Sociology', 'Motivation']),
#  (<src.core.Book at 0x113dec790>,
#   ['Social Justice', 'Parenting', 'Education']),
#  (<src.core.Book at 0x113dec7c0>,
#   ['Self-Help', 'Philosophy', 'Digital Culture']),
#  (<src.core.Book at 0x113dec7f0>,
#   ['Self-Help', 'Business', 'Personal Development']),
#  (<src.core.Book at 0x113dec850>,
#   ['Religion', 'Philosophy', 'Cultural Studies']),
#  (<src.core.Book at 0x113dec880>, ['Science', 'Humor', 'Self-Help']),
#  (<src.core.Book at 0x113dec8b0>,
#   ['Self-Help', 'Personal Development', 'Psychology']),
#  (<src.core.Book at 0x113dec8e0>,
#   ['Health', 'Weight Loss', 'Self-Improvement']),
#  (<src.core.Book at 0x113dec910>,
#   ['Communication', 'Self-Help', 'Conflict Resolution']),
#  (<src.core.Book at 0x113dec940>,
#   ['Self-Help', 'Personal Development', 'Motivation']),
#  (<src.core.Book at 0x113dec970>,
#   ['Social Issues', 'Personal Development', 'Workplace Dynamics']),
#  (<src.core.Book at 0x113dec9a0>,
#   ['Food Politics', 'Sustainability', 'Animal Welfare']),
#  (<src.core.Book at 0x113dec9d0>,
#   ['Career Development', 'Personal Growth', 'Workplace Culture']),
#  (<src.core.Book at 0x113deca00>,
#   ['Military Strategy', 'Philosophy', 'Leadership']),
#  (<src.core.Book at 0x113deca60>,
#   ['Business', 'Entrepreneurship', 'Marketing']),
#  (<src.core.Book at 0x113deca90>, ['Nutrition', 'Health', 'Wellness']),
#  (<src.core.Book at 0x113decac0>, ['Health', 'Nutrition', 'Wellness']),
#  (<src.core.Book at 0x113decaf0>,
#   ['Self-Help', 'Productivity', 'Time Management']),
#  (<src.core.Book at 0x113decb20>,
#   ['Psychology', 'Decision Making', 'Behavioral Economics']),
#  (<src.core.Book at 0x113decb50>,
#   ['Political Philosophy', 'History', 'Current Affairs']),
#  (<src.core.Book at 0x113decb80>,
#   ['Self-Help', 'Personal Development', 'Psychology']),
#  (<src.core.Book at 0x113decbb0>, ['Biography', 'Technology', 'Innovation']),
#  (<src.core.Book at 0x113decbe0>,
#   ['Motivation', 'Self-Improvement', 'Psychology']),
#  (<src.core.Book at 0x113decc10>,
#   ['Communication', 'Self-Help', 'Relationships']),
#  (<src.core.Book at 0x113decc40>,
#   ['Self-Help', 'Spirituality', 'Personal Development']),
#  (<src.core.Book at 0x113decc70>,
#   ['Business', 'Leadership', 'Self-Improvement']),
#  (<src.core.Book at 0x113decca0>, ['Self-Help', 'Business', 'Philosophy']),
#  (<src.core.Book at 0x113deccd0>, ['Nature', 'Humanities', 'Environment']),
#  (<src.core.Book at 0x113decd00>,
#   ['Marketing', 'Business', 'Entrepreneurship']),
#  (<src.core.Book at 0x113decd30>, ['Science', 'Philosophy', 'Astronomy']),
#  (<src.core.Book at 0x113decd60>, ['Sports', 'Business', 'Statistics']),
#  (<src.core.Book at 0x113decd90>,
#   ['Business', 'Innovation', 'Entrepreneurship']),
#  (<src.core.Book at 0x113decdc0>,
#   ['Self-Help', 'Personal Finance', 'Health & Wellness']),
#  (<src.core.Book at 0x113decdf0>, ['Fashion', 'Sustainability', 'Lifestyle']),
#  (<src.core.Book at 0x113dece50>,
#   ['History', 'Social Issues', 'Cultural Studies']),
#  (<src.core.Book at 0x113dece80>,
#   ['Personal Development', 'Health & Wellness', 'Memoir']),
#  (<src.core.Book at 0x113deceb0>,
#   ['Investing', 'Personal Finance', 'Wealth Management']),
#  (<src.core.Book at 0x113decee0>,
#   ['Psychology', 'Self-Help', 'Personal Development']),
#  (<src.core.Book at 0x113decf10>, ['Writing', 'Fiction', 'Creativity']),
#  (<src.core.Book at 0x113decf40>,
#   ['Finance', 'Investing', 'Personal Development']),
#  (<src.core.Book at 0x113decf70>,
#   ['Business', 'Strategy', 'Self-Improvement']),
#  (<src.core.Book at 0x113decfa0>,
#   ['Relationships', 'Psychology', 'Self-Help']),
#  (<src.core.Book at 0x113decfd0>,
#   ['Self-Help', 'Psychology', 'Personal Development']),
#  (<src.core.Book at 0x113ded000>, ['Psychology', 'Gaming', 'Health']),
#  (<src.core.Book at 0x113ded030>, ['Business', 'Self-Help', 'Adventure']),
#  (<src.core.Book at 0x113ded090>, ['Business', 'Gender Studies', 'Self-Help']),
#  (<src.core.Book at 0x113ded0c0>, ['Science', 'Humor', 'Curiosity']),
#  (<src.core.Book at 0x113ded0f0>,
#   ['Self-Help', 'Personal Development', 'Psychology']),
#  (<src.core.Book at 0x113ded120>, ['Finance', 'Self-Help', 'Business']),
#  (<src.core.Book at 0x113ded150>,
#   ['Self-Help', 'Personal Development', 'Motivation']),
#  (<src.core.Book at 0x113ded180>,
#   ['Self-Help', 'Psychology', 'Relationships']),
#  (<src.core.Book at 0x113ded1b0>, ['Psychology', 'Self-Help', 'Design']),
#  (<src.core.Book at 0x113ded1e0>, ['Productivity', 'Self-Help', 'Business']),
#  (<src.core.Book at 0x113ded210>, ['Knowledge', 'Technology', 'Philosophy']),
#  (<src.core.Book at 0x113ded240>, ['Business', 'Psychology', 'Self-Help']),
#  (<src.core.Book at 0x113ded270>,
#   ['Dystopian Fiction', 'Political Commentary', 'Social Critique']),
#  (<src.core.Book at 0x113ded2a0>,
#   ['Self-Help', 'Mindfulness', 'Mental Health']),
#  (<src.core.Book at 0x113ded2d0>,
#   ['Self-Help', 'Personal Development', 'Psychology']),
#  (<src.core.Book at 0x113ded300>, ['Biography', 'Literature', 'History']),
#  (<src.core.Book at 0x113ded330>,
#   ['Self-Help', 'Philosophy', 'Personal Development']),
#  (<src.core.Book at 0x113ded360>, ['Leadership', 'Business', 'Motivation']),
#  (<src.core.Book at 0x113ded390>,
#   ['Leadership', 'Personal Development', 'Business']),
#  (<src.core.Book at 0x113ded3c0>, ['Business', 'Finance', 'Entrepreneurship']),
#  (<src.core.Book at 0x113ded3f0>,
#   ['Psychology', 'Self-Help', 'Communication']),
#  (<src.core.Book at 0x113ded420>,
#   ['Mythology', 'Cultural Studies', 'Philosophy']),
#  (<src.core.Book at 0x113ded450>, ['Biography', 'Self-Help', 'Social Issues']),
#  (<src.core.Book at 0x113ded480>,
#   ['Religion', 'Social Issues', 'Relationships']),
#  (<src.core.Book at 0x113ded4b0>,
#   ['Self-Help', 'Spirituality', 'Personal Development']),
#  (<src.core.Book at 0x113ded4e0>, ['Business', 'Self-Help', 'Leadership']),
#  (<src.core.Book at 0x113ded510>, ['Business', 'Self-Help', 'Communication']),
#  (<src.core.Book at 0x113ded540>,
#   ['Self-Help', 'Lifestyle', 'Personal Finance']),
#  (<src.core.Book at 0x113ded5a0>, ['Animals', 'Psychology', 'Relationships']),
#  (<src.core.Book at 0x113ded5d0>,
#   ['Psychology', 'Self-Help', 'Relationships']),
#  (<src.core.Book at 0x113ded600>, ['Sexuality', 'Relationships', 'Self-Help']),
#  (<src.core.Book at 0x113ded630>,
#   ['Self-Help', 'Psychology', 'Personal Development']),
#  (<src.core.Book at 0x113ded660>,
#   ['Psychology', 'Creativity', 'Self-Improvement']),
#  (<src.core.Book at 0x113ded690>, ['Health', 'Science', 'Self-Help']),
#  (<src.core.Book at 0x113ded6c0>,
#   ['Business', 'Entrepreneurship', 'Self-Help']),
#  (<src.core.Book at 0x113ded6f0>,
#   ['Communication', 'Personal Development', 'Networking']),
#  (<src.core.Book at 0x113ded720>,
#   ['Self-Help', 'Personal Development', 'Success']),
#  (<src.core.Book at 0x113ded750>, ['Science', 'Technology', 'Psychology']),
#  (<src.core.Book at 0x113ded780>, ['Psychology', 'Spirituality', 'Self-Help']),
#  (<src.core.Book at 0x113ded7b0>, ['Business', 'Leadership', 'Self-Help']),
#  (<src.core.Book at 0x113ded7e0>,
#   ['Creativity', 'Self-Promotion', 'Personal Development']),
#  (<src.core.Book at 0x113ded810>, ['Relationships', 'Self-Help', 'Marriage']),
#  (<src.core.Book at 0x113ded840>,
#   ['Health', 'Wellness', 'Personal Development']),
#  (<src.core.Book at 0x113ded870>,
#   ['Self-Help', 'Personal Development', 'Life Skills']),
#  (<src.core.Book at 0x113ded8a0>, ['Health', 'Parenting', "Women's Health"]),
#  (<src.core.Book at 0x113ded8d0>,
#   ['Self-Help', 'Personal Development', 'Leadership']),
#  (<src.core.Book at 0x113ded900>,
#   ['Self-Help', 'Personal Development', 'Motivation']),
#  (<src.core.Book at 0x113ded930>, ['Marketing', 'Business', 'Self-Help']),
#  (<src.core.Book at 0x113ded960>,
#   ['Self-Help', 'Business', 'Personal Development']),
#  (<src.core.Book at 0x113ded990>, ['Business', 'Leadership', 'Teamwork']),
#  (<src.core.Book at 0x113ded9c0>,
#   ['Productivity', 'Self-Help', 'Time Management']),
#  (<src.core.Book at 0x113ded9f0>,
#   ['Self-Help', 'Motivation', 'Personal Development']),
#  (<src.core.Book at 0x113deda20>,
#   ['Business', 'Self-Help', 'Career Development']),
#  (<src.core.Book at 0x113deda50>, ['Self-Help', 'Education', 'Psychology']),
#  (<src.core.Book at 0x113deda80>, ['Business', 'Self-Help', 'Leadership']),
#  (<src.core.Book at 0x113dedab0>,
#   ['Self-Help', 'Relationships', 'Personal Development']),
#  (<src.core.Book at 0x113dedae0>,
#   ['Self-Help', 'Personal Development', 'Career Guidance']),
#  (<src.core.Book at 0x113dedb10>,
#   ['Business', 'Self-Help', 'Career Development']),
#  (<src.core.Book at 0x113dedb40>,
#   ['Investing', 'Finance', 'Personal Development']),
#  (<src.core.Book at 0x113dedb70>, ['Health', 'Nutrition', 'Wellness']),
#  (<src.core.Book at 0x113dedba0>,
#   ['Self-Help', 'Personal Development', 'Motivation']),
#  (<src.core.Book at 0x113dedbd0>, ['Marketing', 'Business', 'Technology']),
#  (<src.core.Book at 0x113dedc00>,
#   ['Productivity', 'Self-Help', 'Time Management']),
#  (<src.core.Book at 0x113dedc30>,
#   ['Self-Help', 'Productivity', 'Time Management']),
#  (<src.core.Book at 0x113dec040>, ['Creativity', 'Self-Help', 'Art']),
#  (<src.core.Book at 0x113dec190>,
#   ['Self-Help', 'Personal Development', 'Motivation']),
#  (<src.core.Book at 0x113dec130>, ['Business', 'Self-Help', 'Motivation']),
#  (<src.core.Book at 0x113dedc60>, ['Business', 'Self-Help', 'Motivation']),
#  (<src.core.Book at 0x113dec160>, ['Health', 'Self-Help', 'Wellness']),
#  (<src.core.Book at 0x113dec0a0>, ['Finance', 'Psychology', 'Self-Help']),
#  (<src.core.Book at 0x113dec070>,
#   ['Parenting', 'Family Relationships', 'Communication Skills']),
#  (<src.core.Book at 0x113df9d50>,
#   ['Productivity', 'Time Management', 'Personal Development']),
#  (<src.core.Book at 0x113df8e50>,
#   ['Career Development', 'Personal Growth', 'Business Insights']),
#  (<src.core.Book at 0x113df9a80>,
#   ['Self-Help', 'Social Skills', 'Personal Development']),
#  (<src.core.Book at 0x113df9e10>,
#   ['Psychology', 'Self-Help', 'Emotional Intelligence']),
#  (<src.core.Book at 0x113df9e40>,
#   ['Finance', 'Self-Help', 'Personal Development']),
#  (<src.core.Book at 0x113df9e70>,
#   ['Career Development', 'Self-Help', 'Motivation']),
#  (<src.core.Book at 0x113df9ea0>,
#   ['Business', 'Technology', 'Entrepreneurship']),
#  (<src.core.Book at 0x113df9ed0>, ['Biography', 'Psychology', 'History']),
#  (<src.core.Book at 0x113df9f00>, ['Self-Help', 'Philosophy', 'Psychology']),
#  (<src.core.Book at 0x113df9f30>,
#   ['Self-Help', 'Personal Development', 'Mindfulness']),
#  (<src.core.Book at 0x113df9f60>,
#   ['Psychology', 'Self-Help', 'Personal Development']),
#  (<src.core.Book at 0x113df9f90>,
#   ['Self-Help', 'Personal Development', 'Lifestyle']),
#  (<src.core.Book at 0x113df9fc0>, ['Biography', 'Technology', 'Politics']),
#  (<src.core.Book at 0x113df9ff0>,
#   ['Self-Help', 'Spirituality', 'Personal Development']),
#  (<src.core.Book at 0x113dfa020>,
#   ['Self-Help', 'Psychology', 'Personal Development']),
#  (<src.core.Book at 0x113dfa050>, ['Finance', 'Technology', 'Ethics']),
#  (<src.core.Book at 0x113dfa080>,
#   ['Personal Development', 'Education', 'Self-Improvement']),
#  (<src.core.Book at 0x113dfa0b0>,
#   ['Career Development', 'Self-Help', 'Job Search']),
#  (<src.core.Book at 0x113dfa0e0>,
#   ['Self-Help', 'Personal Development', 'Mindfulness']),
#  (<src.core.Book at 0x113dfa110>,
#   ['Personal Development', 'Business', 'Relationships']),
#  (<src.core.Book at 0x113dfa140>,
#   ['Education', 'Psychology', 'Self-Improvement']),
#  (<src.core.Book at 0x113dfa170>,
#   ['Self-Help', 'Creativity', 'Personal Development']),
#  (<src.core.Book at 0x113dfa1a0>,
#   ['Marketing', 'Social Media', 'Business Strategy']),
#  (<src.core.Book at 0x113dfa1d0>,
#   ['Business Strategy', 'Innovation', 'Entrepreneurship']),
#  (<src.core.Book at 0x113dfa200>, ['Parenting', 'Self-Help', 'Mental Health']),
#  (<src.core.Book at 0x113dfa230>,
#   ['Education', 'Child Development', 'Parenting']),
#  (<src.core.Book at 0x113dfa260>, ['Psychology', 'Education', 'Neuroscience']),
#  (<src.core.Book at 0x113dfa290>,
#   ['Health', 'Food Industry', 'Consumer Awareness']),
#  (<src.core.Book at 0x113dfa2c0>, ['War', 'Women', 'Health']),
#  (<src.core.Book at 0x113dfa2f0>, ['Business', 'Communication', 'Self-Help']),
#  (<src.core.Book at 0x113dfa320>,
#   ['Creativity', 'Personal Development', 'Innovation']),
#  (<src.core.Book at 0x113dfa350>,
#   ['Self-Help', 'Spirituality', 'Personal Development']),
#  (<src.core.Book at 0x113dfa380>,
#   ['Personal Development', 'Philosophy', 'Social Issues']),
#  (<src.core.Book at 0x113dfa3b0>,
#   ['Self-Help', 'Personal Development', 'Psychology']),
#  (<src.core.Book at 0x113dfa3e0>,
#   ['Self-Help', 'Personal Development', 'Aging']),
#  (<src.core.Book at 0x113dfa410>,
#   ['Self-Help', 'Personal Development', 'Motivation']),
#  (<src.core.Book at 0x113dfa440>, ['Spirituality', 'Self-Help', 'Philosophy']),
#  (<src.core.Book at 0x113dfa470>,
#   ['Business', 'Technology', 'Self-Improvement']),
#  (<src.core.Book at 0x113dfa4a0>,
#   ['Self-Help', 'Motivation', 'Personal Development']),
#  (<src.core.Book at 0x113dfa4d0>, ['Language', 'Communication', 'Technology']),
#  (<src.core.Book at 0x113dfa500>,
#   ['Self-Help', 'Psychology', 'Personal Development']),
#  (<src.core.Book at 0x113dfa530>,
#   ['Social Issues', 'Gender Studies', 'Empowerment']),
#  (<src.core.Book at 0x113dfa560>, ['Nutrition', 'Weight Loss', 'Health']),
#  (<src.core.Book at 0x113dfa590>,
#   ['Lifestyle', 'Sexuality', 'Personal Development']),
#  (<src.core.Book at 0x113dfa5c0>,
#   ['Business', 'Personal Development', 'Leadership']),
#  (<src.core.Book at 0x113dfa5f0>,
#   ['Parenting', 'Education', 'Personal Development']),
#  (<src.core.Book at 0x113dfa620>, ['Memoir', 'Self-Help', 'Social Issues']),
#  (<src.core.Book at 0x113dfa650>,
#   ['Parenting', 'Child Development', 'Family Life']),
#  (<src.core.Book at 0x113dfa680>, ['Business', 'Leadership', 'Management']),
#  (<src.core.Book at 0x113dfa6b0>, ['Adventure', 'Survival', 'Transformation']),
#  (<src.core.Book at 0x113dfa6e0>,
#   ['Self-Help', 'Personal Development', 'Motivation']),
#  (<src.core.Book at 0x113dfa710>, ['History', 'Culture', 'Civilizations']),
#  (<src.core.Book at 0x113dfa740>,
#   ['Personal Development', 'Education', 'Business']),
#  (<src.core.Book at 0x113dfa770>, ['Psychology', 'Self-Help', 'Business']),
#  (<src.core.Book at 0x113dfa7a0>,
#   ['Self-Improvement', 'Psychology', 'Education']),
#  (<src.core.Book at 0x113dfa7d0>,
#   ['Language Learning', 'Self-Improvement', 'Education']),
#  (<src.core.Book at 0x113dfa800>,
#   ['Business', 'Entrepreneurship', 'Self-Help']),
#  (<src.core.Book at 0x113dfa830>,
#   ['Sports', 'Globalization', 'Cultural Studies']),
#  (<src.core.Book at 0x113dfa890>,
#   ['Self-Help', 'Health & Wellness', 'Spirituality']),
#  (<src.core.Book at 0x113dfa8c0>, ['Business', 'Self-Help', 'Productivity']),
#  (<src.core.Book at 0x113dfa8f0>,
#   ['Self-Help', 'Mental Health', 'Personal Development']),
#  (<src.core.Book at 0x113dfa920>,
#   ['Self-Help', 'Personal Development', 'Motivation']),
#  (<src.core.Book at 0x113dfa950>,
#   ['Parenting', 'Christian Living', 'Child Development']),
#  (<src.core.Book at 0x113dfa980>,
#   ['Leadership', 'Business', 'Personal Development']),
#  (<src.core.Book at 0x113dfa9b0>, ['Travel', 'Cultural Studies', 'History']),
#  (<src.core.Book at 0x113dfa9e0>,
#   ['Self-Help', 'Personal Development', 'Psychology']),
#  (<src.core.Book at 0x113dfaa10>,
#   ['Self-Help', 'Personal Development', 'Happiness']),
#  (<src.core.Book at 0x113dfaa40>,
#   ['Health', 'Emergency Preparedness', 'Public Safety']),
#  (<src.core.Book at 0x113dfaa70>,
#   ['Self-Help', 'Mindfulness', 'Personal Development']),
#  (<src.core.Book at 0x113dfaaa0>,
#   ['Self-Help', 'Personal Development', 'Goal Setting']),
#  (<src.core.Book at 0x113dfaad0>,
#   ['Leadership', 'Personal Development', 'Coaching']),
#  (<src.core.Book at 0x113dfab00>, ['Psychology', 'Self-Help', 'Technology']),
#  (<src.core.Book at 0x113dfab30>,
#   ['Spirituality', 'Meditation', 'Philosophy']),
#  (<src.core.Book at 0x113dfab60>,
#   ['Memoir', 'Education', 'Personal Development']),
#  (<src.core.Book at 0x113dfab90>, ['Philosophy', 'Self-Help', 'Literature']),
#  (<src.core.Book at 0x113dfabc0>,
#   ['Self-Help', 'Spirituality', 'Relationships']),
#  (<src.core.Book at 0x113dfabf0>,
#   ['Philosophy', 'Self-Help', 'Personal Development']),
#  (<src.core.Book at 0x113dfac20>,
#   ['Political Science', 'Philosophy', 'History']),
#  (<src.core.Book at 0x113dfac50>,
#   ['Psychology', 'Self-Help', 'Relationships']),
#  (<src.core.Book at 0x113dfac80>,
#   ['Relationships', 'Personal Development', 'Social Issues']),
#  (<src.core.Book at 0x113dfacb0>, ['Health', 'Environment', 'Economics']),
#  (<src.core.Book at 0x113dface0>, ['Marketing', 'Business', 'Psychology']),
#  (<src.core.Book at 0x113dfad10>,
#   ['Economics', 'Technology', 'Social Issues']),
#  (<src.core.Book at 0x113dfad40>, ['Nature', 'Environment', 'Science']),
#  (<src.core.Book at 0x113dfad70>, ['Marketing', 'Business', 'Psychology']),
#  (<src.core.Book at 0x113dfada0>,
#   ['Self-Help', 'Health & Wellness', 'Personal Development']),
#  (<src.core.Book at 0x113dfaef0>, ['Technology', 'Security', 'Communication']),
#  (<src.core.Book at 0x113dfae00>,
#   ['Psychology', 'Self-Help', 'Relationships']),
#  (<src.core.Book at 0x113dfae30>, ['Politics', 'Biography', 'Current Events']),
#  (<src.core.Book at 0x113dfaf20>,
#   ['Health', 'Self-Help', 'Personal Development']),
#  (<src.core.Book at 0x113dfaf50>,
#   ['Self-Help', 'Psychology', 'Personal Development']),
#  (<src.core.Book at 0x113dfaf80>,
#   ['Psychology', 'Self-Help', 'Communication']),
#  (<src.core.Book at 0x113dfafb0>,
#   ['Creativity', 'Self-Help', 'Personal Development']),
#  (<src.core.Book at 0x113dfafe0>,
#   ['Self-Improvement', 'Business', 'Motivation']),
#  (<src.core.Book at 0x113dfb010>,
#   ["Children's Books", 'Self-Help', 'Spirituality']),
#  (<src.core.Book at 0x113dfb040>, ['Journalism', 'Politics', 'History']),
#  (<src.core.Book at 0x113dfb070>, ['Business', 'Self-Help', 'Communication']),
#  (<src.core.Book at 0x113dfb0a0>, ['Business', 'Finance', 'Management']),
#  (<src.core.Book at 0x113dfb0d0>, ['Nutrition', 'Health', 'Self-Improvement']),
#  (<src.core.Book at 0x113dfb100>,
#   ['Philosophy', 'Media Literacy', 'Self-Help']),
#  (<src.core.Book at 0x113dfb130>,
#   ['Self-Help', 'Psychology', 'Personal Development']),
#  (<src.core.Book at 0x113dfb160>,
#   ['Philosophy', 'Social Science', 'Future Studies']),
#  (<src.core.Book at 0x113dfb190>, ['Health', 'Wellness', 'Nutrition']),
#  (<src.core.Book at 0x113dfb1c0>, ['Health', 'Science', 'Safety']),
#  (<src.core.Book at 0x113dfb1f0>,
#   ['Personal Development', 'Psychology', 'Social Science']),
#  (<src.core.Book at 0x113dfb220>, ['Self-Improvement', 'Psychology', 'Games']),
#  (<src.core.Book at 0x113dfb250>,
#   ['History', 'Cultural Studies', 'Holiday Celebrations']),
#  (<src.core.Book at 0x113dfb280>,
#   ['Personal Development', 'Success', 'Motivation']),
#  (<src.core.Book at 0x113dfb2b0>, ['Nutrition', 'Health', 'Wellness']),
#  (<src.core.Book at 0x113dfb2e0>,
#   ['Productivity', 'Self-Help', 'Time Management']),
#  (<src.core.Book at 0x113dfb310>, ['Literature', 'Memoir', 'History']),
#  (<src.core.Book at 0x113dfb340>, ['History', 'LGBTQ+', 'Social Issues']),
#  (<src.core.Book at 0x113dfb370>,
#   ['Essays', 'Self-Help', 'Environmental Studies']),
#  (<src.core.Book at 0x113dfb3a0>,
#   ['Self-Help', 'Productivity', 'Personal Development']),
#  (<src.core.Book at 0x113dfb3d0>,
#   ['Literature', 'Self-Help', 'Personal Development']),
#  (<src.core.Book at 0x113dfb400>,
#   ['Business', 'Communication', 'Self-Improvement']),
#  (<src.core.Book at 0x113dfb430>,
#   ['Entrepreneurship', 'Personal Finance', 'Self-Help']),
#  (<src.core.Book at 0x113dfb460>, ['Finance', 'Technology', 'Business']),
#  (<src.core.Book at 0x113dfb490>,
#   ['Relationships', 'Self-Help', 'Spirituality']),
#  (<src.core.Book at 0x113dfb4c0>, ['Nutrition', 'Weight Loss', 'Health']),
#  (<src.core.Book at 0x113dfb4f0>,
#   ['Psychology', 'Social Science', 'Communication']),
#  (<src.core.Book at 0x113dfb520>,
#   ['Self-Help', 'Personal Development', 'Wellness']),
#  (<src.core.Book at 0x113dfb550>, ['Sports', 'Economics', 'Cultural Studies']),
#  (<src.core.Book at 0x113dfb580>,
#   ['Self-Help', 'Personal Development', 'Health']),
#  (<src.core.Book at 0x113dfb5b0>, ['Health', 'Nutrition', 'Wellness']),
#  (<src.core.Book at 0x113dfb5e0>, ['Relationships', 'Self-Help', 'Marriage']),
#  (<src.core.Book at 0x113dfb610>,
#   ['Self-Help', 'Communication', 'Personal Development']),
#  (<src.core.Book at 0x113dfb640>,
#   ['Business', 'Technology', 'Self-Improvement']),
#  (<src.core.Book at 0x113dfb670>,
#   ['Psychology', 'Self-Help', 'Communication']),
#  (<src.core.Book at 0x113dfb6a0>,
#   ['Personal Development', 'Self-Help', 'Lifestyle']),
#  (<src.core.Book at 0x113dfb6d0>,
#   ['Social Science', 'Psychology', 'Business']),
#  (<src.core.Book at 0x113dfb700>,
#   ['Social Issues', 'Race Relations', 'Cultural Studies']),
#  (<src.core.Book at 0x113dfb730>,
#   ['Finance', 'Self-Help', 'Personal Development']),
#  (<src.core.Book at 0x113dfb760>,
#   ['Self-Help', 'Spirituality', 'Personal Development']),
#  (<src.core.Book at 0x113dfb790>, ['Military', 'Biography', 'Mental Health']),
#  (<src.core.Book at 0x113dfb7c0>, ['History', 'Biography', 'Politics']),
#  (<src.core.Book at 0x113dfb7f0>,
#   ['Relationships', 'Self-Help', 'Communication']),
#  (<src.core.Book at 0x113dfb820>, ['Business', 'Self-Help', 'Psychology']),
#  (<src.core.Book at 0x113dfb850>, ['Business', 'Culture', 'Inspiration']),
#  (<src.core.Book at 0x113dfb880>,
#   ['Self-Help', 'Relationships', 'Personal Development']),
#  (<src.core.Book at 0x113dfb8b0>,
#   ['Gaming', 'Self-Improvement', 'Social Change']),
#  (<src.core.Book at 0x113dfb8e0>, ['Business', 'Technology', 'Social Media']),
#  (<src.core.Book at 0x113dfb910>,
#   ['Cooking', 'Food Science', 'Culinary Arts']),
#  (<src.core.Book at 0x113dfb940>, ['Relationships', 'Self-Help', 'Sexuality']),
#  (<src.core.Book at 0x113dfb970>, ['Business', 'Culture', 'Psychology']),
#  (<src.core.Book at 0x113dfb9a0>,
#   ['Business', 'Career Development', 'Entrepreneurship']),
#  (<src.core.Book at 0x113dfb9d0>,
#   ['Self-Help', 'Mental Health', 'Personal Development']),
#  (<src.core.Book at 0x113dfba00>, ['Science', 'Philosophy', 'Technology']),
#  (<src.core.Book at 0x113dfba30>, ['Philosophy', 'Self-Help', 'Science']),
#  (<src.core.Book at 0x113dfba60>,
#   ['Leadership', 'Business', 'Self-Improvement']),
#  (<src.core.Book at 0x113dfba90>,
#   ['Design', 'Social Change', 'Environmental Studies']),
#  (<src.core.Book at 0x113dfbac0>,
#   ['Business', 'Self-Help', 'Women Empowerment']),
#  (<src.core.Book at 0x113dfbaf0>, ['Health', 'Nutrition', 'Lifestyle']),
#  (<src.core.Book at 0x113dfbb20>,
#   ['Self-Help', 'Mental Health', 'Spirituality']),
#  (<src.core.Book at 0x113dfbb50>,
#   ['Self-Help', 'Personal Development', 'Success']),
#  (<src.core.Book at 0x113dfbb80>, ['Business', 'Culture', 'Inspiration']),
#  (<src.core.Book at 0x113dfbbb0>, ['Biography', 'Music', 'Self-Help']),
#  (<src.core.Book at 0x113dfbbe0>,
#   ['Self-Help', 'Spirituality', 'Personal Development']),
#  (<src.core.Book at 0x113dfbc70>,
#   ['Self-Help', 'Personal Development', 'Psychology']),
#  (<src.core.Book at 0x113dfbcd0>, ['Self-Help', 'Science', 'Time Management']),
#  (<src.core.Book at 0x113dfbca0>,
#   ['Psychology', 'Self-Help', 'Mental Health']),
#  (<src.core.Book at 0x113dfbc40>,
#   ['Business', 'Entrepreneurship', 'Self-Help']),
#  (<src.core.Book at 0x113dfbc10>, ['Writing', 'Language', 'Communication']),
#  (<src.core.Book at 0x113dfbd00>,
#   ['Home Improvement', 'Self-Help', 'Lifestyle']),
#  (<src.core.Book at 0x113dfbd30>,
#   ['Self-Help', 'Mental Health', 'Personal Development']),
#  (<src.core.Book at 0x113dfbd60>, ['Self-Help', 'Business', 'Productivity']),
#  (<src.core.Book at 0x113dfbd90>,
#   ['Business', 'Self-Help', 'Personal Development']),
#  (<src.core.Book at 0x113dfbdc0>,
#   ['Communication', 'Personal Development', 'Social Media']),
#  (<src.core.Book at 0x113dfbdf0>,
#   ['Self-Help', 'Mental Health', 'Personal Development']),
#  (<src.core.Book at 0x113dfbe20>, ['Nutrition', 'Dieting', 'Health']),
#  (<src.core.Book at 0x113dfbe50>,
#   ['Relationships', 'Self-Help', 'Personal Development']),
#  (<src.core.Book at 0x113dfbe80>, ['Personal Development', 'Sports', 'Arts']),
#  (<src.core.Book at 0x113dfbeb0>,
#   ['Self-Help', 'Personal Development', 'Empowerment']),
#  (<src.core.Book at 0x113dfbee0>, ['Psychology', 'Education', 'Self-Help']),
#  (<src.core.Book at 0x113dfbf10>, ['Health', 'Nutrition', 'Fitness']),
#  (<src.core.Book at 0x113dfbf40>,
#   ['Self-Help', 'Mental Health', 'Personal Development']),
#  (<src.core.Book at 0x113dfbf70>, ['Health', 'Fitness', 'Psychology']),
#  (<src.core.Book at 0x113dfbfa0>,
#   ['Women Empowerment', 'Latin American Studies', 'Social Issues']),
# ...
#  (<src.core.Book at 0x113e16d10>, ['Sports', 'Biographies', 'History']),
#  (<src.core.Book at 0x113e16d40>, ['Business', 'Leadership', 'Productivity']),
#  (<src.core.Book at 0x113e16d70>, ['Business', 'Self-Help', 'Culinary']),
#  (<src.core.Book at 0x113e16da0>,
#   ['Psychology', 'Self-Help', 'Mental Health']),
#  (<src.core.Book at 0x113e16dd0>,
#   ['Relationships', 'Self-Help', 'Psychology']),
#  (<src.core.Book at 0x113e16e00>,
#   ['Emotional Intelligence', 'Personal Development', 'Parenting']),
#  (<src.core.Book at 0x113e16e30>,
#   ['Biography', 'Memoir', 'Personal Development']),
#  (<src.core.Book at 0x113e16e60>,
#   ['Philosophy', 'Social Science', 'Classics']),
#  (<src.core.Book at 0x113e16e90>,
#   ['Self-Help', 'Personal Development', 'Productivity']),
#  (<src.core.Book at 0x113e16ec0>,
#   ['Relationships', 'Self-Help', 'Personal Development']),
#  (<src.core.Book at 0x113e16ef0>, ['Philosophy', 'Self-Help', 'Classics']),
#  (<src.core.Book at 0x113e16f20>, ['Business', 'Technology', 'Economics']),
#  (<src.core.Book at 0x113e16f50>,
#   ['Self-Help', 'Personal Development', 'Motivation']),
#  (<src.core.Book at 0x113e16f80>,
#   ['Personal Finance', 'Self-Help', 'Mindfulness']),
#  (<src.core.Book at 0x113e16fb0>,
#   ['Self-Help', 'Relationships', 'Personal Development']),
#  (<src.core.Book at 0x113e16fe0>,
#   ['Parenting', 'Child Development', 'Education']),
#  (<src.core.Book at 0x113e17010>,
#   ['Gender Studies', 'Sexuality', 'Social Issues']),
#  (<src.core.Book at 0x113e17040>,
#   ['Self-Help', 'Personal Development', 'Mental Health']),
#  (<src.core.Book at 0x113e17070>, ['Business', 'Leadership', 'Management']),
#  (<src.core.Book at 0x113e170a0>,
#   ['Self-Improvement', 'Performance', 'Motivation']),
#  (<src.core.Book at 0x113e170d0>, ['Science', 'Popular Science', 'Astronomy']),
#  (<src.core.Book at 0x113e17100>, ['Politics', 'Biography', 'Self-Help']),
#  (<src.core.Book at 0x113e17130>,
#   ['Politics', 'Social Justice', 'Leadership']),
#  (<src.core.Book at 0x113e17160>, ['Nutrition', 'Psychology', 'Lifestyle']),
#  (<src.core.Book at 0x113e17190>, ['Self-Help', 'Mindfulness', 'Wellness']),
#  (<src.core.Book at 0x113e171c0>,
#   ['Self-Help', 'Productivity', 'Personal Development']),
#  (<src.core.Book at 0x113e171f0>,
#   ['Productivity', 'Self-Help', 'Mindfulness']),
#  (<src.core.Book at 0x113e17220>,
#   ['Self-Help', 'Personal Development', 'Motivation']),
#  (<src.core.Book at 0x113e17250>,
#   ['Self-Help', 'Psychology', 'Relationships']),
#  (<src.core.Book at 0x113e17280>,
#   ['Self-Help', 'Health & Wellness', 'Nutrition']),
#  (<src.core.Book at 0x113e172b0>,
#   ['Business', 'Self-Help', 'Conflict Resolution']),
#  (<src.core.Book at 0x113e172e0>, ['Creativity', 'Self-Help', 'Business']),
#  (<src.core.Book at 0x113e17310>,
#   ['Psychology', 'Self-Help', 'Mental Health']),
#  (<src.core.Book at 0x113e17340>, ['Business', 'Leadership', 'Strategy']),
#  (<src.core.Book at 0x113e17370>, ['History', 'Biography', "Women's Studies"]),
#  (<src.core.Book at 0x113e173a0>,
#   ['History', 'Women Studies', 'Cultural Studies']),
#  (<src.core.Book at 0x113e173d0>, ['Self-Help', 'Productivity', 'Motivation']),
#  (<src.core.Book at 0x113e17400>,
#   ['Self-Help', 'Motivation', 'Personal Development']),
#  (<src.core.Book at 0x113e17430>,
#   ['Self-Help', 'Business', 'Personal Development']),
#  (<src.core.Book at 0x113e17460>,
#   ['Personal Development', 'Finance', 'Philosophy']),
#  (<src.core.Book at 0x113e17490>, ['Humor', 'Personal Development', 'Memoir']),
#  (<src.core.Book at 0x113e174c0>, ['History', 'Politics', 'Cultural Studies']),
#  (<src.core.Book at 0x113e174f0>, ['Mental Health', 'Self-Help', 'Wellness']),
#  (<src.core.Book at 0x113e17520>,
#   ['Self-Help', 'Personal Development', 'Philosophy']),
#  (<src.core.Book at 0x113e17550>,
#   ['Psychology', 'Self-Help', 'Personal Development']),
#  (<src.core.Book at 0x113e17580>,
#   ['Creativity', 'Business', 'Personal Development']),
#  (<src.core.Book at 0x113e175b0>,
#   ['Career Development', 'Job Search', 'Professional Networking']),
#  (<src.core.Book at 0x113e175e0>,
#   ['Relationships', 'Personal Development', 'Psychology']),
#  (<src.core.Book at 0x113e17610>,
#   ['Conflict Resolution', 'Personal Development', 'Psychology']),
#  (<src.core.Book at 0x113e17640>,
#   ['Social Issues', 'Education', 'Young Adult']),
#  (<src.core.Book at 0x113e17670>, ['Science', 'Philosophy', 'Cosmology']),
#  (<src.core.Book at 0x113e176a0>, ['Psychology', 'War Studies', 'Self-Help']),
#  (<src.core.Book at 0x113e176d0>,
#   ['Parenting', 'Technology', 'Family Wellness']),
#  (<src.core.Book at 0x113e17700>,
#   ['Self-Help', 'Personal Development', 'Mindfulness']),
#  (<src.core.Book at 0x113e17730>,
#   ['Self-Help', 'Psychology', 'Relationships']),
#  (<src.core.Book at 0x113e17760>,
#   ['Literature', 'Literary Criticism', 'Reading Skills']),
#  (<src.core.Book at 0x113e17790>,
#   ['Humor', 'Personal Essays', 'Graphic Novels']),
#  (<src.core.Book at 0x113e177c0>, ['Self-Help', 'Psychology', 'Spirituality']),
#  (<src.core.Book at 0x113e177f0>,
#   ['Career Development', 'Personal Growth', 'Workplace Satisfaction']),
#  (<src.core.Book at 0x113e17820>, ['Art', 'History', 'Cultural Studies']),
#  (<src.core.Book at 0x113e17850>, ['Biography', 'Science', 'History']),
#  (<src.core.Book at 0x113e17880>,
#   ['Parenting', 'Cultural Insights', 'Self-Help']),
#  (<src.core.Book at 0x113e178b0>, ['Business', 'Psychology', 'Self-Help']),
#  (<src.core.Book at 0x113e178e0>,
#   ['History', 'Cultural Studies', 'Geography']),
#  (<src.core.Book at 0x113e17910>, ['Business', 'Technology', 'Culture']),
#  (<src.core.Book at 0x113e17940>, ['Psychology', 'Self-Help', 'Parenting']),
#  (<src.core.Book at 0x113e17970>,
#   ['Self-Help', 'Psychology', 'Personal Development']),
#  (<src.core.Book at 0x113e179a0>,
#   ['Self-Help', 'Psychology', 'Personal Development']),
#  (<src.core.Book at 0x113e179d0>, ['Memoir', 'Sociology', 'Social Issues']),
#  (<src.core.Book at 0x113e17a00>, ['Psychology', 'Biology', 'Self-Help']),
#  (<src.core.Book at 0x113e17a30>,
#   ['Self-Help', 'Personal Development', 'Mindfulness']),
#  (<src.core.Book at 0x113e17a60>, ['Business', 'Sales', 'Marketing']),
#  (<src.core.Book at 0x113e17a90>,
#   ['Memoir', 'Cultural Identity', 'Family Relationships']),
#  (<src.core.Book at 0x113e17ac0>, ['Beauty', 'Health', 'Self-Care']),
#  (<src.core.Book at 0x113e17af0>,
#   ['Self-Help', 'Personal Development', 'Motivation']),
#  (<src.core.Book at 0x113e17b20>, ['Politics', 'Business', 'Social Change']),
#  (<src.core.Book at 0x113e17b50>,
#   ['Self-Help', 'Mindfulness', 'Personal Development']),
#  (<src.core.Book at 0x113e17b80>,
#   ['Self-Help', 'Personal Development', 'Business Strategy']),
#  (<src.core.Book at 0x113e17bb0>, ['Parenting', 'Psychology', 'Self-Help']),
#  (<src.core.Book at 0x113e17be0>, ['Literature', 'Feminism', 'Creativity']),
#  (<src.core.Book at 0x113e17c10>, ['Politics', 'True Crime', 'History']),
#  (<src.core.Book at 0x113e17c40>,
#   ['Self-Help', 'Personal Development', 'Motivation']),
#  (<src.core.Book at 0x113e17c70>,
#   ['Home Improvement', 'Self-Help', 'Lifestyle']),
#  (<src.core.Book at 0x113e17ca0>, ['Philosophy', 'Psychology', 'Religion']),
#  (<src.core.Book at 0x113e17cd0>,
#   ['Self-Help', 'Psychology', 'Personal Development']),
#  (<src.core.Book at 0x113e17d00>, ['Health', 'Self-Help', 'Science']),
#  (<src.core.Book at 0x113e17d30>,
#   ['Leadership', 'Personal Development', 'Coaching']),
#  (<src.core.Book at 0x113e17d60>,
#   ['Relationships', 'Self-Help', 'Psychology']),
#  (<src.core.Book at 0x113e17d90>,
#   ['Parenting', 'Child Development', 'Family Relationships']),
#  (<src.core.Book at 0x113e17dc0>,
#   ['Leadership', 'Personal Development', 'Business Strategy']),
#  (<src.core.Book at 0x113e17df0>, ['Memoir', 'LGBTQ+', 'Identity']),
#  (<src.core.Book at 0x113e17e20>, ['Relationships', 'Self-Help', 'Marriage']),
#  (<src.core.Book at 0x113e17e50>,
#   ['Self-Help', 'Spirituality', 'Personal Development']),
#  (<src.core.Book at 0x113e17e80>, ['Relationships', 'Self-Help', 'Humor']),
#  (<src.core.Book at 0x113e17eb0>, ['Self-Help', 'Spirituality', 'Psychology']),
#  (<src.core.Book at 0x113e17ee0>, ['Travel', 'History', 'Adventure']),
#  (<src.core.Book at 0x113e17f10>, ['Self-Help', 'Environment', 'Motivation']),
#  (<src.core.Book at 0x113e17f40>,
#   ['Productivity', 'Self-Help', 'Time Management']),
#  (<src.core.Book at 0x113e17f70>,
#   ['Holidays', 'Cultural Traditions', 'Travel']),
#  (<src.core.Book at 0x113e17fa0>,
#   ['Psychology', 'Self-Help', 'Relationships']),
#  (<src.core.Book at 0x113e14a30>, ['Philosophy', 'Self-Help', 'Spirituality']),
#  (<src.core.Book at 0x113e14cd0>,
#   ['Self-Help', 'Personal Development', 'Emotional Wellness']),
#  (<src.core.Book at 0x113e16830>, ['Business', 'Self-Help', 'Psychology']),
#  (<src.core.Book at 0x113e17fd0>,
#   ['Spirituality', 'Self-Help', 'Personal Development']),
#  (<src.core.Book at 0x113e16860>,
#   ['Self-Help', 'Time Management', 'Personal Development']),
#  (<src.core.Book at 0x113e16800>, ['Business', 'Culture', 'Social Issues']),
#  (<src.core.Book at 0x113e156c0>,
#   ['Career Development', 'Diversity & Inclusion', 'Empowerment']),
#  (<src.core.Book at 0x113e24040>,
#   ['Career Development', 'Social Critique', 'Workplace Culture']),
#  (<src.core.Book at 0x113e27790>,
#   ['Self-Help', 'Personal Development', 'Philosophy']),
#  (<src.core.Book at 0x113e275e0>,
#   ['Psychology', 'Self-Help', 'Family Dynamics']),
#  (<src.core.Book at 0x113e24100>,
#   ['Self-Help', 'Personal Development', 'Motivation']),
#  (<src.core.Book at 0x113e24130>,
#   ['Health', 'Lifestyle', 'Personal Development']),
#  (<src.core.Book at 0x113e24160>, ['Health', 'Science', 'Self-Improvement']),
#  (<src.core.Book at 0x113e24190>, ['Memoir', 'Grief', 'Literature']),
#  (<src.core.Book at 0x113e241c0>,
#   ['Mental Health', 'Self-Help', 'Personal Development']),
#  (<src.core.Book at 0x113e241f0>,
#   ['Parenting', 'Humor', 'Personal Development']),
#  (<src.core.Book at 0x113e24220>, ['Humor', "Women's Issues", 'Self-Help']),
#  (<src.core.Book at 0x113e24250>,
#   ['Mental Health', 'Self-Help', 'Personal Development']),
#  (<src.core.Book at 0x113e24280>, ['Self-Help', 'Mindfulness', 'Happiness']),
#  (<src.core.Book at 0x113e242b0>,
#   ['Self-Help', 'Home & Garden', 'Spirituality']),
#  (<src.core.Book at 0x113e242e0>,
#   ['Self-Help', 'Social Issues', 'Cultural Studies']),
#  (<src.core.Book at 0x113e24310>,
#   ['Technology', 'Career Development', 'Education']),
#  (<src.core.Book at 0x113e24340>,
#   ['Psychology', 'Self-Help', 'Personal Development']),
#  (<src.core.Book at 0x113e24370>, ['Business', 'Self-Help', 'Productivity']),
#  (<src.core.Book at 0x113e243a0>,
#   ['History', 'Social Issues', 'Cultural Studies']),
#  (<src.core.Book at 0x113e243d0>,
#   ['Self-Help', 'Personal Development', 'Psychology']),
#  (<src.core.Book at 0x113e24400>,
#   ['Finance', 'Self-Help', 'Personal Development']),
#  (<src.core.Book at 0x113e24430>, ['Health', 'Self-Help', 'Psychology']),
#  (<src.core.Book at 0x113e24460>,
#   ['Personal Development', 'Self-Help', 'Psychology']),
#  (<src.core.Book at 0x113e24490>, ['Literature', 'Education', 'Self-Help']),
#  (<src.core.Book at 0x113e244c0>,
#   ['Motivation', 'Self-Help', 'Personal Development']),
#  (<src.core.Book at 0x113e244f0>,
#   ['Relationships', 'Conflict Resolution', 'Personal Development']),
#  (<src.core.Book at 0x113e24520>,
#   ['Finance', 'Investing', 'Personal Development']),
#  (<src.core.Book at 0x113e24550>,
#   ['Fiction', 'Cultural Studies', 'Historical Literature']),
#  (<src.core.Book at 0x113e24580>, ['Business', 'Innovation', 'Culture']),
#  (<src.core.Book at 0x113e245b0>, ['Health', 'Self-Help', 'Wellness']),
#  (<src.core.Book at 0x113e245e0>, ['Self-Help', 'Spirituality', 'Philosophy']),
#  (<src.core.Book at 0x113e24610>, ['Health', 'Wellness', 'Self-Help']),
#  (<src.core.Book at 0x113e24640>, ['Creativity', 'Innovation', 'Leadership']),
#  (<src.core.Book at 0x113e24670>,
#   ['Self-Help', 'Personal Development', 'Decision Making']),
#  (<src.core.Book at 0x113e246a0>, ['Politics', 'History', 'Self-Help']),
#  (<src.core.Book at 0x113e246d0>, ['History', 'Social Justice', 'Biography']),
#  (<src.core.Book at 0x113e24700>, ['Health', 'Self-Help', 'Relationships']),
#  (<src.core.Book at 0x113e24730>,
#   ['Self-Help', 'Personal Development', 'Mental Health']),
#  (<src.core.Book at 0x113e24760>,
#   ['Self-Help', 'Personal Development', 'Psychology']),
#  (<src.core.Book at 0x113e24790>,
#   ['Parenting', 'Personal Development', 'Family Planning']),
#  (<src.core.Book at 0x113e247c0>,
#   ['Business', 'Health & Wellness', 'Technology']),
#  (<src.core.Book at 0x113e247f0>, ['Parenting', 'Humor', 'Self-Help']),
#  (<src.core.Book at 0x113e24820>, ['Biography', 'Business', 'Innovation']),
#  (<src.core.Book at 0x113e24850>, ['Science', 'Biography', 'Technology']),
#  (<src.core.Book at 0x113e24880>, ['Design', 'Typography', 'Education']),
#  (<src.core.Book at 0x113e248b0>, ['Business', 'Productivity', 'Management']),
#  (<src.core.Book at 0x113e248e0>,
#   ['Social Issues', 'Cultural Studies', 'Political Commentary']),
#  (<src.core.Book at 0x113e24910>, ['Memoir', 'Migration', 'Personal Growth']),
#  (<src.core.Book at 0x113e24940>,
#   ['Self-Help', 'Personal Development', 'Motivation']),
#  (<src.core.Book at 0x113e24970>,
#   ['Self-Help', 'Psychology', 'Communication']),
#  (<src.core.Book at 0x113e249a0>, ['Energy', 'Technology', 'Society']),
#  (<src.core.Book at 0x113e249d0>, ['Biography', 'Self-Help', 'Royalty']),
#  (<src.core.Book at 0x113e24a00>, ['Self-Help', 'Psychology', 'Philosophy']),
#  (<src.core.Book at 0x113e24a30>, ['Science', 'Nature', 'Philosophy']),
#  (<src.core.Book at 0x113e24a60>,
#   ['Business', 'Entrepreneurship', 'Leadership']),
#  (<src.core.Book at 0x113e24a90>, ['Philosophy', 'Science', 'Ethics']),
#  (<src.core.Book at 0x113e24ac0>, ['Business', 'Leadership', 'Management']),
#  (<src.core.Book at 0x113e24af0>, ['Ethics', 'Technology', 'Social Issues']),
#  (<src.core.Book at 0x113e24b20>,
#   ['Psychology', 'Social Issues', 'Self-Help']),
#  (<src.core.Book at 0x113e24b50>, ['Science', 'Technology', 'Psychology']),
#  (<src.core.Book at 0x113e24b80>,
#   ['Education', 'Science', 'Self-Improvement']),
#  (<src.core.Book at 0x113e24bb0>,
#   ['Social Issues', 'Work Culture', 'Economic Critique']),
#  (<src.core.Book at 0x113e24be0>, ['Travel', 'Philosophy', 'Self-Discovery']),
#  (<src.core.Book at 0x113e24c10>, ['Parenting', 'Pregnancy', 'Family Life']),
#  (<src.core.Book at 0x113e24c40>,
#   ['Parenting', 'Self-Help', 'Conflict Resolution']),
#  (<src.core.Book at 0x113e24c70>, ['Psychology', 'Self-Help', 'Health']),
#  (<src.core.Book at 0x113e24ca0>,
#   ['Psychology', 'Social Issues', 'Self-Improvement']),
#  (<src.core.Book at 0x113e24cd0>, ['Biography', 'Politics', 'Family']),
#  (<src.core.Book at 0x113e24d00>,
#   ['Self-Help', 'Personal Development', 'Creativity']),
#  (<src.core.Book at 0x113e24d30>, ['History', 'War', 'Survivor Stories']),
#  (<src.core.Book at 0x113e24d60>,
#   ['Parenting', 'Family', 'Personal Development']),
#  (<src.core.Book at 0x113e24d90>, ['Nutrition', 'Health', 'Self-Help']),
#  (<src.core.Book at 0x113e24dc0>, ['Business', 'Leadership', 'Strategy']),
#  (<src.core.Book at 0x113e24df0>,
#   ['Parenting', 'Self-Help', 'Personal Development']),
#  (<src.core.Book at 0x113e24e20>,
#   ['Self-Help', 'Personal Development', 'Psychology']),
#  (<src.core.Book at 0x113e24e50>, ['Philosophy', 'Spirituality', 'Self-Help']),
#  (<src.core.Book at 0x113e24e80>,
#   ['Social Media', 'Marketing', 'Personal Branding']),
#  (<src.core.Book at 0x113e24eb0>, ['Business', 'Creativity', 'Innovation']),
#  (<src.core.Book at 0x113e24ee0>,
#   ['Self-Help', 'Personal Development', 'Psychology']),
#  (<src.core.Book at 0x113e24f10>, ['Health', 'Science', 'Self-Help']),
#  (<src.core.Book at 0x113e24fd0>, ['Performing Arts', 'Humor', 'Self-Help']),
#  (<src.core.Book at 0x113e24f70>, ['Business', 'Self-Help', 'Motivation']),
#  (<src.core.Book at 0x113e24fa0>,
#   ['Spirituality', 'Self-Help', 'Alternative Medicine']),
#  (<src.core.Book at 0x113e25000>,
#   ['Politics', 'Media Literacy', 'Digital Culture']),
#  (<src.core.Book at 0x113e25030>,
#   ['Self-Help', 'Mental Health', 'Personal Development']),
#  ...]

# %%
class FormalizedCategory(BaseModel):
        name: str = Field(description='Category name')
        description: str = Field(description='Category description')


class FormalizedBookCategoriesResponseModel(BaseModel):
    categories: list[FormalizedCategory] = Field(description="Final list of categories")


class OpenAICategoriesConsolidator:
    
    def __init__(self) -> None:
        self._logger = StatisticsLogger()

        llm_categories_consolidator = ChatOpenAI(model='gpt-4o-mini', temperature=0).with_structured_output(FormalizedBookCategoriesResponseModel)
        prompt_template_categories_consolidator = PromptTemplate.from_template(
            'You are an expert in taxonomy and classification. I have a list of raw book categories that contains: \n'
            ' - Near-duplicates (e.g., "Sexuality" and "Sexual Health") \n'
            ' - Broad and specific categories (e.g., "Fitness" and "Martial Arts") \n'
            ' - Overlapping topics that could be consolidated \n'
            'Your task is to synthesize these into {min}-{max} well-balanced final categories following these instructions: \n'
            ' 1. **Avoid long category names. E.g. "Education" is better than "Education & Learning", "Cooking" is better than "Culinary Arts & Food"**.\n'
            ' 2. Minimize redundancy. \n'
            ' 4. Cover all major themes while avoiding excessive granularity. \n'
            ' 5. Use clear, intuitive, concise names that make sense to a broad audience. \n'
            ' 6. Consider the fact that these categories will be used primarily for non-fiction books that help adults to grow and learn new stuff. \n'
            'Raw book categories:\n'
            '{categories} \n'
            'Please return the final list of categories along with a description (specification) to each of them. \n'
        )

        self._categories_consolidator_chain = prompt_template_categories_consolidator | llm_categories_consolidator

    @property
    def logger(self) -> StatisticsLogger:
        return self._logger
    
    def consolidate_categories(self, categories: list[str], desired_min: int, desired_max: int) -> list[FormalizedCategory]:
        with get_openai_callback() as cb:
            res = self._categories_consolidator_chain.invoke({
                'categories': categories,
                'min': desired_min,
                'max': desired_max
            })

            self._logger.log(
                prompt_tokens=cb.prompt_tokens,
                completion_tokens=cb.completion_tokens,
                cost=cb.total_cost
            )

        return res.categories

# %%
consolidator = OpenAICategoriesConsolidator()

# %%
min_cat = 10
max_cat = 15
final_categories = consolidator.consolidate_categories(list(set(all_categories)), min_cat, max_cat)

# %%
print(consolidator.logger)
# Out:
# Statistics:
# 	Num inferences: 4
# 	Average Prompt Tokens: 2013.0
# 	Average Completion Tokens: 586.5
# 	Average Cost: 0.0006538499999999999
# 	Total Prompt Tokens: 8052
# 	Total Completion Tokens: 2346
# 	Total Cost: 0.0026153999999999995

# %%
df_final_categories = pd.DataFrame([v.__dict__ for v in final_categories])

# %%
df_final_categories
# Out:
#                           name  \
# 0         Personal Development
# 1            Health & Wellness
# 2              Social Sciences
# 3         Business & Economics
# 4         Education & Learning
# 5           Politics & Society
# 6            Creativity & Arts
# 7         Science & Technology
# 8            History & Culture
# 9       Family & Relationships
# 10         Lifestyle & Leisure
# 11  Psychology & Mental Health
# 12      Self-Help & Motivation
# 13       Environmental Studies
# 14          Career Development
#
#                                           description
# 0   Books focused on self-improvement, emotional i...
# 1   Resources on physical health, mental well-bein...
# 2   Explorations of human behavior, society, cultu...
# 3   Insights into business management, finance, ma...
# 4   Guides on personal and professional developmen...
# 5   Analysis of political theories, civil rights, ...
# 6   Books on creative processes, art, literature, ...
# 7   Explorations of scientific concepts, technolog...
# 8   Insights into historical events, cultural stud...
# 9   Guides on family dynamics, parenting, and inte...
# 10  Books on hobbies, cooking, travel, and persona...
# 11  Resources on psychological theories, mental he...
# 12  Inspirational stories and strategies for perso...
# 13  Explorations of environmental issues, sustaina...
# 14  Guides on job searching, professional networki...

# %%
df_final_categories.to_csv(p_data_dest / f'v0.0.1.final_categories.{min_cat}-{max_cat}.csv')
