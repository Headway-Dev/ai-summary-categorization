# %%
from pathlib import Path

import pandas as pd

# %%
p_books_with_predictions = Path('../data/books_predictions.csv')

# %%
df_books = pd.read_csv(p_books_with_predictions)
for col in ['categories', 'learning_items', 'pred_reasoning_steps', 'pred_categories']:
    df_books[col] = df_books[col].apply(lambda s: [] if pd.isna(s) else s.split('|'))

# %%
df_books.head()
# Out:
#    Unnamed: 0                      firebase_document_path  \
# 0           0  books/0059543c-a8e5-4615-a78c-69f8e73c19c1
# 1           1  books/00bb4531-5150-44af-9eb1-c160c7d26ed6
# 2           2                  books/012399fc36f74c489e4e
# 3           3  books/012d6fde-51e2-4289-822a-1cbb57394bcd
# 4           4                  books/017dab0f35d34af59653
#
#                                      id  \
# 0  0059543c-a8e5-4615-a78c-69f8e73c19c1
# 1  00bb4531-5150-44af-9eb1-c160c7d26ed6
# 2                  012399fc36f74c489e4e
# 3  012d6fde-51e2-4289-822a-1cbb57394bcd
# 4                  017dab0f35d34af59653
#
#                                                title            author  \
# 0  Parenting the New Teen in the Age of Anxiety: ...        John Duffy
# 1  Right Thing, Right Now: Good Values, Good Char...      Ryan Holiday
# 2  Eat Move Sleep: How Small Choices Lead to Big ...          Tom Rath
# 3  From Strength to Strength: Finding Success, Ha...  Arthur C. Brooks
# 4  Dream Big: Know What You Want, Why You Want It...          Bob Goff
#
#                                             overview  \
# 0  What’s inside\nYou're looking at a modern pare...
# 1  What’s inside\nThe modern world has many fasci...
# 2  What’s inside\nDiscover how inner strength, wi...
# 3  What’s inside\nAchieving your dreams is fulfil...
# 4  What’s inside\nBreak free from the cycle of un...
#
#                                      author_overview  \
# 0  John Duffy is a successful clinical psychologi...
# 1  Ryan Holiday is known for bringing philosophy ...
# 2  Tom Rath is a renowned author of best-selling ...
# 3  Arthur C. Brooks is a scientist whose research...
# 4  Robert Kendall Goff is a speaker, lawyer, auth...
#
#                  categories  \
# 0                  [Family]
# 1             [Self-Growth]
# 2                  [Health]
# 3  [Happiness, Self-Growth]
# 4             [Self-Growth]
#
#                                       learning_items  \
# 0  [Why your teenager is glued to their screens, ...
# 1  [Which four core virtues pave the way to a suc...
# 2  [The power of positive dietary choices, How mo...
# 3  [The two kinds of intelligence , How to maximi...
# 4  [Ways to pick one ambition to focus on, Strate...
#
#                                 pred_reasoning_steps  \
# 0  [The book is a guide for parents, specifically...
# 1  [The book discusses moral codes and virtues, w...
# 2  [The book focuses on well-being and how small ...
# 3  [The book discusses finding purpose and fulfil...
# 4  [The book focuses on achieving goals and ambit...
#
#                            pred_categories
# 0    [Family, Self-Growth, Society & Tech]
# 1         [Self-Growth, Happiness, Health]
# 2  [Health, Self-Growth, Sports & Fitness]
# 3                 [Happiness, Self-Growth]
# 4   [Self-Growth, Productivity, Happiness]

# %%
# Flatten the lists in each column and get unique values
unique_categories = set(cat for sublist in df_books['categories'] for cat in sublist)
unique_pred_categories = set(cat for sublist in df_books['pred_categories'] for cat in sublist)

# Print the counts
print(f"Number of unique categories: {len(unique_categories)}")
print(f"Number of unique predicted categories: {len(unique_pred_categories)}")
print(f"Same categories: {len(set(unique_categories) & set(unique_pred_categories))}")
# Out:
# Number of unique categories: 16
# Number of unique predicted categories: 16
# Same categories: 16

# %%
def show_books(df: pd.DataFrame) -> None:
    for i, row in df.iterrows():
        print(f'Book (idx={i})')
        print(f' - Title: "{row["title"]}"')
        print(f' - Author: {row["author"]}')
        newline = "\n"
        print(f' - Overview: {row["overview"].replace(newline, " ") if row["overview"] is not None else None}')
        print(f' - Author Overview: {row["author_overview"].replace(newline, " ") if row["author_overview"] is not None else None}')
        print(f' - Learning items: {row["learning_items"]}')
        print(f' - Categories: {row["categories"]}')
        print(f' - AI Categories: {row["pred_categories"]}')
        print(f' - AI Reasoning Steps: {row["pred_reasoning_steps"]}')
        print()
        print()

# %%
show_books(df_books.sample(10, random_state=42))
# Out:
# Book (idx=1791)
#  - Title: "Modern Romance"
#  - Author: Aziz Ansari, Eric Klinenberg, PhD
#  - Overview: What’s inside Find out how the image of love has changed over the past century and realize that there is no universal norm for romantic relationships.You’ll learn • The secrets of grandma's happy marriage • About dating in different countries • The impact of social media on personal life • How to meet your one and only About the author Aziz Ansari is a comedian and writer included in the 2016 Time 100 list of most influential people. Eric Klinenberg is a professor of Social Science and Director of the Institute for Public Knowledge at New York University.
#  - Author Overview: Aziz Ansari is a comedian and writer included in the 2016 Time 100 list of most influential people. Eric Klinenberg is a professor of Social Science and Director of the Institute for Public Knowledge at New York University.
#  - Learning items: ["The secrets of grandma's happy marriage", 'About dating in different countries', 'The impact of social media on personal life', 'How to meet your one and only']
#  - Categories: ['Love & Sex']
#  - AI Categories: ['Love & Sex', 'Society & Tech']
#  - AI Reasoning Steps: ['The book discusses the evolution of romantic relationships over time, indicating a focus on love and relationships.', 'It includes insights into dating practices in different cultures, which aligns with themes of love and societal norms.', 'The impact of social media on personal relationships suggests a connection to society and technology, but the primary focus remains on romantic relationships.', "The key learning items emphasize aspects of love, dating, and relationships, reinforcing the relevance of the 'Love & Sex' category.", 'While there are elements of societal analysis, the core subject matter is centered around love and romance rather than broader societal issues.']
#
#
# Book (idx=322)
#  - Title: "Boundaries: When to Say Yes, How to Say No to Take Control of Your Life"
#  - Author: Dr. Henry Cloud, Dr. John Townsend
#  - Overview: What’s inside Discover the necessity and power of setting clear boundaries. Enhance your relationships by safeguarding your personal space.You’ll learn • How to keep others from crossing your boundaries • Why you should set personal limits • How to teach children to establish frontiers • That saying no is not selfish About the author Dr. Henry Cloud and Dr. John Townsend are licensed psychologists, best-selling authors, and popular speakers. Their work empowers people to develop self-awareness and cultivate fulfilling relationships.
#  - Author Overview: Dr. Henry Cloud and Dr. John Townsend are licensed psychologists, best-selling authors, and popular speakers. Their work empowers people to develop self-awareness and cultivate fulfilling relationships.
#  - Learning items: ['How to keep others from crossing your boundaries', 'Why you should set personal limits', 'How to teach children to establish frontiers', 'That saying no is not selfish']
#  - Categories: ['Self-Growth', 'Love & Sex']
#  - AI Categories: ['Self-Growth', 'Family', 'Happiness']
#  - AI Reasoning Steps: ['The book focuses on the concept of boundaries, which is primarily about personal development and self-awareness.', 'It discusses how to set limits in relationships, which aligns with themes of self-growth and personal empowerment.', 'The authors are psychologists, indicating a professional and psychological approach to the subject matter, further supporting the self-growth category.', 'The key learning items emphasize personal limits and teaching boundaries to children, which relates to family dynamics and personal development.', 'The overall theme of the book is about enhancing relationships and personal space, which can also connect to happiness and self-growth.']
#
#
# Book (idx=1033)
#  - Title: "The White Coat Investor: A Doctor’s Guide to Personal Finance and Investing"
#  - Author: James M. Dahle, MD
#  - Overview: What’s inside Struggling with the financial pressures of being a doctor? This handbook breaks down doctors' economic challenges and provides practical, actionable advice for financial success.You’ll learn • Why docs struggle financially • How to thrive on a doctor's salary • Keys to early financial stability • How to avoid common financial traps About the author James M. Dahle, MD, is an emergency physician and the founder of "The White Coat Investor," a popular personal finance website specifically helping medical professionals manage and grow their wealth more effectively.
#  - Author Overview: James M. Dahle, MD, is an emergency physician and the founder of "The White Coat Investor," a popular personal finance website specifically helping medical professionals manage and grow their wealth more effectively.
#  - Learning items: ['Why docs struggle financially', "How to thrive on a doctor's salary", 'Keys to early financial stability', 'How to avoid common financial traps']
#  - Categories: ['Money & Investments']
#  - AI Categories: ['Money & Investments', 'Business & Career']
#  - AI Reasoning Steps: ['The book is focused on personal finance, specifically tailored for doctors, which indicates a strong connection to financial management and investment strategies.', 'The author, James M. Dahle, MD, is an expert in the field of finance for medical professionals, suggesting that the content is credible and specialized.', 'The key learning items highlight financial challenges faced by doctors and provide actionable advice for financial stability and success, reinforcing the theme of money management.', "Given the focus on financial advice and investment strategies, the category 'Money & Investments' is highly relevant.", "While the book may touch on aspects of career and professional life, the primary focus remains on financial education rather than broader business concepts, making 'Business & Career' less relevant than 'Money & Investments'.", 'The book does not address themes related to fiction, spirituality, sports, happiness, self-growth, personalities, productivity, society, leadership, family, love, or health in a direct manner, which further narrows down the relevant categories.']
#
#
# Book (idx=162)
#  - Title: "Made to Stick: Why Some Ideas Survive and Others Die"
#  - Author: Chip Heath, Dan Heath
#  - Overview: What’s inside Pioneer the art of memorable idea curation. Craft messages that engage and inspire, leaving a lasting impression beyond the ordinary.You’ll learn • How simplicity powers understanding • Crafting stories that motivate action • Keys to boosting message credibility • Engaging emotions to drive care • The magic of unexpected twists About the author Chip Heath, a Stanford professor, and his brother, bestselling author, and professor, Dan Heath, have co-authored four NYT bestsellers. Their work bridges academic insight and real-world application.
#  - Author Overview: Chip Heath, a Stanford professor, and his brother, bestselling author, and professor, Dan Heath, have co-authored four NYT bestsellers. Their work bridges academic insight and real-world application.
#  - Learning items: ['How simplicity powers understanding', 'Crafting stories that motivate action', 'Keys to boosting message credibility', 'Engaging emotions to drive care', 'The magic of unexpected twists']
#  - Categories: ['Business & Career']
#  - AI Categories: ['Business & Career', 'Productivity', 'Leadership']
#  - AI Reasoning Steps: ['The book focuses on how to make ideas memorable and impactful, which relates to communication and persuasion.', 'The key learning items emphasize crafting messages, engaging emotions, and boosting credibility, all of which are essential skills in business and career contexts.', 'The authors are well-known for their work in applying academic insights to real-world situations, particularly in the realm of business and communication.', 'Given the focus on effective messaging and idea curation, the book aligns closely with themes of productivity and leadership, as these skills are crucial for effective leaders and productive individuals.']
#
#
# Book (idx=1273)
#  - Title: "The Pivot Year"
#  - Author: Brianna Wiest
#  - Overview: What’s inside Imagine this year becoming your turning point. Discover a roadmap to align your life with purpose and inner peace, challenging you to redefine happiness and success.You’ll learn • That self-compassion fuels lasting transformation • What aligns your life with authentic happiness • How inner peace shapes your outer world • Why letting go creates space for growth About the author Brianna Wiest is a prolific author and thought leader and is celebrated for her work on mindfulness and self-improvement. With a background in psychology, she inspires readers worldwide to embrace intentional living.
#  - Author Overview: Brianna Wiest is a prolific author and thought leader and is celebrated for her work on mindfulness and self-improvement. With a background in psychology, she inspires readers worldwide to embrace intentional living.
#  - Learning items: ['That self-compassion fuels lasting transformation', 'What aligns your life with authentic happiness', 'How inner peace shapes your outer world', 'Why letting go creates space for growth']
#  - Categories: ['Happiness', 'Business & Career', 'Self-Growth']
#  - AI Categories: ['Happiness', 'Self-Growth', 'Spirituality']
#  - AI Reasoning Steps: ["The book focuses on personal transformation and aligning one's life with purpose, which suggests a focus on self-improvement.", 'The key learning items emphasize self-compassion, authentic happiness, and inner peace, all of which are central themes in self-growth and happiness.', "The author's background in psychology and emphasis on mindfulness indicates a strong connection to self-growth and spirituality.", 'The overall theme of the book is about redefining happiness and success, which aligns closely with the category of Happiness.', 'Given the focus on personal development and intentional living, Self-Growth is also a fitting category.']
#
#
# Book (idx=70)
#  - Title: "168 Hours: You Have More Time Than You Think"
#  - Author: Laura Vanderkam
#  - Overview: What’s inside Learn to tackle your time in a more productive and fulfilling manner. Discover your time-wasting habits and improve your routine.You’ll learn • About things that keep you from progress • Why you’re afraid to evolve • How to plan your week to balance life and work • To achieve goals you’ve had for a while About the author Laura Vanderkam is an American journalist and writer on productivity, self-development, and time management. Her sphere of expertise also includes work-life balance for women based on her journalistic experience.
#  - Author Overview: Laura Vanderkam is an American journalist and writer on productivity, self-development, and time management. Her sphere of expertise also includes work-life balance for women based on her journalistic experience.
#  - Learning items: ['About things that keep you from progress', 'Why you’re afraid to evolve', 'How to plan your week to balance life and work', 'To achieve goals you’ve had for a while']
#  - Categories: ['Productivity']
#  - AI Categories: ['Self-Growth', 'Productivity']
#  - AI Reasoning Steps: ['The book focuses on time management and productivity, which are key themes in self-development.', 'The author, Laura Vanderkam, specializes in productivity and self-growth, indicating that the book aligns with these areas.', 'The key learning items emphasize improving routines, achieving goals, and balancing life and work, all of which are aspects of self-growth and productivity.', "Given the content and focus on personal improvement and effective time management, the categories of 'Self-Growth' and 'Productivity' are the most relevant."]
#
#
# Book (idx=247)
#  - Title: "The First 20 Hours: How to Learn Anything . . . Fast!"
#  - Author: Josh Kaufman
#  - Overview: What’s inside Dive deep into rapid skill acquisition, transforming the way you approach learning. Reveal methods that will elevate you from novice to knowledgeable in record time.You’ll learn • Why curiosity is your best learning asset • How microtasks lead to macro mastery • A mystic connection between yoga and mindfulness • The art behind rapid touch typing About the author Josh Kaufman is a self-made business expert and author of several personal development and entrepreneurship books.
#  - Author Overview: Josh Kaufman is a self-made business expert and author of several personal development and entrepreneurship books.
#  - Learning items: ['Why curiosity is your best learning asset', 'How microtasks lead to macro mastery', 'A mystic connection between yoga and mindfulness', 'The art behind rapid touch typing']
#  - Categories: ['Productivity']
#  - AI Categories: ['Self-Growth', 'Productivity']
#  - AI Reasoning Steps: ['The book focuses on rapid skill acquisition, which suggests a focus on personal development and learning strategies.', 'The author, Josh Kaufman, is known for writing about personal development and entrepreneurship, indicating that the book likely falls into the self-growth category.', 'Key learning items include curiosity as a learning asset and microtasks leading to mastery, which are concepts related to self-improvement and productivity.', 'The mention of yoga and mindfulness connects to personal well-being, but it is more about learning techniques than spirituality in a traditional sense.', 'Overall, the themes of learning quickly and effectively align closely with self-growth and productivity.']
#
#
# Book (idx=736)
#  - Title: "Win Every Argument: The Art of Debating, Persuading, and Public Speaking"
#  - Author: Mehdi Hasan
#  - Overview: What’s inside Learn to win every argument with intelligence, confidence, and grace — whether it's a casual conversation turned into heated discussion or an impromptu debate in front of colleagues.You’ll learn • The value of arguments • Winning strategies for any dispute • Techniques to trap your opponent • How to prepare for your victory About the author Mehdi Hasan is an award-winning journalist, broadcaster, and host of The Mehdi Hasan Show. Formerly a columnist and podcaster at the Intercept, he also served as a presenter at Al Jazeera English.
#  - Author Overview: Mehdi Hasan is an award-winning journalist, broadcaster, and host of The Mehdi Hasan Show. Formerly a columnist and podcaster at the Intercept, he also served as a presenter at Al Jazeera English.
#  - Learning items: ['The value of arguments', 'Winning strategies for any dispute', 'Techniques to trap your opponent', 'How to prepare for your victory']
#  - Categories: ['Negotiation']
#  - AI Categories: ['Self-Growth', 'Negotiation']
#  - AI Reasoning Steps: ['The book focuses on debating, persuading, and public speaking, which are skills related to communication and argumentation.', 'The key learning items emphasize strategies for winning arguments and preparing for discussions, indicating a focus on personal development in communication.', 'The author, Mehdi Hasan, is a journalist and broadcaster, suggesting that the book may also touch on aspects of media and public discourse.', "Given the emphasis on winning arguments and techniques for effective communication, the categories of 'Self-Growth' and 'Negotiation' are particularly relevant."]
#
#
# Book (idx=1518)
#  - Title: "The Wisdom of Sundays: Life-Changing Insights from Super Soul Conversations"
#  - Author: Oprah Winfrey
#  - Overview: What’s inside Did you ever feel stuck in your personal growth? Water your inner blossom with this collection of profound dialogues that illuminate pathways to a more fulfilled life.You’ll learn • How beliefs shape the truth • Why reflect on spirituality • What's the power of gratitude? • The true power of intentions • Why you should trust your intuition About the author Oprah Winfrey is a celebrated media mogul and philanthropist who has profoundly impacted global media with her distinctive blend of empathic broadcasting and transformative discourse.
#  - Author Overview: Oprah Winfrey is a celebrated media mogul and philanthropist who has profoundly impacted global media with her distinctive blend of empathic broadcasting and transformative discourse.
#  - Learning items: ['How beliefs shape the truth', 'Why reflect on spirituality', "What's the power of gratitude?", 'The true power of intentions', 'Why you should trust your intuition']
#  - Categories: ['Spirituality']
#  - AI Categories: ['Spirituality', 'Self-Growth']
#  - AI Reasoning Steps: ['The book focuses on personal growth and insights from conversations that aim to help individuals lead more fulfilled lives.', 'Key learning items include spirituality, gratitude, intentions, and intuition, which are all closely related to self-exploration and personal development.', "The author, Oprah Winfrey, is known for her work in media that often revolves around themes of self-improvement and spirituality, further emphasizing the book's focus on these areas.", "Given the content and themes presented in the overview and key learning items, the categories of 'Spirituality' and 'Self-Growth' are the most relevant."]
#
#
# Book (idx=1006)
#  - Title: "The Parenting Map: Step-by-Step Solutions to Consciously Create the Ultimate Parent-Child Relationship"
#  - Author: Shefali Tsabary, PhD
#  - Overview: What’s inside Overcome limiting beliefs to evolve beyond ego-driven parenting, enabling your child to grow confidently and joyfully, true to their essence, free from external expectations.You’ll learn • The danger of the rescue complex • How to deal with a teenager • What's good about naughty children • Mistakes and their solutions in parenting About the author Shefali Tsabary, PhD, integrates Western psychology and Eastern philosophy as an acclaimed author, clinical psychologist, family coach, consultant, and speaker.
#  - Author Overview: Shefali Tsabary, PhD, integrates Western psychology and Eastern philosophy as an acclaimed author, clinical psychologist, family coach, consultant, and speaker.
#  - Learning items: ['The danger of the rescue complex', 'How to deal with a teenager', "What's good about naughty children", 'Mistakes and their solutions in parenting']
#  - Categories: ['Family']
#  - AI Categories: ['Family', 'Self-Growth']
#  - AI Reasoning Steps: ['The book focuses on parenting techniques and improving parent-child relationships, which suggests a strong connection to family dynamics.', 'The author discusses overcoming limiting beliefs and ego-driven parenting, indicating a focus on personal development and self-awareness in the context of parenting.', 'Key learning items include dealing with teenagers and understanding the nature of children, which further emphasizes the family aspect of the book.', 'The integration of psychology and philosophy in parenting suggests a deeper exploration of personal growth and self-awareness, aligning with self-growth themes.', "Overall, the primary focus of the book is on family relationships and parenting strategies, making 'Family' the most relevant category."]

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_category_count_distribution(df, col1, col2, title='Distribution of Category Counts'):
    """
    Plots the distribution of the number of categories per book for both manual and predicted categories.
    
    :param df: Pandas DataFrame
    :param col1: First column (manual categories)
    :param col2: Second column (predicted categories)
    :param title: Title of the plot
    """
    # Compute number of categories per book
    manual_counts = df[col1].apply(len)
    predicted_counts = df[col2].apply(len)

    # Set bins based on max count
    max_count = max(manual_counts.max(), predicted_counts.max())
    bins = np.arange(0, max_count + 1.5) - 0.5  # Ensure integer bin edges

    # Plot histograms
    plt.figure(figsize=(8, 5))
    plt.hist(manual_counts, bins=bins, alpha=0.6, color='royalblue', edgecolor='black', label='Manual Categories')
    plt.hist(predicted_counts, bins=bins, alpha=0.6, color='violet', edgecolor='black', label='Predicted Categories')

    # Labels and formatting
    plt.xlabel('Number of Categories per Book')
    plt.ylabel('Frequency')
    plt.title(title)
    plt.xticks(range(0, max_count + 1))
    plt.legend()
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.show()

# Usage
plot_category_count_distribution(df_books, 'categories', 'pred_categories')

# %% [markdown]
#  - The most common number of manual categories — 1
#  - The number of predicted categories has wider distribution. Mode — 2 ,then 3, and only then 1.
#
# Why? The obvious question is
#  - Does AI has tendency to assign irrelevant categories?

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

def plot_category_count_heatmap(df, col1, col2, title='Heatmap of Category Counts'):
    """
    Plots a heatmap showing the relationship between the number of manual and predicted categories per book.
    
    :param df: Pandas DataFrame
    :param col1: First column (manual categories)
    :param col2: Second column (predicted categories)
    :param title: Title of the plot
    """
    # Compute number of categories per book
    manual_counts = df[col1].apply(len)
    predicted_counts = df[col2].apply(len)

    # Create a dataframe for heatmap
    heatmap_data = pd.crosstab(manual_counts, predicted_counts)

    # Plot heatmap
    plt.figure(figsize=(8, 6))
    sns.heatmap(heatmap_data, annot=True, fmt='d', cmap='coolwarm', linewidths=0.5)

    # Labels and formatting
    plt.xlabel('Number of Predicted Categories')
    plt.ylabel('Number of Manual Categories')
    plt.title(title)
    plt.show()

# Usage
plot_category_count_heatmap(df_books, 'categories', 'pred_categories')

# %%
# ensure validity of the plot above
len(df_books[(df_books['categories'].apply(len) == 1) & (df_books['pred_categories'].apply(len) == 2)])
# Out:
# 475

# %% [markdown]
# Here we see the picture in more detail.
#  - The most common case — there is 1 manual category but AI predicts 2; in the similar vein, AI predicting 3 categories is the second most common case.
#  - Although less frequently, the number of categories assign can match (for 1 and 2, mostly).
#  - There are some outliers. Noticeably, there are cases when summaries have no manual categories at all, but AI predicts 2-4 categories. There is one case when AI hasn't assigned any category (but there is one manual category). Also, interestingly, there is the case when there are 5 manual categories and only 2 AI categories.

# %%
show_books(df_books[(df_books['categories'].apply(len) == 1) & (df_books['pred_categories'].apply(len) == 2)].sample(n=10, random_state=42))
# Out:
# Book (idx=1358)
#  - Title: "Stock Investing for Dummies"
#  - Author: Paul Mladjenovic
#  - Overview: What’s inside Open the door to a happy and fulfilling life by learning the secrets of successful investing and searching for companies and brokers.You’ll learn • The difference between common and preferred stock • Who company insiders are • Time-tested financial strategies • Five levels of market capitalization • How to check your broker About the author Paul Mladjenovic is an American speaker and educator. He has written books on investing and financial literacy for over twenty years. He also annually conducts more than a hundred workshops on investment strategies.
#  - Author Overview: Paul Mladjenovic is an American speaker and educator. He has written books on investing and financial literacy for over twenty years. He also annually conducts more than a hundred workshops on investment strategies.
#  - Learning items: ['The difference between common and preferred stock', 'Who company insiders are', 'Time-tested financial strategies', 'Five levels of market capitalization', 'How to check your broker']
#  - Categories: ['Money & Investments']
#  - AI Categories: ['Money & Investments', 'Business & Career']
#  - AI Reasoning Steps: ["The book is titled 'Stock Investing for Dummies', indicating it is a guide for beginners in stock investing.", 'The overview mentions learning about different types of stocks, financial strategies, and how to evaluate brokers, which are all related to investing and finance.', "The author, Paul Mladjenovic, specializes in investing and financial literacy, further emphasizing the book's focus on financial education.", 'Key learning items include concepts directly related to investing, such as market capitalization and stock types, which align with financial topics.', "Given the focus on investing and financial strategies, the most relevant category from the predefined list is 'Money & Investments'.", 'While the author has a background in education and workshops, the primary focus of the book remains on investing rather than broader business or career topics.']
#
#
# Book (idx=1588)
#  - Title: "Exercised: The Science of Physical Activity, Rest and Health"
#  - Author: Daniel Lieberman
#  - Overview: What’s inside Tired of feeling lazy? Find out why you dodge workouts and how changing this mindset sparks a healthier life.You’ll learn • How genetics influence fitness • What makes sitting so deadly • Why walking is overrated • If sports can replace exercise • What myths cloud your view of fitness About the author Daniel Lieberman is a Harvard Professor famed for pioneering research in human evolutionary biology. His expertise in physical activity and its impacts forms the backbone of his enlightening work on health.
#  - Author Overview: Daniel Lieberman is a Harvard Professor famed for pioneering research in human evolutionary biology. His expertise in physical activity and its impacts forms the backbone of his enlightening work on health.
#  - Learning items: ['How genetics influence fitness', 'What makes sitting so deadly', 'Why walking is overrated', 'If sports can replace exercise', 'What myths cloud your view of fitness']
#  - Categories: ['Health']
#  - AI Categories: ['Sports & Fitness', 'Health']
#  - AI Reasoning Steps: ['The book focuses on physical activity and its impact on health, which suggests a strong connection to health-related topics.', 'The author, Daniel Lieberman, is an expert in human evolutionary biology and physical activity, indicating that the book is likely grounded in scientific research about fitness and health.', 'Key learning items include discussions on fitness influenced by genetics, the dangers of a sedentary lifestyle, and common myths about exercise, all of which are relevant to health and fitness.', "The title 'Exercised: The Science of Physical Activity, Rest and Health' explicitly mentions health and physical activity, reinforcing the idea that the book is primarily about health and fitness.", "Given the emphasis on physical activity, rest, and health, the categories 'Sports & Fitness' and 'Health' are the most relevant."]
#
#
# Book (idx=62)
#  - Title: "Toxic Parents: Overcoming Their Hurtful Legacy and Reclaiming Your Life"
#  - Author: Susan Forward PhD, Craig Buck
#  - Overview: What’s inside Discover how your parents’ past actions affect you now. Learn how to break the toxicity cycle to become a better version of yourself.You’ll learn • How much your upbringing continues to influence you • Why you can’t rush forgiveness • The importance of defining yourself • Ways to navigate confronting your parents about their mistakes About the author Susan Forward is an experienced therapist, best-selling author, and lecturer. Craig Buck is a film and television writer and producer.
#  - Author Overview: Susan Forward is an experienced therapist, best-selling author, and lecturer. Craig Buck is a film and television writer and producer.
#  - Learning items: ['How much your upbringing continues to influence you', 'Why you can’t rush forgiveness', 'The importance of defining yourself', 'Ways to navigate confronting your parents about their mistakes']
#  - Categories: ['Family']
#  - AI Categories: ['Self-Growth', 'Family']
#  - AI Reasoning Steps: ["The book discusses the impact of parents' actions on their children's lives, which relates to family dynamics.", 'It focuses on overcoming negative influences from parents, indicating a theme of self-growth and personal development.', 'The key learning points emphasize defining oneself and navigating difficult conversations with parents, which aligns with self-growth and family issues.', 'The author is a therapist, suggesting a professional perspective on personal development and family relationships.']
#
#
# Book (idx=247)
#  - Title: "The First 20 Hours: How to Learn Anything . . . Fast!"
#  - Author: Josh Kaufman
#  - Overview: What’s inside Dive deep into rapid skill acquisition, transforming the way you approach learning. Reveal methods that will elevate you from novice to knowledgeable in record time.You’ll learn • Why curiosity is your best learning asset • How microtasks lead to macro mastery • A mystic connection between yoga and mindfulness • The art behind rapid touch typing About the author Josh Kaufman is a self-made business expert and author of several personal development and entrepreneurship books.
#  - Author Overview: Josh Kaufman is a self-made business expert and author of several personal development and entrepreneurship books.
#  - Learning items: ['Why curiosity is your best learning asset', 'How microtasks lead to macro mastery', 'A mystic connection between yoga and mindfulness', 'The art behind rapid touch typing']
#  - Categories: ['Productivity']
#  - AI Categories: ['Self-Growth', 'Productivity']
#  - AI Reasoning Steps: ['The book focuses on rapid skill acquisition, which suggests a focus on personal development and learning strategies.', 'The author, Josh Kaufman, is known for writing about personal development and entrepreneurship, indicating that the book likely falls into the self-growth category.', 'Key learning items include curiosity as a learning asset and microtasks leading to mastery, which are concepts related to self-improvement and productivity.', 'The mention of yoga and mindfulness connects to personal well-being, but it is more about learning techniques than spirituality in a traditional sense.', 'Overall, the themes of learning quickly and effectively align closely with self-growth and productivity.']
#
#
# Book (idx=1288)
#  - Title: "The Intelligence Trap — Why Smart People Do Stupid Things and How to Make Wiser Decisions"
#  - Author: David Robson
#  - Overview: What’s inside Dare to question your intellectual prowess. Unearth the hidden traps that await even the brightest minds.You’ll learn • The dark side of enlightenment • Why intelligence isn't enough • How your brain can lead you astray • When to question your assumptions • Whether intuition is a scam About the author David Robson is a science journalist known for his insightful writing. With a talent for making complex scientific ideas relatable, Robson captivates readers and uncovers the intricacies of the human mind.
#  - Author Overview: David Robson is a science journalist known for his insightful writing. With a talent for making complex scientific ideas relatable, Robson captivates readers and uncovers the intricacies of the human mind.
#  - Learning items: ['The dark side of enlightenment', "Why intelligence isn't enough", 'How your brain can lead you astray', 'When to question your assumptions', 'Whether intuition is a scam']
#  - Categories: ['Self-Growth']
#  - AI Categories: ['Self-Growth', 'Productivity']
#  - AI Reasoning Steps: ['The book discusses the concept of intelligence and how it can lead to poor decision-making, which suggests a focus on self-awareness and personal development.', "It emphasizes the importance of questioning assumptions and understanding the limitations of one's own intellect, aligning with themes of self-growth and personal improvement.", 'The author is a science journalist, indicating that the book likely presents research and insights into human behavior, which can relate to productivity and decision-making processes.', 'The key learning items highlight critical thinking and the psychology behind decision-making, which are relevant to self-growth and productivity.']
#
#
# Book (idx=138)
#  - Title: "Winning at Sales: How to Get So Good People Say "Thank You" for Letting Them Buy"
#  - Author: Taylor A. Welch
#  - Overview: What’s inside Discover how to build unshakeable conviction in your product, overcome objections easily, and create a sales process that attracts customers and leaves them feeling genuinely valued.You’ll learn • How to overcome a negative conviction  • The three essential rules for building trust • Techniques to reframe objections • Strategies to leap outside your comfort zone  About the author Podcaster and video content creator Taylor Welch focuses on redefining wealth from a Christian perspective. He is also the founder of Welch Equities, a portfolio of small brands that aims to "make the world happier and smarter."
#  - Author Overview: Podcaster and video content creator Taylor Welch focuses on redefining wealth from a Christian perspective. He is also the founder of Welch Equities, a portfolio of small brands that aims to "make the world happier and smarter."
#  - Learning items: ['How to overcome a negative conviction ', 'The three essential rules for building trust', 'Techniques to reframe objections', 'Strategies to leap outside your comfort zone ']
#  - Categories: ['Money & Investments']
#  - AI Categories: ['Business & Career', 'Self-Growth']
#  - AI Reasoning Steps: ['The book focuses on sales techniques and strategies, which directly relates to the field of business.', 'It discusses building trust and overcoming objections, which are key components of effective sales and negotiation.', 'The author emphasizes personal growth in the context of sales, suggesting a connection to self-improvement and self-growth.', 'The mention of redefining wealth from a Christian perspective may hint at a spiritual angle, but the primary focus remains on sales and business.', "Given the content and focus on sales processes, the most relevant category is 'Business & Career'.", "The emphasis on personal development and overcoming challenges also aligns with 'Self-Growth'.", "While there is a slight spiritual aspect, it is not the main focus, so 'Spirituality' is less relevant than the other categories."]
#
#
# Book (idx=268)
#  - Title: "The Motive: Why So Many Leaders Abdicate Their Most Important Responsibilities"
#  - Author: Patrick Lencioni
#  - Overview: What’s inside Unearth the transformational power of leadership when it's seen as responsibility rather than reward.You’ll learn • What hidden sacrifices successful leaders make • How tough talks can be empowering • Why expertise complicates leadership • About the risks coming with ignoring employee personalities About the author Patrick Lencioni, a well-known author and speaker on leadership and teamwork, is the founder of The Table Group, a consulting firm that serves Fortune 500 companies, sports teams, and nonprofits.
#  - Author Overview: Patrick Lencioni, a well-known author and speaker on leadership and teamwork, is the founder of The Table Group, a consulting firm that serves Fortune 500 companies, sports teams, and nonprofits.
#  - Learning items: ['What hidden sacrifices successful leaders make', 'How tough talks can be empowering', 'Why expertise complicates leadership', 'About the risks coming with ignoring employee personalities']
#  - Categories: ['Leadership']
#  - AI Categories: ['Leadership', 'Business & Career']
#  - AI Reasoning Steps: ["The book focuses on leadership and the responsibilities that come with it, indicating a strong connection to the category of 'Leadership'.", "The author, Patrick Lencioni, is known for his work in leadership and teamwork, further reinforcing the relevance of the 'Leadership' category.", 'The key learning items discuss aspects of leadership such as sacrifices, empowering tough conversations, and understanding employee personalities, all of which are central themes in leadership discussions.', "While the book touches on personal growth and development in the context of leadership, the primary focus remains on leadership responsibilities rather than personal self-growth, which suggests that 'Self-Growth' is less relevant than 'Leadership'.", "The book does not fit into categories like 'Fiction', 'Home & Environment', 'Spirituality', 'Sports & Fitness', 'Happiness', 'Money & Investments', 'Personalities', 'Productivity', 'Society & Tech', 'Family', 'Love & Sex', or 'Health', as these themes are not central to the book's content."]
#
#
# Book (idx=1669)
#  - Title: "Hillbilly Elegy: A Memoir of a Family and Culture in Crisis"
#  - Author: J.D. Vance. JD
#  - Overview: What’s inside Discover the inside perspective of hillbilly culture. Learn about the moral and material decline that currently threatens its existence.You’ll learn • Details on the current state of hillbilly culture • About stigma that sticks for life • The cost of moving to a higher socioeconomic level • Lack of knowledge and its consequences About the author James David Vance is an American venture capitalist, author, and politician. He has served as the junior United States senator from Ohio since 2023.
#  - Author Overview: James David Vance is an American venture capitalist, author, and politician. He has served as the junior United States senator from Ohio since 2023.
#  - Learning items: ['Details on the current state of hillbilly culture', 'About stigma that sticks for life', 'The cost of moving to a higher socioeconomic level', 'Lack of knowledge and its consequences']
#  - Categories: ['Society & Tech']
#  - AI Categories: ['Society & Tech', 'Family']
#  - AI Reasoning Steps: ['The book is a memoir, which typically falls under personal narratives or societal observations.', 'The overview discusses the decline of hillbilly culture, indicating a focus on societal issues and cultural analysis.', 'Key learning points mention stigma, socioeconomic levels, and knowledge, which relate to societal and personal growth themes.', 'The author, J.D. Vance, provides insights into family and cultural dynamics, suggesting relevance to family and societal themes.', "Given the predefined categories, 'Society & Tech' and 'Family' are the most relevant as they encompass cultural and familial aspects."]
#
#
# Book (idx=396)
#  - Title: "Flow: The Psychology of Optimal Experience"
#  - Author: Mihaly Csikszentmihalyi, Dr.
#  - Overview: What’s inside Discover how to achieve happiness through mastering flow in your daily activities. Unveil the secret to living a fulfilled life beyond material gains.You’ll learn • Why happiness isn't bought • Mastery leads to deeper joy • How flow redefines pleasure • Finding calm in life's chaos About the author Mihaly Csikszentmihalyi is a distinguished psychologist renowned for his research on happiness and creativity. His concept of "flow" has influenced millions to find joy and fulfillment beyond material success.
#  - Author Overview: Mihaly Csikszentmihalyi is a distinguished psychologist renowned for his research on happiness and creativity. His concept of "flow" has influenced millions to find joy and fulfillment beyond material success.
#  - Learning items: ["Why happiness isn't bought", 'Mastery leads to deeper joy', 'How flow redefines pleasure', "Finding calm in life's chaos"]
#  - Categories: ['Productivity']
#  - AI Categories: ['Happiness', 'Self-Growth']
#  - AI Reasoning Steps: ['The book focuses on achieving happiness and fulfillment, which suggests a strong connection to the concept of happiness.', 'The author, Mihaly Csikszentmihalyi, is known for his research on happiness and creativity, reinforcing the theme of happiness in the book.', 'The key learning items emphasize mastery, joy, and finding calm, all of which relate to personal development and self-improvement.', 'The book discusses how to live a fulfilled life beyond material gains, which aligns with self-growth and personal happiness.', "Given the focus on personal experience and mastery leading to joy, 'Self-Growth' and 'Happiness' are the most relevant categories."]
#
#
# Book (idx=320)
#  - Title: "Money Master The Game: 7 Simple Steps to Financial Freedom"
#  - Author: Tony Robbins
#  - Overview: What’s inside Go through the world’s most effective finance methods and pick the one that could provide financial freedom for you and your family.You’ll learn • 7 steps to reach generational wealth • How to set a life income plan • Getting free of existing loans • Rules of investing • How to treat money About the author Tony Robbins is an entrepreneur, business strategist, philanthropist, and bestselling author. He’s a chairman of a holding company with combined sales of over five billion dollars.
#  - Author Overview: Tony Robbins is an entrepreneur, business strategist, philanthropist, and bestselling author. He’s a chairman of a holding company with combined sales of over five billion dollars.
#  - Learning items: ['7 steps to reach generational wealth', 'How to set a life income plan', 'Getting free of existing loans', 'Rules of investing', 'How to treat money']
#  - Categories: ['Money & Investments']
#  - AI Categories: ['Money & Investments', 'Self-Growth']
#  - AI Reasoning Steps: ['The book focuses on financial freedom and wealth-building strategies, which suggests a strong connection to financial topics.', 'The key learning items include steps to reach generational wealth, setting a life income plan, and rules of investing, all of which are directly related to managing money and investments.', 'The author, Tony Robbins, is known for his work in business and personal development, which aligns with themes of self-growth and financial education.', "Given the emphasis on financial strategies and wealth management, the category 'Money & Investments' is highly relevant.", 'While there are elements of self-growth in the book, the primary focus is on financial strategies rather than personal development in a broader sense.', 'The book does not fit into categories like Fiction, Home & Environment, Spirituality, Sports & Fitness, Happiness, Personalities, Productivity, Society & Tech, Leadership, Family, Love & Sex, or Health, as these themes are not central to the content.']

# %% [markdown]
# #### So does AI tend to assign irrelevant categories? Or are the manual categoris not complete?
#
# **JUSTIFIED** will mean that AI has assigned a valid category, i.e. manually assigned categories are not complete. \
# **NOT JUSTIFIED**, on the other hand, will mean that AI has assigned redundant, irrelevant category. \
# We'll use other notations to express ambiguity, etc.
#
#
#  - 1358 — Interestingly, AI reasoning steps underline the fact that Business & Career is not a fitting category, but it's still present in the final categories. **NOT JUSTIFIED**
#  - 1588 — Sports & Fitness is definitelly a fitting category. **JUSTIFIED**
#  - 62 — Self-Growth definitely has a relevance to this book, especially considering the Overview. At the same time, it seems slightly off, most non-fiction books can be related to Self-Growth. **AMBIGUOUS**
#  - 247 — Self-Growth seems relevant here. **JUSTIFIED**
#  - 1288 — Productivity doesn't seem relevant, although AI tries to justify it. **NOT JUSTIFIED**
#  - 138 — Interestingly, the two AI categories differ from the one manual category. The overview of the book inclines towards Self-Growth category, although it doesn't seem to be a relevant topic. Business & Career (especially Business) fits. Money & Investment is missing. **PARTIALLY JUSTIFIED**
#  - 268 — Business & Career fits. **JUSTIFIED**
#  - 1669 — The book includes the story of the family, so Famaily seems a valid category here. **JUSTIFIED**
#  - 396 — The categories assigned by AI are valid, but the one manual category should have also been included. **JUSTIFIED**
#  - 320 — Again, Self-Growth is relevant, but does seem superfluous. **PARTIALLY JUSTIFIED**
#
#
# #### CONCLUSIONS
#  - It seems that detailed specification of every category would be very beneficial. Passing these specification to AI might significantly improve the accuracy.
#  - The assignment of categories by AI that are not present within manually assigned categoires is often justified. I.e., those categories seem to be missing.
#  - Self-Growth is a very common topic with non-fiction books, but frequently its presence seems superfluous.
#  - Sometimes, AI hallucinates and assignes invalid categories (#1288)
#  - AI can be inconsistent. While it's thoughts about #1358 are valid, the presence of Business & Carreer in final list of categories contradicts them. Additional prompt/flow imporvements might be desirable.
#
#
# ##### Deprecated (indexes are off)
#  - 1030 - Happiness seems like a relevant category. **JUSTIFIED**
#  - 1765 — A more tricky one, BUT there are mentions of money/investing, moreover, Goodreads assigned category "Finance" as the second most relevant. ***PROBABLY* JUSTIFIED**
#  - 1540 — The point is that so many non-fiction books can be related to Self-Growth (as reasoning steps, actually, justify it). PROBABLY JUSTIFIED
#  - 509 — The book definitely expands on Sports & Fitness. **JUSTIFIED**
#  - 1775 — Tricky one, in Ukrainian. But the category Presonalities is definitely suitable. **JUSTIFIED**
#  - 439 — Business & Career seems a totally fitting category. **JUSTIFIED**

# %%
import matplotlib.pyplot as plt
import numpy as np
from collections import Counter

def plot_category_comparison(df, col1, col2, title):
    """
    Plots the count of each category for two columns in the same bar chart.
    
    :param df: Pandas DataFrame
    :param col1: First column name containing lists of categories
    :param col2: Second column name containing lists of categories
    :param title: Title for the plot
    """
    # Count occurrences in both columns
    counts_col1 = Counter(cat for sublist in df[col1] for cat in sublist)
    counts_col2 = Counter(cat for sublist in df[col2] for cat in sublist)

    # Get all unique categories
    all_categories = sorted(set(counts_col1.keys()).union(set(counts_col2.keys())))

    # Get counts in order, defaulting to 0 if category is missing
    values_col1 = [counts_col1.get(cat, 0) for cat in all_categories]
    values_col2 = [counts_col2.get(cat, 0) for cat in all_categories]

    # Set up bar positions
    x = np.arange(len(all_categories))
    width = 0.4  # Bar width

    # Create the plot
    plt.figure(figsize=(12, 6))
    plt.bar(x - width/2, values_col1, width=width, label=col1, color='skyblue')
    plt.bar(x + width/2, values_col2, width=width, label=col2, color='salmon')

    # Labels and title
    plt.xlabel('Categories')
    plt.ylabel('Count')
    plt.title(title)
    plt.xticks(ticks=x, labels=all_categories, rotation=45, ha='right')
    plt.legend()
    plt.show()

# Usage
plot_category_comparison(df_books, 'categories', 'pred_categories', 'Manual vs. Predicted Categories Count')

# %% [markdown]
#  - Overall, AI tends to use categories more (i.e., assigns more categories than humans on average).
#  - The distribution of the number of books across categories is highly ununiform.
#  - Many categories are used by AI significantly more than by manual categorizers: Business & Career, Happiness, Leadership, Productivity, Self-Growth. A common pattern across those topics — broadness and some uncertainty.
#  - Self-Growth is a category that is especially over-used by AI. No wonder — most non-fiction books can be somehow related to this. Again, specification and more tuned instructions should help.
#  - Some categories are almost unused: fiction, Home & Envoronment.

# %%
import matplotlib.pyplot as plt
import numpy as np


def compute_conditional_frequencies(df, col1, col2):
    """
    Computes the conditional probabilities P(col2 | col1) and P(col1 | col2).
    
    :param df: Pandas DataFrame
    :param col1: First column name containing lists of categories (manual or predicted)
    :param col2: Second column name containing lists of categories (predicted or manual)
    :return: Two dictionaries with conditional probabilities
    """
    # Count occurrences for conditional probabilities (initialization)
    count_col1 = {cat: 0 for sublist in df[col1] for cat in sublist}
    count_col2_given_col1 = {cat: 0 for sublist in df[col1] for cat in sublist}

    count_col2 = {cat: 0 for sublist in df[col2] for cat in sublist}
    count_col1_given_col2 = {cat: 0 for sublist in df[col2] for cat in sublist}

    # Compute co-occurrences
    for _, row in df.iterrows():
        manual_cats = set(row[col1])
        pred_cats = set(row[col2])
        
        for cat in manual_cats:
            count_col1[cat] += 1
            count_col2_given_col1[cat] += int(cat in pred_cats)  # Matching predictions
        
        for cat in pred_cats:
            count_col2[cat] += 1
            count_col1_given_col2[cat] += int(cat in manual_cats)  # Matching manual labels

    # Compute conditional probabilities
    prob_col2_given_col1 = {cat: count_col2_given_col1[cat] / count_col1[cat] for cat in count_col1 if count_col1[cat] > 0}
    prob_col1_given_col2 = {cat: count_col1_given_col2[cat] / count_col2[cat] for cat in count_col2 if count_col2[cat] > 0}

    return prob_col2_given_col1, prob_col1_given_col2


def plot_conditional_frequencies(df, col1, col2, title):
    """
    Plots conditional frequencies P(col2 | col1) and P(col1 | col2) as bar plots.
    """
    prob_col2_given_col1, prob_col1_given_col2 = compute_conditional_frequencies(df, col1, col2)

    # Sorting categories for consistent plotting
    all_categories = sorted(set(prob_col2_given_col1.keys()).union(set(prob_col1_given_col2.keys())))

    # Get values
    values_col2_given_col1 = [prob_col2_given_col1.get(cat, 0) for cat in all_categories]
    values_col1_given_col2 = [prob_col1_given_col2.get(cat, 0) for cat in all_categories]

    # Set up bar positions
    x = np.arange(len(all_categories))
    width = 0.4

    # Plot
    plt.figure(figsize=(12, 6))
    plt.bar(x - width/2, values_col2_given_col1, width=width, label=f'P({col2} | {col1})', color='skyblue')
    plt.bar(x + width/2, values_col1_given_col2, width=width, label=f'P({col1} | {col2})', color='salmon')

    # Labels and title
    plt.xlabel('Categories')
    plt.ylabel('Frequency')
    plt.title(title)
    plt.xticks(ticks=x, labels=all_categories, rotation=45, ha='right')
    plt.ylim(0, 1)
    plt.legend()
    plt.show()


# Usage
plot_conditional_frequencies(df_books, 'categories', 'pred_categories', 'Conditional Frequencies of Categories')

# %% [markdown]
#  - Given summaries categorized as either Sports & Fitness, Negotiation, or Personalities (3) by human labelers, AI is more likely not to assign these categories than to do so. I.e., **AI doesn't think those summaries belong to these categories while humans do so.**.
#  - Interestingly, there are quite a few categories for which humans are more likely not to assign them than to do so given that AI has labeled these categories as relevant: Sports & Fitness, Self-Growth, Leadership, Happiness, Productivity, Business & Career (6). I.e., **Humans don't think those summaries belong to these categories while AI does so**.

# %%
print("HUMAN SET SPORTS & FITNESS, BUT AI DIDN'T")
show_books(df_books[
    df_books['categories'].apply(lambda l: 'Sports & Fitness' in l) &
    df_books['pred_categories'].apply(lambda l: 'Sports & Fitness' not in l)].sample(5, random_state=42))
# Out:
# HUMAN SET SPORTS & FITNESS, BUT AI DIDN'T
# Book (idx=1596)
#  - Title: "The Righteous Mind: Why Good People Are Divided by Politics and Religion"
#  - Author: Jonathan Haidt, PhD
#  - Overview: What’s inside Explore the niche of moral psychology that will clarify how humans form their ethical standards and which factors can alter them.You’ll learn • The origin of righteousness • The difference between western and eastern principles • Whether morality is influenced by culture • About the controversy over religion About the author Jonathan Haidt is a leading American psychologist conducting studies on moral reasoning and righteousness. His research made him one of the most influential psychology experts in the world.
#  - Author Overview: Jonathan Haidt is a leading American psychologist conducting studies on moral reasoning and righteousness. His research made him one of the most influential psychology experts in the world.
#  - Learning items: ['The origin of righteousness', 'The difference between western and eastern principles', 'Whether morality is influenced by culture', 'About the controversy over religion']
#  - Categories: ['Society & Tech', 'Sports & Fitness']
#  - AI Categories: ['Society & Tech']
#  - AI Reasoning Steps: ['The book discusses moral psychology, which relates to how people form ethical standards.', 'It explores the origins of righteousness and the influence of culture on morality, indicating a focus on societal values and ethics.', "The mention of politics and religion suggests a connection to societal structures and beliefs, which aligns with the category of 'Society & Tech'.", "The book does not fit into categories like 'Fiction', 'Home & Environment', 'Sports & Fitness', 'Business & Career', 'Happiness', 'Self-Growth', 'Money & Investments', 'Personalities', 'Productivity', 'Leadership', 'Family', 'Love & Sex', or 'Health' as it is primarily focused on moral psychology and societal issues.", "Therefore, the most fitting category for this book is 'Society & Tech'."]
#
#
# Book (idx=1015)
#  - Title: "Hoax: Donald Trump, Fox News, and the Dangerous Distortion of Truth"
#  - Author: Brian Stelter
#  - Overview: What’s inside Is your news source reliable or a weapon of distortion? Unveil how media bias can reshape your reality and challenge you to think critically about information.You’ll learn • How Fox shaped Trump's views • What makes news into propaganda • Why label COVID a "hoax"? • How media bias sways elections About the author Brian Stelter is a seasoned media reporter and former TV host at CNN, known for his sharp analysis of the television industry. His insights draw on extensive experience covering media influence and misinformation.
#  - Author Overview: Brian Stelter is a seasoned media reporter and former TV host at CNN, known for his sharp analysis of the television industry. His insights draw on extensive experience covering media influence and misinformation.
#  - Learning items: ["How Fox shaped Trump's views", 'What makes news into propaganda', 'Why label COVID a "hoax"?', 'How media bias sways elections']
#  - Categories: ['Society & Tech', 'Sports & Fitness']
#  - AI Categories: ['Society & Tech']
#  - AI Reasoning Steps: ['The book discusses media bias and its impact on public perception, particularly in relation to Donald Trump and Fox News.', "It addresses how news can be manipulated into propaganda, which relates to societal issues and technology's role in shaping narratives.", "The focus on critical thinking about information sources suggests a connection to societal awareness and technology's influence on media.", 'The author, Brian Stelter, is a media reporter, indicating that the book is rooted in analysis of media and its societal implications.', 'The key learning items emphasize the relationship between media, politics, and public perception, which aligns with societal themes.']
#
#
# Book (idx=1307)
#  - Title: "Nothing to Envy: Ordinary Lives in North Korea"
#  - Author: Barbara Demick
#  - Overview: What’s inside Peek behind the curtain of hidden North Korean life and discover how authoritarian power can destroy people's destinies.You’ll learn • About the creation of North Korea • What Juche philosophy is • The function of the caste system • How people managed to flee the country About the author Barbara Demick is a leading journalist and former bureau chief in China and South Korea. Through her job, she uncovered human rights issues and injustice in North Korea.
#  - Author Overview: Barbara Demick is a leading journalist and former bureau chief in China and South Korea. Through her job, she uncovered human rights issues and injustice in North Korea.
#  - Learning items: ['About the creation of North Korea', 'What Juche philosophy is', 'The function of the caste system', 'How people managed to flee the country']
#  - Categories: ['Society & Tech', 'Sports & Fitness']
#  - AI Categories: ['Society & Tech']
#  - AI Reasoning Steps: ['The book discusses the lives of ordinary people in North Korea, which suggests a focus on societal issues.', 'It explores themes of authoritarianism, human rights, and the impact of political systems on individuals, indicating a strong connection to societal structures.', 'The author is a journalist who has reported on human rights issues, further emphasizing the societal and political context of the book.', 'The key learning items include the creation of North Korea, Juche philosophy, and the caste system, all of which relate to societal and political themes.', 'The book does not fit into categories like Fiction, Home & Environment, Spirituality, Sports & Fitness, Business & Career, Happiness, Self-Growth, Money & Investments, Personalities, Productivity, Leadership, Family, Love & Sex, or Health, as it is primarily focused on societal issues rather than personal development or relationships.']
#
#
# Book (idx=1341)
#  - Title: "Midnight in Chernobyl: The Untold Story of the World's Greatest Nuclear Disaster"
#  - Author: Adam Higginbotham
#  - Overview: What’s inside Find out why and how the worst nuclear disaster in history happened. Expand your horizons and reflect on the fragility of the environment.You’ll learn • Causes of a nuclear explosion • Who is to blame for the Chornobyl disaster • How radiation kills • The dangers of Soviet politics About the author Adam Higginbotham is a journalist for The Sunday Telegraph Magazine. According to The New York Times, his book received the Military and Intelligence Writing Award and is one of the 10 Best Books of 2019.
#  - Author Overview: Adam Higginbotham is a journalist for The Sunday Telegraph Magazine. According to The New York Times, his book received the Military and Intelligence Writing Award and is one of the 10 Best Books of 2019.
#  - Learning items: ['Causes of a nuclear explosion', 'Who is to blame for the Chornobyl disaster', 'How radiation kills', 'The dangers of Soviet politics']
#  - Categories: ['Home & Environment', 'Society & Tech', 'Sports & Fitness']
#  - AI Categories: ['Health', 'Society & Tech']
#  - AI Reasoning Steps: ['The book discusses the Chernobyl disaster, which is a historical event, indicating a focus on real-world events rather than fictional narratives.', 'It explores the causes of a nuclear explosion and the implications of radiation, which relates to health and environmental concerns.', 'The mention of Soviet politics suggests a societal and technological context, as it reflects on the political environment surrounding the disaster.', 'The book does not fit into categories like Fiction, Spirituality, Sports & Fitness, Business & Career, Happiness, Self-Growth, Money & Investments, Personalities, Productivity, Leadership, Family, or Love & Sex, as these themes are not present in the overview or key learning items.', "The most relevant categories based on the content are 'Health' due to the discussion of radiation and its effects, and 'Society & Tech' because of the exploration of political factors and technological failures leading to the disaster."]
#
#
# Book (idx=882)
#  - Title: "The Varieties of Religious Experience"
#  - Author: William James
#  - Overview: What’s inside Is spiritual insight more than brain chemistry? Discover the profound interplay between faith and psychology, a journey beyond mere data to the core of human belief.You’ll learn • How beliefs affect behavior • What exceeds neurology in faith • Why spiritual data makes sense • If actions justify beliefs About the author William James, an eminent American philosopher and psychologist, built a bridge between psychology, philosophy, and religion. He has deeply influenced the modern thought on the nature of the human experience​.
#  - Author Overview: William James, an eminent American philosopher and psychologist, built a bridge between psychology, philosophy, and religion. He has deeply influenced the modern thought on the nature of the human experience​.
#  - Learning items: ['How beliefs affect behavior', 'What exceeds neurology in faith', 'Why spiritual data makes sense', 'If actions justify beliefs']
#  - Categories: ['Society & Tech', 'Spirituality', 'Sports & Fitness']
#  - AI Categories: ['Spirituality', 'Self-Growth']
#  - AI Reasoning Steps: ['The book discusses the interplay between faith and psychology, indicating a focus on spirituality.', 'It explores how beliefs affect behavior, which aligns with themes of self-growth and personal understanding.', 'The author, William James, is known for his contributions to philosophy and psychology, particularly in relation to human experience and spirituality.', 'The key learning items suggest a deep exploration of spiritual insights and their implications on human behavior, further emphasizing the spiritual aspect.']

# %% [markdown]
# Justified if AI was right not to include this category
#  - 1596 — *JUSTIFIED*
#  - 1015 — *JUSTIFIED*
#  - 1307 — *JUSTIFIED*
#  - 1341 — *JUSTIFIED*
#  - 882 — *JUSTIFIED*
#
# Conclusion
#  - So far it seems that humans assigned books to Sports & Fitness randomly...

# %%
print("AI SET SPORTS & FITNESS, BUT HUMAN DIDN'T")
show_books(df_books[
    df_books['categories'].apply(lambda l: 'Sports & Fitness' not in l) &
    df_books['pred_categories'].apply(lambda l: 'Sports & Fitness' in l)].sample(5, random_state=42))
# Out:
# AI SET SPORTS & FITNESS, BUT HUMAN DIDN'T
# Book (idx=2)
#  - Title: "Eat Move Sleep: How Small Choices Lead to Big Changes"
#  - Author: Tom Rath
#  - Overview: What’s inside Discover how inner strength, willpower, and right choices can significantly impact your well-being and learn tricks to lead a healthier, more fulfilling life.You’ll learn • The power of positive dietary choices • How movement enhances well-being • The crucial role of quality sleep • Strategies for building inner strength About the author Tom Rath is a renowned author of best-selling books and an expert on employee well-being and improving workplace health.
#  - Author Overview: Tom Rath is a renowned author of best-selling books and an expert on employee well-being and improving workplace health.
#  - Learning items: ['The power of positive dietary choices', 'How movement enhances well-being', 'The crucial role of quality sleep', 'Strategies for building inner strength']
#  - Categories: ['Health']
#  - AI Categories: ['Health', 'Self-Growth', 'Sports & Fitness']
#  - AI Reasoning Steps: ['The book focuses on well-being and how small choices can lead to significant changes in health.', 'It discusses dietary choices, movement, and sleep, which are all related to health and fitness.', 'The author is an expert in employee well-being, indicating a focus on health in a workplace context.', 'The key learning items emphasize personal health strategies, which align with self-growth and health improvement.', 'The overall theme of the book is about making positive lifestyle changes, which fits well within the categories of Health and Self-Growth.']
#
#
# Book (idx=90)
#  - Title: "String Theory: David Foster Wallace on Tennis"
#  - Author: David Foster Wallace
#  - Overview: What’s inside Uncover the profound intricacies of professional tennis, steeped in tactics and endurance. See how this sport can offer life-changing insights and unique strategies for success.You’ll learn • How wind silently affects a tennis match • Why sweating can be a game-changer • About unseen brutality of tennis qualifiers • The two unique visions of professional players About the author David Foster Wallace is an award-winning author known for his profound insights and engaging narratives. Famous for works like "Infinite Jest," Wallace's deep dive into tennis reveals not just the sport but his strategic mind.
#  - Author Overview: David Foster Wallace is an award-winning author known for his profound insights and engaging narratives. Famous for works like "Infinite Jest," Wallace's deep dive into tennis reveals not just the sport but his strategic mind.
#  - Learning items: ['How wind silently affects a tennis match', 'Why sweating can be a game-changer', 'About unseen brutality of tennis qualifiers', 'The two unique visions of professional players']
#  - Categories: ['Society & Tech']
#  - AI Categories: ['Sports & Fitness']
#  - AI Reasoning Steps: ["The book is titled 'String Theory: David Foster Wallace on Tennis', indicating a focus on tennis as a sport.", 'The overview discusses professional tennis, including tactics, endurance, and insights that can be drawn from the sport.', 'Key learning items mention specific aspects of tennis, such as the impact of wind, the significance of sweating, and the experiences of players in qualifiers, all of which relate directly to sports.', "David Foster Wallace is known for his deep insights, and this book appears to explore not just the sport but also the life lessons and strategies that can be derived from it, which aligns with the 'Sports & Fitness' category.", "Given that the book is centered around tennis, a sport, and discusses various elements of it, the most fitting category from the predefined list is 'Sports & Fitness'.", "Other categories such as 'Self-Growth' or 'Happiness' could be considered if the book focused more on personal development or life lessons, but the primary focus remains on tennis."]
#
#
# Book (idx=828)
#  - Title: "I Can Make You Thin: The Revolutionary System Used by More Than 3 Million People"
#  - Author: Paul McKenna
#  - Overview: What’s inside Discover how to manage your eating habits and shed pounds with minimal effort. Learn about common challenges keeping most people from losing weight and how to overcome them.You’ll learn • Secrets of naturally slim individuals • How to differentiate hunger from emotional eating • The influence of mindset on weight control • Steps to combat emotional eating triggers About the author Paul McKenna is a British hypnotist, author, and television presenter. He's known for pioneering self-help techniques, authoring bestsellers, and hosting popular TV shows on hypnosis and personal transformation.
#  - Author Overview: Paul McKenna is a British hypnotist, author, and television presenter. He's known for pioneering self-help techniques, authoring bestsellers, and hosting popular TV shows on hypnosis and personal transformation.
#  - Learning items: ['Secrets of naturally slim individuals', 'How to differentiate hunger from emotional eating', 'The influence of mindset on weight control', 'Steps to combat emotional eating triggers']
#  - Categories: ['Health']
#  - AI Categories: ['Health', 'Self-Growth', 'Sports & Fitness']
#  - AI Reasoning Steps: ['The book focuses on managing eating habits and weight loss, which directly relates to health and fitness.', 'It discusses emotional eating and mindset, which are important aspects of personal growth and self-awareness.', 'The author, Paul McKenna, is known for self-help techniques, indicating a strong connection to self-growth and personal development.', "The content is practical and aimed at improving one's lifestyle, which aligns with health and self-growth categories."]
#
#
# Book (idx=229)
#  - Title: "The TB12 Method: How to Achieve a Lifetime of Sustained Peak Performance"
#  - Author: Tom Brady
#  - Overview: What’s inside Uncover a revolutionary approach to health and fitness, transcending traditional methods to achieve holistic well-being through a unique blend of physical, mental, and nutritional strategies.You’ll learn • What is pliability, and how it can help you feel better • How much water you really need • About food choices that make you sick • Why mental fitness and recovery is critical About the author Thomas Edward Patrick Brady Jr. is a former American football quarterback in the National Football League (NFL). He led his teams to seven Super Bowl victories and was named the Most Valuable Player five times.
#  - Author Overview: Thomas Edward Patrick Brady Jr. is a former American football quarterback in the National Football League (NFL). He led his teams to seven Super Bowl victories and was named the Most Valuable Player five times.
#  - Learning items: ['What is pliability, and how it can help you feel better', 'How much water you really need', 'About food choices that make you sick', 'Why mental fitness and recovery is critical']
#  - Categories: ['Personalities']
#  - AI Categories: ['Sports & Fitness', 'Health', 'Self-Growth']
#  - AI Reasoning Steps: ['The book focuses on health and fitness, which suggests a strong connection to physical well-being.', 'It discusses mental fitness and recovery, indicating a holistic approach to health that encompasses both physical and mental aspects.', 'The author, Tom Brady, is a well-known figure in sports, particularly football, which aligns the book with sports and fitness themes.', 'The key learning items include nutrition and hydration, which are essential components of health and fitness.', 'Given the emphasis on achieving peak performance, the book also touches on self-growth and personal development.']
#
#
# Book (idx=1090)
#  - Title: "Commander In Cheat: How Golf Explains Trump"
#  - Author: Rick Reilly
#  - Overview: What’s inside Discover how golf provides a unique lens to view Donald Trump's character and leadership style. Learn insights that challenge and enlighten your understanding of power and integrity.You’ll learn • Why Trump's golf game mirrors his politics • How bending rules reflects on leadership • The paradox of power in shaping reality • About Scotland's standoff and its deeper meaning About the author Rick Reilly is a famous sports journalist and author known for his engaging and insightful commentary on sports. He has contributed to notable publications like Sports Illustrated and ESPN.
#  - Author Overview: Rick Reilly is a famous sports journalist and author known for his engaging and insightful commentary on sports. He has contributed to notable publications like Sports Illustrated and ESPN.
#  - Learning items: ["Why Trump's golf game mirrors his politics", 'How bending rules reflects on leadership', 'The paradox of power in shaping reality', "About Scotland's standoff and its deeper meaning"]
#  - Categories: ['Society & Tech']
#  - AI Categories: ['Sports & Fitness', 'Leadership', 'Society & Tech']
#  - AI Reasoning Steps: ["The book discusses golf as a lens to view Donald Trump's character, indicating a focus on sports and its intersection with politics.", 'The author, Rick Reilly, is a sports journalist, which suggests that the book will have a strong emphasis on sports-related themes.', 'Key learning points include insights into leadership and power dynamics, which are relevant to the category of Leadership.', 'The book also touches on societal issues and the implications of bending rules, which could relate to Society & Tech.', "However, the primary focus remains on golf and its relation to Trump's character, making Sports & Fitness a strong category."]

# %% [markdown]
# JUSTIFIED — AI was right to include Sports & Fitness.
#
#  - 2 — There definitely is a relation to Sports, GoodReads classifies it as Fitness, so *PROBABLY JUSTIFIED*
#  - 90 — ***DEFINITELY** JUSTIFIED*
#  - 828 — While Self-Growth might be a little too much, Sports & Fitness is a good fit. *JUSTIFIED*
#  - 229 — Wow... Personalities? AI is right. *JUSTIFIED*
#  - 1090 — *JUSTIFIED*
#
# Conclusion:
#  - Actually here rises a question: why Sports & Fitness category is so wrong? Given the examples above AI is so much better at assigning (or not) summaries to Sports & Fitness.

# %%
print("HUMAN SET NEGOTIATION, BUT AI DIDN'T")
show_books(df_books[
    df_books['categories'].apply(lambda l: 'Negotiation' in l) &
    df_books['pred_categories'].apply(lambda l: 'Negotiation' not in l)].sample(5, random_state=42))
# Out:
# HUMAN SET NEGOTIATION, BUT AI DIDN'T
# Book (idx=1412)
#  - Title: "The War for Reality: How to Win in the World of Fakes, Truths, and Communities"
#  - Author: Dmytro Kuleba
#  - Overview: What’s inside Make a world-view shift by looking behind the scenes of digitalization. Learn to filter the information flows and distinguish truth from fakes.You’ll learn • How power players shape a reality that benefits them • The influence of dopamine on the perception of reality • Decoding the community • How to interact with the state About the author Dmytro Kuleba is an experienced Ukrainian diplomat, statesman, and Minister of Foreign Affairs of Ukraine since 2020.
#  - Author Overview: Dmytro Kuleba is an experienced Ukrainian diplomat, statesman, and Minister of Foreign Affairs of Ukraine since 2020.
#  - Learning items: ['How power players shape a reality that benefits them', 'The influence of dopamine on the perception of reality', 'Decoding the community', 'How to interact with the state']
#  - Categories: ['Personalities', 'Society & Tech', 'Negotiation']
#  - AI Categories: ['Society & Tech', 'Leadership']
#  - AI Reasoning Steps: ['The book discusses the impact of digitalization on reality, which relates to technology and society.', 'It emphasizes the importance of filtering information and distinguishing truth from fakes, indicating a focus on media literacy and societal issues.', 'The author, being a diplomat, likely brings insights into leadership and state interaction, which could relate to political and societal dynamics.', "The themes of community influence and power dynamics suggest a connection to societal structures and technology's role in shaping perceptions."]
#
#
# Book (idx=1604)
#  - Title: "4 Essential Keys to Effective Communication in Love, Life, Work — Anywhere!"
#  - Author: Bento C. Leal III
#  - Overview: What’s inside Discover crucial skills based on empathic listening and non-judgemental talking to improve your communication and enrich your relationships with others.You’ll learn • Why empathy is vital for successful interaction • Techniques of mindful listening • How to overcome communication blocks • Simple approaches to impressive speaking About the author Bento C. Leal III is a certified relationship skills trainer and an Amazon bestselling author.
#  - Author Overview: Bento C. Leal III is a certified relationship skills trainer and an Amazon bestselling author.
#  - Learning items: ['Why empathy is vital for successful interaction', 'Techniques of mindful listening', 'How to overcome communication blocks', 'Simple approaches to impressive speaking']
#  - Categories: ['Negotiation', 'Self-Growth']
#  - AI Categories: ['Self-Growth', 'Love & Sex', 'Business & Career']
#  - AI Reasoning Steps: ['The book focuses on communication skills, which are essential in various aspects of life, including personal relationships and professional settings.', 'The key learning items emphasize empathy, mindful listening, and overcoming communication barriers, which are crucial for effective interaction in love and work.', 'The author is a certified relationship skills trainer, indicating a strong focus on interpersonal relationships and communication.', 'Given the emphasis on relationships and communication, categories related to personal development and interpersonal skills are most relevant.']
#
#
# Book (idx=10)
#  - Title: "The First Minute: How to Start Conversations That Get Results"
#  - Author: Chris Fenning
#  - Overview: What’s inside Are you ready to elevate your teamwork, leadership, and public speaking skills? Enhance your work processes and time management by becoming an expert at starting conversations.You’ll learn • How to become a peak performer • Time-saving strategies for you and your team • Effective email protocols • To conduct productive work meetings About the author Chris Fenning has over 20 years of experience helping organizations like NATO and Google communicate better. After being fed up with endless ads for communication courses that failed to deliver, he wrote his own guide.
#  - Author Overview: Chris Fenning has over 20 years of experience helping organizations like NATO and Google communicate better. After being fed up with endless ads for communication courses that failed to deliver, he wrote his own guide.
#  - Learning items: ['How to become a peak performer', 'Time-saving strategies for you and your team', 'Effective email protocols', 'To conduct productive work meetings']
#  - Categories: ['Negotiation']
#  - AI Categories: ['Business & Career', 'Productivity', 'Leadership']
#  - AI Reasoning Steps: ['The book focuses on starting conversations effectively, which is a key skill in business and career settings.', 'It discusses teamwork, leadership, and public speaking, all of which are essential components of professional development.', 'The author has extensive experience in communication, particularly in organizational contexts, indicating a strong business focus.', 'The key learning items include strategies for productivity and effective communication, which align with business and career advancement.', "Given the emphasis on improving work processes and time management, the categories of 'Business & Career' and 'Productivity' are particularly relevant."]
#
#
# Book (idx=1103)
#  - Title: "Don't Shoot the Dog!: The New Art of Teaching and Training"
#  - Author: Karen Pryor
#  - Overview: What’s inside Discover transformative strategies to foster positive change and enhance learning effectiveness. Use the power of reinforcement to improve your training and personal growth.You’ll learn • The magic of clicker training's success • Secrets behind timing in reinforcement • Surprising impact of "jackpot" rewards • About mimicry's power in behavior change About the author Karen Pryor is a writer and behavioral biologist. She was Hawaii's Sea Life Park's founder and pioneer dolphin trainer. She has an international reputation as a scientist in behavioral psychology and marine mammal biology.
#  - Author Overview: Karen Pryor is a writer and behavioral biologist. She was Hawaii's Sea Life Park's founder and pioneer dolphin trainer. She has an international reputation as a scientist in behavioral psychology and marine mammal biology.
#  - Learning items: ["The magic of clicker training's success", 'Secrets behind timing in reinforcement', 'Surprising impact of "jackpot" rewards', "About mimicry's power in behavior change"]
#  - Categories: ['Leadership', 'Negotiation']
#  - AI Categories: ['Self-Growth', 'Happiness']
#  - AI Reasoning Steps: ['The book focuses on teaching and training, which suggests a connection to personal development and self-improvement.', 'The mention of positive change and learning effectiveness indicates a focus on self-growth and personal development strategies.', 'The techniques discussed, such as clicker training and reinforcement, are often applied in personal growth contexts, particularly in behavior modification.', "The author's background in behavioral psychology further emphasizes the book's relevance to self-growth and personal development.", 'Given the emphasis on training and behavior change, the book aligns well with categories related to self-growth.']
#
#
# Book (idx=109)
#  - Title: "The Art of Witty Banter: Be Clever, Quick, & Magnetic"
#  - Author: Patrick King
#  - Overview: What’s inside Grasp key communication strategies to avoid awkward silences and become the most engaging conversationalist in the room.You’ll learn • To balance listening and speaking • What makes teasing playful • When to switch gears in a chat • Ways to break the tension  • How to never run out of things to say About the author Patrick King, a well-known communication coach, has been featured in Forbes, GQ Magazine, and NBC News. He specializes in helping people break through emotional barriers to build confidence and develop charisma.
#  - Author Overview: Patrick King, a well-known communication coach, has been featured in Forbes, GQ Magazine, and NBC News. He specializes in helping people break through emotional barriers to build confidence and develop charisma.
#  - Learning items: ['To balance listening and speaking', 'What makes teasing playful', 'When to switch gears in a chat', 'Ways to break the tension ', 'How to never run out of things to say']
#  - Categories: ['Negotiation']
#  - AI Categories: ['Self-Growth']
#  - AI Reasoning Steps: ['The book focuses on communication strategies, which suggests it is aimed at improving interpersonal skills.', 'The key learning items emphasize skills like balancing listening and speaking, teasing, and breaking tension, all of which relate to personal development in social contexts.', 'The author is a communication coach, indicating that the book is likely intended for self-improvement and personal growth in social interactions.', 'Given the emphasis on becoming a more engaging conversationalist and building confidence, the book aligns with themes of self-growth and personal development.', "The predefined categories include 'Self-Growth', which directly relates to the book's focus on improving communication skills and confidence.", "Other categories like 'Happiness' and 'Productivity' could be tangentially related, but 'Self-Growth' is the most fitting based on the content."]

# %% [markdown]
# JUSTIFIED — AI was right not to include 'Negotiation'
#
#  - 1412 — There is probably some relation to Negotiation, but at the same time, the book seems to be more about Society & Tech. Maybe the book itself relates topics of Negotiation and Personalities, but It's hard to say so just from the overview and learing items. *AMBIGUOUS*
#  - 1604 — *NOT JUSTIFIED*
#  - 10 — AI has actually assigned very relevant categories, but Negotiation *might* be applicable to. Actually, seems like we really need detailed descriptions of categories. *AMBIGUOUS*
#  - 1103 — I see no mention of Negotiantion. *JUSTIFIED*
#  - 109 — *PROBABLY NOT JUSTIFIED*
#
# Conclusion:
#  - It seems that this specific category is harder for AI to get right. Hypothesis: AI thinks negotiation is related to politics, sales, etc., and not to personal life. (see below)

# %%
print("AI SET NEGOTIATION")
show_books(df_books[
    df_books['pred_categories'].apply(lambda l: 'Negotiation' in l)].sample(5, random_state=5))
# Out:
# AI SET NEGOTIATION
# Book (idx=547)
#  - Title: "Start With NO: The Negotiating Tools that The Pros Don’t Want You to Know"
#  - Author: Jim Camp
#  - Overview: What’s inside Learn tactics that give you control and edge and turn any negotiations in your favor. Equip yourself with these skills to boost your deal-making confidence.You’ll learn • Why “no” is your strongest asset • How to keep feelings from deals • About the power of homework in negotiations • How to use someone's needs to your advantage About the author Jim Camp is a negotiation coach and founder of The Camp System. He has trained thousands of people worldwide and has worked with companies such as Intel, IBM, and Cisco.
#  - Author Overview: Jim Camp is a negotiation coach and founder of The Camp System. He has trained thousands of people worldwide and has worked with companies such as Intel, IBM, and Cisco.
#  - Learning items: ['Why “no” is your strongest asset', 'How to keep feelings from deals', 'About the power of homework in negotiations', "How to use someone's needs to your advantage"]
#  - Categories: ['Negotiation']
#  - AI Categories: ['Negotiation', 'Business & Career']
#  - AI Reasoning Steps: ['The book focuses on negotiation tactics, which is a specific skill set related to business interactions.', 'The author, Jim Camp, is a negotiation coach, indicating that the content is professional and aimed at improving negotiation skills.', "Key learning items emphasize strategies for negotiating effectively, such as the importance of saying 'no' and understanding the needs of others, which are central to negotiation.", "The predefined category list includes 'Negotiation', which directly aligns with the book's subject matter.", "Other categories like 'Business & Career' could also be relevant since negotiation skills are often applied in business contexts."]
#
#
# Book (idx=847)
#  - Title: "The Anatomy of Peace: Resolving the Heart of Conflict"
#  - Author: The Arbinger Institute
#  - Overview: What’s inside Tired of conflict? Turn confrontation into collaboration and guide your life toward genuine peace!You’ll learn • Why a quick fix is a big no • How do you humanize others • What hides behind a conflict • When to communicate openly About the author The Arbinger Institute is known worldwide for employing cutting-edge psychology to empower individuals and organizations to achieve peace.
#  - Author Overview: The Arbinger Institute is known worldwide for employing cutting-edge psychology to empower individuals and organizations to achieve peace.
#  - Learning items: ['Why a quick fix is a big no', 'How do you humanize others', 'What hides behind a conflict', 'When to communicate openly']
#  - Categories: ['Negotiation', 'Self-Growth']
#  - AI Categories: ['Self-Growth', 'Negotiation', 'Leadership']
#  - AI Reasoning Steps: ['The book focuses on resolving conflict and achieving peace, which suggests themes of personal development and interpersonal relationships.', 'The key learning items emphasize understanding others, communication, and the psychological aspects of conflict, aligning with self-growth and personal development.', 'The author, The Arbinger Institute, specializes in psychology aimed at empowering individuals, which further supports the categorization under self-growth and possibly leadership.', 'The book does not fit into categories like Fiction, Home & Environment, Sports & Fitness, Money & Investments, Personalities, or Health, as it is not about those topics.', 'The themes of collaboration and communication also suggest relevance to negotiation, as it involves resolving conflicts and reaching agreements.']
#
#
# Book (idx=1615)
#  - Title: "WOLFPACK: How to Come Together, Unleash Our Power, and Change the Game"
#  - Author: Abby Wambach
#  - Overview: What’s inside Do you feel like society's expectations limit you? Unleash your potential with strategies to redefine women's leadership and claim your power.You’ll learn • How to lead like a wolf • Negotiation tactics for equality • How to confront gender issues in sports and beyond • Ways to build and sustain supportive communities About the author Abby Wambach, a soccer legend and activist, transitioned to advocating for gender equality and leadership training for women post-retirement. She inspires others through initiatives like the Wolfpack Endeavor.
#  - Author Overview: Abby Wambach, a soccer legend and activist, transitioned to advocating for gender equality and leadership training for women post-retirement. She inspires others through initiatives like the Wolfpack Endeavor.
#  - Learning items: ['How to lead like a wolf', 'Negotiation tactics for equality', 'How to confront gender issues in sports and beyond', 'Ways to build and sustain supportive communities']
#  - Categories: ['Leadership', 'Self-Growth']
#  - AI Categories: ['Sports & Fitness', 'Self-Growth', 'Leadership', 'Negotiation', 'Society & Tech']
#  - AI Reasoning Steps: ["The book focuses on women's leadership and empowerment, which suggests a connection to 'Self-Growth' and 'Leadership'.", "It discusses negotiation tactics for equality, indicating relevance to the 'Negotiation' category.", "The author, Abby Wambach, is a prominent figure in sports, which aligns the book with 'Sports & Fitness'.", "The themes of community building and confronting gender issues suggest a societal aspect, linking it to 'Society & Tech'.", 'Overall, the book emphasizes personal development and leadership in the context of sports and gender equality.']
#
#
# Book (idx=317)
#  - Title: "Women Don’t Ask: Negotiation and the Gender Divide"
#  - Author: Linda Babcock, PhD, Sara Laschever
#  - Overview: What’s inside Uncover how gender dynamics shape negotiation behaviors and career progress. Learn to empower your negotiation skills for greater success.You’ll learn • Why women hesitate to negotiate • The impact of gender roles on careers • Strategies to improve negotiation results • About the power of assertive communication • How to overcome negotiation anxiety About the author Linda Babcock is the James M. Walton Professor of Economics and Head of the Social and Decision Sciences Department. Sara Laschever is a writer and authority on women's challenges at work.
#  - Author Overview: Linda Babcock is the James M. Walton Professor of Economics and Head of the Social and Decision Sciences Department. Sara Laschever is a writer and authority on women's challenges at work.
#  - Learning items: ['Why women hesitate to negotiate', 'The impact of gender roles on careers', 'Strategies to improve negotiation results', 'About the power of assertive communication', 'How to overcome negotiation anxiety']
#  - Categories: ['Society & Tech', 'Negotiation']
#  - AI Categories: ['Negotiation', 'Business & Career']
#  - AI Reasoning Steps: ["The book focuses on negotiation, particularly how gender dynamics affect women's negotiation behaviors.", 'It discusses the reasons why women may hesitate to negotiate, which is directly related to negotiation skills and strategies.', 'The authors provide insights into assertive communication and overcoming anxiety in negotiations, which are key components of negotiation training.', 'The content is aimed at improving career outcomes through better negotiation practices, linking it to business and career development.', "Given the emphasis on negotiation and its specific challenges for women, the category 'Negotiation' is highly relevant.", "The book also touches on broader themes of gender roles and their impact on careers, which could relate to 'Society & Tech' but is more specifically focused on negotiation."]
#
#
# Book (idx=1462)
#  - Title: "Crucial Conversations: Tools for Talking When Stakes Are High"
#  - Author: Kerry Patterson, Joseph Grenny, Ron McMillan, Al Switzer
#  - Overview: What’s inside Discover practical strategies for conducting meaningful conversations and learn how to get the desired results at work and in your life.You’ll learn • The importance of crucial conversations • What the Pool of Shared Meaning is • About conversational warning signs • How to use the S.T.A.T.E. framework About the author Kerry Patterson, Joseph Grenny, Ron McMillan, and Al Switzler are the co-founders of VitalSmarts, a company specializing in redesigned courses.
#  - Author Overview: Kerry Patterson, Joseph Grenny, Ron McMillan, and Al Switzler are the co-founders of VitalSmarts, a company specializing in redesigned courses.
#  - Learning items: ['The importance of crucial conversations', 'What the Pool of Shared Meaning is', 'About conversational warning signs', 'How to use the S.T.A.T.E. framework']
#  - Categories: ['Negotiation']
#  - AI Categories: ['Business & Career', 'Self-Growth', 'Leadership', 'Negotiation']
#  - AI Reasoning Steps: ['The book focuses on strategies for effective communication, particularly in high-stakes situations, which suggests a focus on interpersonal skills.', 'The key learning items emphasize the importance of conversations, frameworks for communication, and understanding conversational dynamics, indicating a focus on personal development and skills.', 'Given the emphasis on communication and its application in both personal and professional contexts, categories related to self-improvement and career development are relevant.', 'The authors are experts in the field of communication and training, which aligns with themes of leadership and negotiation, as effective communication is crucial in these areas.']

# %% [markdown]
#  - Yes, seems that AI percieves "Negotiation" topic more like politics- or sales-related, or if there is a strong indication (e.g., explicit use of this word).

# %%
print("HUMAN SET PESRONALITIES, BUT AI DIDN'T")
show_books(df_books[
    df_books['categories'].apply(lambda l: 'Personalities' in l) &
    df_books['pred_categories'].apply(lambda l: 'Personalities' not in l)].sample(5, random_state=42))
# Out:
# HUMAN SET PESRONALITIES, BUT AI DIDN'T
# Book (idx=719)
#  - Title: "Good for a Girl: A Woman Running in a Man's World"
#  - Author: Lauren Fleshman
#  - Overview: What’s inside Uncover the story of the professional runner Lauren Fleshman and find out what difficulties female athletes face in sports today.You’ll learn • About the dangers of strict diets • How puberty affects female runners' speed • The percentage of women coaches in professional sports • Different career paths for professional runners About the author Lauren Fleshman is an American runner, coach, and author. She won five NCAA championships at Stanford and two national championships as a professional athlete.
#  - Author Overview: Lauren Fleshman is an American runner, coach, and author. She won five NCAA championships at Stanford and two national championships as a professional athlete.
#  - Learning items: ['About the dangers of strict diets', "How puberty affects female runners' speed", 'The percentage of women coaches in professional sports', 'Different career paths for professional runners']
#  - Categories: ['Personalities', 'Business & Career', 'Self-Growth']
#  - AI Categories: ['Sports & Fitness', 'Health']
#  - AI Reasoning Steps: ["The book is about a female athlete's experiences and challenges in a male-dominated sport, which suggests a focus on sports.", 'It discusses specific issues faced by female runners, such as the impact of puberty and the dangers of strict diets, indicating a health and fitness aspect.', 'The mention of women coaches and career paths for professional runners suggests a connection to sports careers and the broader societal context of women in sports.', "Given the author's background as a professional runner and coach, the book likely emphasizes sports and fitness, as well as health-related topics."]
#
#
# Book (idx=1293)
#  - Title: "Hidden Figures: The Untold Story of the African American Women Who Helped Win the Space Race"
#  - Author: Margot Lee Shetterly
#  - Overview: What’s inside Dive into the story of black women mathematicians at NASA during the Space Race. Inspire your life and learn how to overcome the biggest challenges.You’ll learn • About the role of women in NASA's history • How to overcome racial and gender barriers • The impact of teamwork on success • Ways to evolve persistence in the face of adversity About the author Margot Lee Shetterly is an American bestselling author of nonfiction with extensive experience in startups. In her work, she focuses on gender and racial discrimination.
#  - Author Overview: Margot Lee Shetterly is an American bestselling author of nonfiction with extensive experience in startups. In her work, she focuses on gender and racial discrimination.
#  - Learning items: ["About the role of women in NASA's history", 'How to overcome racial and gender barriers', 'The impact of teamwork on success', 'Ways to evolve persistence in the face of adversity']
#  - Categories: ['Personalities', 'Society & Tech']
#  - AI Categories: ['Self-Growth', 'Society & Tech']
#  - AI Reasoning Steps: ['The book focuses on the contributions of African American women mathematicians at NASA, which highlights themes of gender and racial discrimination.', 'It emphasizes overcoming barriers, which aligns with personal development and self-growth.', 'The narrative also discusses teamwork and persistence, which are important aspects of leadership and personal growth.', 'The author, Margot Lee Shetterly, has a background in addressing issues of gender and racial discrimination, further supporting the themes of self-growth and societal impact.', "Given the focus on overcoming challenges and the historical context, the book fits well within the categories of 'Self-Growth' and 'Society & Tech'."]
#
#
# Book (idx=1246)
#  - Title: "Hamilton: The Revolution"
#  - Author: Lin-Manuel Miranda, Jeremy McCarter
#  - Overview: What’s inside Have you ever wondered whether a musical could change the world? See how Hamilton broke all the rules and reshaped Broadway.You’ll learn • Why diverse casting reflects today's America • How history shapes art and vice versa • About the impact of shows on young audiences • How Hamilton turns casting into a statement About the author Lin-Manuel Miranda is a singer and playwright who has received the Pulitzer Prize and three Tony Awards. Jeremy McCarter, a journalist and writer, has contributed to The New York Times and Buzzfeed, covering culture and politics.
#  - Author Overview: Lin-Manuel Miranda is a singer and playwright who has received the Pulitzer Prize and three Tony Awards. Jeremy McCarter, a journalist and writer, has contributed to The New York Times and Buzzfeed, covering culture and politics.
#  - Learning items: ["Why diverse casting reflects today's America", 'How history shapes art and vice versa', 'About the impact of shows on young audiences', 'How Hamilton turns casting into a statement']
#  - Categories: ['Personalities']
#  - AI Categories: ['Society & Tech']
#  - AI Reasoning Steps: ["The book 'Hamilton: The Revolution' discusses the impact of the musical 'Hamilton' on Broadway and society.", 'It emphasizes themes such as diverse casting and how it reflects contemporary America, which relates to societal issues.', 'The book also explores the intersection of history and art, indicating a focus on cultural and societal narratives.', 'The authors, Lin-Manuel Miranda and Jeremy McCarter, are involved in the arts and culture, further aligning the book with societal themes rather than personal development or business.', "Given the predefined categories, 'Society & Tech' is the most relevant as it encompasses discussions about societal issues, culture, and the impact of art on society."]
#
#
# Book (idx=952)
#  - Title: "Solito: A Memoir"
#  - Author: Javier Zamora
#  - Overview: What’s inside Discover how trials build character and hone talent. Be inspired by a 9-year-old migrant who managed to get from El Salvador to the USA thanks to his strength of mind and the kindness of strangers.You’ll learn • Why kindness can save the world • How migrants cross the US border • What many children of El Salvador go through • Reasons to never give up after the first failure About the author Javier Zamora is a Salvadoran poet and writer with a National Endowment for the Arts and Poetry Foundation Fellowship.
#  - Author Overview: Javier Zamora is a Salvadoran poet and writer with a National Endowment for the Arts and Poetry Foundation Fellowship.
#  - Learning items: ['Why kindness can save the world', 'How migrants cross the US border', 'What many children of El Salvador go through', 'Reasons to never give up after the first failure']
#  - Categories: ['Personalities', 'Society & Tech', 'Sports & Fitness']
#  - AI Categories: ['Society & Tech', 'Self-Growth', 'Happiness']
#  - AI Reasoning Steps: ['The book is a memoir, which typically falls under personal narratives and experiences.', 'The author, Javier Zamora, shares his journey as a migrant child, which relates to themes of society and personal growth.', 'Key learning points emphasize kindness, resilience, and the experiences of migrants, which align with societal issues and personal development.', 'The focus on the challenges faced by children in El Salvador and the journey to the USA highlights societal themes and personal struggles.', 'The overarching message of never giving up and the importance of kindness suggests a connection to self-growth and happiness.']
#
#
# Book (idx=889)
#  - Title: "All Boys Aren’t Blue: A Memoir-Manifesto"
#  - Author: George M. Johnson
#  - Overview: What’s inside Discover George’s journey of navigating his life as a Black queer man and learn to embrace the complexities of your own identity.You’ll learn • Identity challenges in the Black/queer intersection • How to counter homophobia and racism • Limitations LGBTQIAP+ people encounter • The journey of embracing how you identify About the author George Matthew Johnson is an Emmy-nominated, queer, Black American author, journalist, and activist. His books “All Boys Aren’t Blue” and “We Are Not Broken” are New York Times bestsellers.
#  - Author Overview: George Matthew Johnson is an Emmy-nominated, queer, Black American author, journalist, and activist. His books “All Boys Aren’t Blue” and “We Are Not Broken” are New York Times bestsellers.
#  - Learning items: ['Identity challenges in the Black/queer intersection', 'How to counter homophobia and racism', 'Limitations LGBTQIAP+ people encounter', 'The journey of embracing how you identify']
#  - Categories: ['Personalities', 'Society & Tech', 'Sports & Fitness']
#  - AI Categories: ['Self-Growth', 'Society & Tech']
#  - AI Reasoning Steps: ['The book is a memoir, which typically falls under personal narratives or self-exploration.', 'The author discusses identity challenges, particularly at the intersection of being Black and queer, indicating a focus on personal identity and societal issues.', "The key learning items emphasize self-acceptance and understanding of one's identity, which aligns with themes of self-growth.", 'The book addresses societal issues such as homophobia and racism, suggesting a broader commentary on society and its impact on individuals.', "Given the focus on personal identity and growth, the most fitting category from the predefined list would be 'Self-Growth'."]

# %% [markdown]
# JUSTIFIED — AI was right not to set Personalities
#
#  - 719 — *NOT JUSTIFIED*
#  - 1293 — *NOT JUSTIFIED*
#  - 1246 — *NOT JUSTIFIED*
#  - 952 — *NOT JUSTIFIED*
#  - 889 — *NOT JUSTIFIED*
#
# Well, it seems that AI does pretty bad with this category. What books does it classify as "Personalities"?

# %%
show_books(df_books[df_books['pred_categories'].apply(lambda l: 'Personalities' in l)].sample(8, random_state=1))
# Out:
# Book (idx=1295)
#  - Title: "Jay-Z: Made in America"
#  - Author: Michael Eric Dyson
#  - Overview: What’s inside Unveil the cultural importance of hip-hop, and learn about the transformative power of Jay-Z's music in reflecting and shaping American society.You’ll learn • How hip-hop reshapes academic perspectives • Why “hustling” reflects American ambition • The poetic mastery behind Jay-Z's lyrics • About hip-hop's role in racial justice and politics About the author Michael Eric Dyson is an American author, ordained minister, and radio host. Ebony magazine designated him one of the 100 Most Influential African Americans and one of America’s 150 most powerful Black people.
#  - Author Overview: Michael Eric Dyson is an American author, ordained minister, and radio host. Ebony magazine designated him one of the 100 Most Influential African Americans and one of America’s 150 most powerful Black people.
#  - Learning items: ['How hip-hop reshapes academic perspectives', 'Why “hustling” reflects American ambition', "The poetic mastery behind Jay-Z's lyrics", "About hip-hop's role in racial justice and politics"]
#  - Categories: ['Personalities']
#  - AI Categories: ['Society & Tech', 'Personalities']
#  - AI Reasoning Steps: ['The book focuses on Jay-Z and his impact on American culture, particularly through hip-hop music.', 'It discusses themes of ambition, racial justice, and the poetic nature of lyrics, which are deeply tied to societal issues.', 'The author, Michael Eric Dyson, is known for his work on race and culture, indicating a strong societal focus in his writing.', "The key learning items emphasize hip-hop's role in reshaping academic perspectives and its influence on politics and justice, which aligns with societal themes.", "Given the predefined categories, 'Society & Tech' is the most relevant as it encompasses cultural discussions and societal impacts."]
#
#
# Book (idx=1617)
#  - Title: "Seven Kinds of People You Find in Bookshops"
#  - Author: Shaun Bythell
#  - Overview: What’s inside Uncover a humorous exploration of the diverse personalities encountered in bookshops, offering a witty insight into human behavior and the book-selling world.You’ll learn • What kind of reader you are • The people you should avoid in the bookstore • How to detect customer type • Which consultants will genuinely help you About the author Shaun Bythell owns Scotland's largest second-hand bookshop and co-organizes the Wigtown Festival.
#  - Author Overview: Shaun Bythell owns Scotland's largest second-hand bookshop and co-organizes the Wigtown Festival.
#  - Learning items: ['What kind of reader you are', 'The people you should avoid in the bookstore', 'How to detect customer type', 'Which consultants will genuinely help you']
#  - Categories: ['Society & Tech', 'Sports & Fitness']
#  - AI Categories: ['Personalities']
#  - AI Reasoning Steps: ['The book is a humorous exploration of different personalities found in bookshops, which suggests a focus on human behavior.', 'The author provides insights into the types of readers and customers, indicating a study of personalities in a specific context (bookshops).', 'The key learning points emphasize understanding different customer types and behaviors, which aligns with the study of personalities.', 'Given the context of the book, it does not fit into categories like Fiction, Home & Environment, Spirituality, Sports & Fitness, Business & Career, Happiness, Self-Growth, Money & Investments, Productivity, Leadership, Family, Love & Sex, Health, or Negotiation.', "The most fitting category from the predefined list is 'Personalities' as it directly relates to the exploration of different types of people."]
#
#
# Book (idx=1036)
#  - Title: "Just Kids"
#  - Author: Patti Smith
#  - Overview: What’s inside Discover the intimate and inspiring story of Patti Smith and Robert Mapplethorpe's rocky journey to the top through unique glimpses into their development as artists and people.You’ll learn • About Smith and Mapplethorpe’s youth • The inspiration behind their art • How to navigate complex relationships • The artistic legacy of Chelsea Hotel About the author Patti Smith is an acclaimed singer, songwriter, painter, writer, and poet most famous for her punk rock album Horses.
#  - Author Overview: Patti Smith is an acclaimed singer, songwriter, painter, writer, and poet most famous for her punk rock album Horses.
#  - Learning items: ['About Smith and Mapplethorpe’s youth', 'The inspiration behind their art', 'How to navigate complex relationships', 'The artistic legacy of Chelsea Hotel']
#  - Categories: ['Personalities']
#  - AI Categories: ['Personalities', 'Love & Sex']
#  - AI Reasoning Steps: ["The book 'Just Kids' is a memoir that focuses on the lives of Patti Smith and Robert Mapplethorpe, which suggests a personal narrative rather than a fictional story.", 'The overview mentions their youth and development as artists, indicating a focus on personal growth and artistic inspiration.', 'The key learning items include navigating complex relationships, which aligns with themes of love and personal connections.', 'The mention of the artistic legacy of Chelsea Hotel suggests a cultural and societal context, but it does not fit neatly into the predefined categories.', "Given that the book is a memoir about personal experiences and relationships, the most fitting categories would be 'Personalities' for the focus on the lives of two notable figures, and 'Love & Sex' for the exploration of their complex relationship."]
#
#
# Book (idx=1269)
#  - Title: "The Storyteller: Tales of Life and Music"
#  - Author: Dave Grohl
#  - Overview: What’s inside Get a dose of motivation and inspiration to start your musical career by reading the autobiography of a world-famous drummer.You’ll learn • How Grohl's first love influenced his career • When is it helpful to lie about age • What made Kurt Cobain a unique musician • Why Foo Fighters' backstage turned into a kindergarten About the author Dave Grohl was the drummer of Scream and Nirvana. During the coronavirus lockdown, he wrote a book that became the #1 New York Times Bestseller and one of Variety's Best Music Books of 2021.
#  - Author Overview: Dave Grohl was the drummer of Scream and Nirvana. During the coronavirus lockdown, he wrote a book that became the #1 New York Times Bestseller and one of Variety's Best Music Books of 2021.
#  - Learning items: ["How Grohl's first love influenced his career", 'When is it helpful to lie about age', 'What made Kurt Cobain a unique musician', "Why Foo Fighters' backstage turned into a kindergarten"]
#  - Categories: ['Personalities']
#  - AI Categories: ['Personalities', 'Self-Growth']
#  - AI Reasoning Steps: ['The book is an autobiography, which typically falls under the category of Personalities as it focuses on the life and experiences of a notable individual, in this case, Dave Grohl.', 'The overview mentions motivation and inspiration for starting a musical career, which aligns with themes of Self-Growth, as it encourages readers to pursue their passions and develop their skills.', "The book discusses Grohl's experiences in the music industry, including his relationships with other musicians like Kurt Cobain, which could also relate to Personalities, but primarily it emphasizes personal development and career inspiration.", 'The key learning items focus on personal anecdotes and insights that can inspire readers, further supporting the Self-Growth category.', 'While the book touches on aspects of career and the music industry, it does not fit neatly into Business & Career as it is more about personal experiences rather than business strategies or career advice in a corporate sense.']
#
#
# Book (idx=1717)
#  - Title: "Spare"
#  - Author: Prince Harry, The Duke of Sussex
#  - Overview: What’s inside Learn about the unique fate of Prince Harry, fifth in line to the British throne, who survived the trauma of loss in childhood. Become inspired by his struggle for freedom, love, and justice.You’ll learn • The cons of being royalty • The fate of Princess Diana • Prince Harry’s experiences with war • The price of freedom • What Meghan Markle is hiding About the author Prince Harry is part of the British royal family and the Duke of Sussex. He is a humanitarian, military veteran, mental wellness advocate, and environmentalist.
#  - Author Overview: Prince Harry is part of the British royal family and the Duke of Sussex. He is a humanitarian, military veteran, mental wellness advocate, and environmentalist.
#  - Learning items: ['The cons of being royalty', 'The fate of Princess Diana', 'Prince Harry’s experiences with war', 'The price of freedom', 'What Meghan Markle is hiding']
#  - Categories: ['Personalities']
#  - AI Categories: ['Self-Growth', 'Personalities', 'Society & Tech', 'Happiness']
#  - AI Reasoning Steps: ['The book is a memoir by Prince Harry, which suggests it will focus on personal experiences and insights rather than fictional storytelling.', 'The overview mentions themes of trauma, freedom, love, and justice, indicating a focus on personal growth and societal issues.', 'Key learning items include the cons of being royalty and experiences with war, which relate to societal and personal challenges.', 'The author is a public figure with a focus on humanitarian efforts, which aligns with themes of personal growth and societal impact.', 'The mention of mental wellness advocacy suggests a connection to self-growth and happiness.']
#
#
# Book (idx=1569)
#  - Title: "You Never Forget Your First: A Biography of George Washington"
#  - Author: Alexis Coe
#  - Overview: What’s inside Let history come alive as you explore the human side of George Washington. Embark on a thought-provoking adventure and enjoy a few lighthearted chuckles along the way.You’ll learn • How George Washington was a mama's boy • Whether his gorgeous hair was natural or a wig • About Washington's hidden talents • The love-hate relationship he had with politics About the author Alexis Coe is a historian and author known for her engaging and unconventional approach. She brings history to life with her vibrant narratives and fresh perspectives.
#  - Author Overview: Alexis Coe is a historian and author known for her engaging and unconventional approach. She brings history to life with her vibrant narratives and fresh perspectives.
#  - Learning items: ["How George Washington was a mama's boy", 'Whether his gorgeous hair was natural or a wig', "About Washington's hidden talents", 'The love-hate relationship he had with politics']
#  - Categories: ['Personalities', 'Society & Tech', 'Sports & Fitness']
#  - AI Categories: ['Personalities']
#  - AI Reasoning Steps: ['The book is a biography of George Washington, which suggests it focuses on a historical figure rather than a fictional narrative.', "The overview emphasizes the human side of Washington, indicating a focus on personal traits and characteristics, which aligns with the category of 'Personalities'.", 'The author, Alexis Coe, is a historian known for her engaging storytelling, which further supports the idea that the book is about a notable personality in history.', "The key learning items mention aspects of Washington's personal life and relationships, which could also relate to themes of 'Family' and 'Society & Tech', but the primary focus remains on his personality.", "Given the predefined categories, 'Personalities' is the most fitting category for this biography, as it directly relates to the exploration of George Washington as an individual."]
#
#
# Book (idx=1332)
#  - Title: "Narcissists and You: Learn to Manage Them in all Areas of Your Life"
#  - Author: Júlia Pascual
#  - Overview: What’s inside Discover how to deal with narcissistic individuals and avoid their negative influence.You’ll learn • About the definition of narcissism • The circumstances that lead to narcissism • How to recognize the different types of narcissists • Narcissists’ common manipulation methods About the author Júlia Pascual is a Spanish psychologist with more than ten years of experience. She provides strategic coaching to her patients, highlighting her efficiency and effectiveness.
#  - Author Overview: Júlia Pascual is a Spanish psychologist with more than ten years of experience. She provides strategic coaching to her patients, highlighting her efficiency and effectiveness.
#  - Learning items: ['About the definition of narcissism', 'The circumstances that lead to narcissism', 'How to recognize the different types of narcissists', 'Narcissists’ common manipulation methods']
#  - Categories: ['Spirituality', 'Self-Growth']
#  - AI Categories: ['Self-Growth', 'Personalities']
#  - AI Reasoning Steps: ['The book focuses on understanding and managing narcissistic individuals, which suggests a psychological and self-help aspect.', 'The author is a psychologist, indicating that the content is likely to be based on psychological principles and strategies for personal development.', 'Key learning items include recognizing types of narcissists and manipulation methods, which aligns with themes of self-awareness and personal growth.', 'The book aims to help readers manage relationships with narcissists, which can be related to personal development and self-growth in interpersonal contexts.', "Given the focus on managing relationships and understanding personalities, the categories 'Self-Growth' and 'Personalities' are particularly relevant."]
#
#
# Book (idx=1200)
#  - Title: "Life Will Be The Death of Me… And You Too"
#  - Author: Chelsea Handler
#  - Overview: What’s inside Is giving truly better than receiving? Find out how self-analysis can lead to unexpected enlightenment, turning insight into a rewarding journey.You’ll learn • How loss reshapes your worldview • Why empathy is key to community • To question life for self-understanding • The power of the Enneagram for personality About the author A successful comedian, Chelsea Handler shares her transformative journey with raw honesty. From fame to introspection, her tale reveals the richness of life beyond success.
#  - Author Overview: A successful comedian, Chelsea Handler shares her transformative journey with raw honesty. From fame to introspection, her tale reveals the richness of life beyond success.
#  - Learning items: ['How loss reshapes your worldview', 'Why empathy is key to community', 'To question life for self-understanding', 'The power of the Enneagram for personality']
#  - Categories: ['Society & Tech']
#  - AI Categories: ['Self-Growth', 'Happiness', 'Personalities']
#  - AI Reasoning Steps: ['The book discusses self-analysis and personal growth, which suggests a focus on self-improvement and understanding oneself.', "It emphasizes themes of loss and how it reshapes one's worldview, indicating a connection to emotional and psychological growth.", 'The mention of empathy and community points towards social aspects of personal development, which aligns with self-growth and societal understanding.', 'The reference to the Enneagram for personality suggests a focus on understanding different personality types, which relates to self-growth and personal insights.', 'Overall, the book seems to be a blend of personal narrative and self-help, focusing on personal development and emotional intelligence.']

# %% [markdown]
#  - So AI might sometimes think that Personalities is about specific traits of people, types of their behaviour, etc.
#  - Shouldn't we distinguish biographies from "types of personalities"?

# %%
print("AI SET LEADERSHIP, BUT HUMAN DIDN'T")
show_books(df_books[
    df_books['categories'].apply(lambda l: 'Leadership' not in l) &
    df_books['pred_categories'].apply(lambda l: 'Leadership' in l)].sample(5, random_state=42))
# Out:
# AI SET LEADERSHIP, BUT HUMAN DIDN'T
# Book (idx=178)
#  - Title: "The 15 Invaluable Laws Of Growth: Live Them And Reach Your Potential"
#  - Author: John C. Maxwell
#  - Overview: What’s inside Cultivate a constant desire to grow by asking yourself the right questions, avoiding unhealthy comparisons, practicing discipline, and influencing others.You’ll learn • What is potential • How to choose a mentor • Why you may need to change your environment • How to know yourself and become valuable About the author John C. Maxwell is an internationally recognized leadership expert and speaker, teaching personal development for fifty years. He is also a New York Times and Wall Street Journal best-selling author, selling millions of books.
#  - Author Overview: John C. Maxwell is an internationally recognized leadership expert and speaker, teaching personal development for fifty years. He is also a New York Times and Wall Street Journal best-selling author, selling millions of books.
#  - Learning items: ['What is potential', 'How to choose a mentor', 'Why you may need to change your environment', 'How to know yourself and become valuable']
#  - Categories: ['Self-Growth']
#  - AI Categories: ['Self-Growth', 'Leadership']
#  - AI Reasoning Steps: ['The book focuses on personal growth and development, which aligns with the concept of self-improvement.', "It discusses how to reach one's potential, which is a key aspect of self-growth.", 'The author, John C. Maxwell, is known for his expertise in leadership and personal development, indicating that leadership is a significant theme in the book.', 'The key learning items include choosing a mentor and understanding oneself, both of which are crucial for personal and professional growth.', 'The book emphasizes discipline and influencing others, which are important in both leadership and self-growth contexts.']
#
#
# Book (idx=114)
#  - Title: "Switch: How to Change Things When Change is Hard"
#  - Author: Dan Heath, Chip Heath
#  - Overview: What’s inside Curious how to harness change for your betterment? Use transformative insights to turn life’s challenges into opportunities for growth!You’ll learn • How bigger portions trick our minds • The power of the Elephant and the Rider • Bright spots' role in solving malnutrition • Why too many choices paralyze us About the author Dan Heath is a professor and speaker at Duke University. His works, along with his brother Chip Heath, a Stanford professor of organizational behavior, have been certified as great behavioral studies books.
#  - Author Overview: Dan Heath is a professor and speaker at Duke University. His works, along with his brother Chip Heath, a Stanford professor of organizational behavior, have been certified as great behavioral studies books.
#  - Learning items: ['How bigger portions trick our minds', 'The power of the Elephant and the Rider', "Bright spots' role in solving malnutrition", 'Why too many choices paralyze us']
#  - Categories: ['Productivity']
#  - AI Categories: ['Self-Growth', 'Productivity', 'Leadership']
#  - AI Reasoning Steps: ['The book focuses on how to implement change in various aspects of life, which suggests a focus on personal development and growth.', 'The key learning items indicate a strong emphasis on understanding human behavior and decision-making, which aligns with self-improvement and personal growth themes.', 'The authors are recognized for their work in behavioral studies, which further supports categorizing the book under self-growth and productivity.', "The insights provided in the book, such as the 'Elephant and the Rider' metaphor, are tools for personal and organizational change, which are often associated with leadership and productivity.", 'The overall theme of harnessing change for betterment aligns closely with self-growth and productivity.']
#
#
# Book (idx=1781)
#  - Title: "The Perfect Day to Boss Up: A Hustler's Guide to Building Your Empire"
#  - Author: Rick Ross, Neil Martinez-Belkin
#  - Overview: What’s inside Discover the principles that helped Rick Ross build his business empire and how to use them to reach your wildest dreams by unlocking your potential.You’ll learn • Seven things each leader must do • What matters more than talent for success • Why should you hurry up slowly • About tunnel vision and its pitfalls About the author Rick Ross (William Leonard Roberts II) is an influential American rapper, record executive, and entrepreneur. Neil Martinez-Belkin is a former music editor, known for his works on contemporary hip-hop.
#  - Author Overview: Rick Ross (William Leonard Roberts II) is an influential American rapper, record executive, and entrepreneur. Neil Martinez-Belkin is a former music editor, known for his works on contemporary hip-hop.
#  - Learning items: ['Seven things each leader must do', 'What matters more than talent for success', 'Why should you hurry up slowly', 'About tunnel vision and its pitfalls']
#  - Categories: ['Personalities', 'Business & Career']
#  - AI Categories: ['Business & Career', 'Leadership', 'Self-Growth']
#  - AI Reasoning Steps: ['The book is a guide to building a business empire, which suggests a focus on entrepreneurship and business principles.', 'The author, Rick Ross, is an entrepreneur and rapper, indicating a blend of personal experience and professional insight in the business realm.', 'Key learning items include leadership principles, success factors beyond talent, and strategic thinking, all of which are central to business and career development.', 'The themes of leadership and personal growth are prominent, as the book discusses what leaders must do and how to unlock potential.', "Given the focus on business strategies and leadership, the categories 'Business & Career' and 'Leadership' are highly relevant."]
#
#
# Book (idx=807)
#  - Title: "Living Forward: A Proven Plan to Stop Drifting and Get the Life You Want"
#  - Author: Michael Hyatt, Daniel Harkavy
#  - Overview: What’s inside Learn the art of self-management using accessible tools. Discern your priorities and lead your life toward them.You’ll learn • What it means to drift • To leave your desired legacy • How to change without losing routine • The importance of sticking to necessities About the author Michael Hyatt is an American writer and the founder of Michael Hyatt & Company. His professional interests include leadership and productivity. Daniel Harkavy is an American business coach and the founder of Building Champions.
#  - Author Overview: Michael Hyatt is an American writer and the founder of Michael Hyatt & Company. His professional interests include leadership and productivity. Daniel Harkavy is an American business coach and the founder of Building Champions.
#  - Learning items: ['What it means to drift', 'To leave your desired legacy', 'How to change without losing routine', 'The importance of sticking to necessities']
#  - Categories: ['Productivity', 'Self-Growth']
#  - AI Categories: ['Self-Growth', 'Productivity', 'Leadership', 'Business & Career']
#  - AI Reasoning Steps: ['The book focuses on self-management and personal development, which suggests a connection to self-growth.', "It discusses the concept of drifting and how to lead a life aligned with one's priorities, indicating a focus on productivity and personal effectiveness.", 'The authors have backgrounds in leadership and coaching, which aligns with themes of leadership and career development.', 'The key learning items emphasize changing routines and sticking to necessities, which are important aspects of productivity and self-growth.']
#
#
# Book (idx=679)
#  - Title: "The Third Door: The Wild Quest to Uncover How the World's Most Successful People Launched Their Careers"
#  - Author: Alex Banayan
#  - Overview: What’s inside Embark on a thrilling journey with an 18-year-old dreamer to explore the behind-the-scenes lives of the world's most influential people and uncover their secrets to success.You’ll learn • How to make money while having fun • About the Qi Time method to have more hours in a day • Ways to calculate risk when making decisions • Why being wrong is better than doing nothing About the author Alex Banayan holds the title of the youngest bestselling business author in American history. He is a leading expert in high performance and personal development, recognized on Forbes' 30 Under 30 list.
#  - Author Overview: Alex Banayan holds the title of the youngest bestselling business author in American history. He is a leading expert in high performance and personal development, recognized on Forbes' 30 Under 30 list.
#  - Learning items: ['How to make money while having fun', 'About the Qi Time method to have more hours in a day', 'Ways to calculate risk when making decisions', 'Why being wrong is better than doing nothing']
#  - Categories: ['Business & Career']
#  - AI Categories: ['Business & Career', 'Self-Growth', 'Productivity', 'Leadership']
#  - AI Reasoning Steps: ['The book focuses on uncovering the secrets to success from influential people, which suggests a strong connection to personal development and career advancement.', 'The author, Alex Banayan, is recognized for his expertise in high performance and personal development, indicating that the book likely aligns with themes of self-growth and career strategies.', 'Key learning items include making money while having fun, which relates to business and career success, as well as personal finance.', 'The Qi Time method mentioned suggests a focus on productivity and time management, which is relevant to both personal growth and career efficiency.', 'The overall theme of the book revolves around achieving success and understanding the paths taken by successful individuals, which ties into leadership and personal development.']

# %% [markdown]
# JUSTIFIED — AI was right to set leadership
#
#  - 178 — One of the topic of the book — influencing other. The author is a leadership experts, so *JUSTIFIED*
#  - 114 — *PROBABLY JUSTIFIED*
#  - 1781 — *JUSTIFIED*
#  - 807 — *PROBABLY JUSTIFIED*
#  - 679 — *JUSTIFIED*
#
# Conclusion
#  - It seems that AI setting Leadership when human don't is mostly justified.

# %%
print("AI SET HAPPINESS, BUT HUMAN DIDN'T")
show_books(df_books[
    df_books['categories'].apply(lambda l: 'Happiness' not in l) &
    df_books['pred_categories'].apply(lambda l: 'Happiness' in l)].sample(5, random_state=0))
# Out:
# AI SET HAPPINESS, BUT HUMAN DIDN'T
# Book (idx=637)
#  - Title: "Reinventing the Body, Resurrecting the Soul: How to Create a New You"
#  - Author: Deepak Chopra, MD
#  - Overview: What’s inside Enter the universe hidden in all of us and face the fears that stop you from becoming a better version of yourself. Discover what holds you back and learn to address it.You’ll learn • To care for your mind and body the same way • Why change is scary but rewarding • How to manage your energy to self-improve • Ways to stay peaceful through challenging times About the author Deepak Chopra is an Indian-American writer and alternative medicine specialist. He is one of the most renowned advocates for non-traditional treatment.
#  - Author Overview: Deepak Chopra is an Indian-American writer and alternative medicine specialist. He is one of the most renowned advocates for non-traditional treatment.
#  - Learning items: ['To care for your mind and body the same way', 'Why change is scary but rewarding', 'How to manage your energy to self-improve', 'Ways to stay peaceful through challenging times']
#  - Categories: ['Spirituality']
#  - AI Categories: ['Spirituality', 'Self-Growth', 'Health', 'Happiness']
#  - AI Reasoning Steps: ['The book focuses on self-improvement and personal transformation, which aligns with the concept of self-growth.', 'It discusses caring for the mind and body, indicating a connection to health and wellness.', 'The themes of managing energy and staying peaceful through challenges suggest a spiritual or holistic approach to personal development.', 'The author, Deepak Chopra, is known for his work in alternative medicine and spirituality, reinforcing the relevance of spirituality as a category.']
#
#
# Book (idx=346)
#  - Title: "Breaking the Habit of Being Yourself: How to Lose Your Mind and Create a New One"
#  - Author: Dr. Joe Dispenza
#  - Overview: What’s inside Discover a new science that allows us to create our reality. Start using techniques that will enable you to change yourself and your life.You’ll learn • About the quantum field • How your brain works • The power of meditation • About the higher mind • How to change your habits About the author Dr. Joe Dispenza is a professor of neurochemistry and neuroscience, lecturer, and business consultant. He is also the author of a unique life transformation program called Coherence Healing.
#  - Author Overview: Dr. Joe Dispenza is a professor of neurochemistry and neuroscience, lecturer, and business consultant. He is also the author of a unique life transformation program called Coherence Healing.
#  - Learning items: ['About the quantum field', 'How your brain works', 'The power of meditation', 'About the higher mind', 'How to change your habits']
#  - Categories: ['Self-Growth']
#  - AI Categories: ['Spirituality', 'Self-Growth', 'Happiness']
#  - AI Reasoning Steps: ['The book focuses on changing oneself and creating a new reality, which aligns with themes of personal transformation.', 'It discusses concepts like the quantum field and the workings of the brain, indicating a scientific approach to self-improvement.', 'Meditation is highlighted as a key technique, which is often associated with spirituality and self-growth.', 'The author, Dr. Joe Dispenza, has a background in neuroscience, suggesting a blend of science and personal development.', "The overall theme of the book is about breaking habits and changing one's mindset, which fits well within the self-growth category."]
#
#
# Book (idx=758)
#  - Title: "The Six Pillars of Self-Esteem"
#  - Author: Nathaniel Branden
#  - Overview: What’s inside Explore the foundation of personal growth and unlock your success potential. Arm yourself with six transformative principles to heal and elevate your self-perception.You’ll learn • How conscious living fuels your inner power • The transformative magic of self-acceptance • Why owning your actions reshapes your reality • The strength in voicing your true self About the author Nathaniel Branden was a Canadian-American psychotherapist and writer renowned for his work on the psychology of self-esteem.
#  - Author Overview: Nathaniel Branden was a Canadian-American psychotherapist and writer renowned for his work on the psychology of self-esteem.
#  - Learning items: ['How conscious living fuels your inner power', 'The transformative magic of self-acceptance', 'Why owning your actions reshapes your reality', 'The strength in voicing your true self']
#  - Categories: ['Self-Growth']
#  - AI Categories: ['Self-Growth', 'Happiness']
#  - AI Reasoning Steps: ['The book focuses on self-esteem, which is a key aspect of personal development and self-improvement.', 'The overview mentions principles that help in personal growth, indicating a focus on self-growth and self-awareness.', "The key learning items emphasize self-acceptance, conscious living, and owning one's actions, all of which are central themes in self-growth literature.", "The author, Nathaniel Branden, is known for his work in psychology related to self-esteem, further reinforcing the book's alignment with self-growth themes."]
#
#
# Book (idx=1334)
#  - Title: "The Code of the Extraordinary Mind: 10 Unconventional Laws to Redefine Your Life and Succeed On Your Own Terms"
#  - Author: Vishen Lakhiani
#  - Overview: What’s inside Find out how to evaluate and change the principles you live by. Discover how your culture shapes you, and learn to take back control.You’ll learn • Whether the choices you’re making are yours • How the rules we live by are messing us up • What it takes to rewire your brain • How to love yourself • Life hacks to find your purpose About the author Vishen Lakhiani is a Malaysian entrepreneur, motivational speaker, and author. He founded Mindvalley, a personal growth platform with ten million students worldwide.
#  - Author Overview: Vishen Lakhiani is a Malaysian entrepreneur, motivational speaker, and author. He founded Mindvalley, a personal growth platform with ten million students worldwide.
#  - Learning items: ['Whether the choices you’re making are yours', 'How the rules we live by are messing us up', 'What it takes to rewire your brain', 'How to love yourself', 'Life hacks to find your purpose']
#  - Categories: ['Health', 'Self-Growth']
#  - AI Categories: ['Self-Growth', 'Happiness']
#  - AI Reasoning Steps: ['The book focuses on personal development and self-improvement, which suggests a connection to self-growth.', 'It discusses evaluating and changing personal principles, indicating a focus on self-awareness and personal transformation.', 'The mention of rewiring the brain and finding purpose aligns with themes of happiness and fulfillment in life.', "The author's background as a motivational speaker and founder of a personal growth platform reinforces the idea of self-growth and happiness as central themes.", 'The content emphasizes unconventional laws and life hacks, which are often associated with self-help and personal development genres.']
#
#
# Book (idx=787)
#  - Title: "Wired to Create: Unraveling the Mysteries of the Creative Mind"
#  - Author: Scott Barry Kaufman, PhD, Carolyn Gregoire
#  - Overview: What’s inside Curious about the spark behind your creativity? This piece examines key influences on your creative processes and provides practical insights to enrich your personal and professional life.You’ll learn • How to inspire creativity through play • What is the role of risk in innovation • Why adversity fuels art • How the environment shapes ideas About the author Motivated by what makes highly creative people different, Kaufman and Gregoire teamed up to delve into the messy minds of creatives. Their focus on the nature of human creativity unearthed fascinating details about what makes us tick.
#  - Author Overview: Motivated by what makes highly creative people different, Kaufman and Gregoire teamed up to delve into the messy minds of creatives. Their focus on the nature of human creativity unearthed fascinating details about what makes us tick.
#  - Learning items: ['How to inspire creativity through play', 'What is the role of risk in innovation', 'Why adversity fuels art', 'How the environment shapes ideas']
#  - Categories: ['Self-Growth']
#  - AI Categories: ['Self-Growth', 'Happiness', 'Business & Career', 'Productivity']
#  - AI Reasoning Steps: ['The book focuses on creativity, which is a key aspect of personal development and self-expression.', 'It discusses how to inspire creativity, which aligns with self-growth and personal development themes.', 'The authors explore the role of risk in innovation, which can relate to business and career development.', 'The book also touches on how adversity fuels art, indicating a deeper understanding of human experiences and emotions, which can connect to happiness and self-growth.', "The environment's influence on ideas suggests a connection to society and technology, but it is more about personal creativity than societal structures.", 'Overall, the themes of creativity, personal development, and the psychological aspects of innovation are central to the book.']

# %% [markdown]
# JUSTIFIED — AI was right to set Happiness category
#
#  - 637 — just *JUSTIFIED*
#  - 346 — *JUSTIFIED*
#  - 758 — *PROBABLY JUSTIFIED*
#  - 1334 — Considering everyting, it's *JUSTIFIED*
#  - 787 — The book seems to be about everything, frankly. *AMBIGUOUS*
#
# Conclusion
#  - Overall, again, AI seems right setting Happiness category when humans don't.

# %% [markdown]
# Finally, as we've seen fiction is the least used category. Let's see the summaries that have been attributed to Fiction.

# %%
show_books(df_books[df_books['categories'].apply(lambda l: 'Fiction' in l) | df_books['pred_categories'].apply(lambda l: 'Fiction' in l)])
# Out:
# Book (idx=244)
#  - Title: "The Last Wish: Introducing the Witcher"
#  - Author: Andrzej Sapkowski
#  - Overview: What’s inside Dive into a world where magic, morality, and might entwine. By the end, unravel destiny's intricate knit.You’ll learn • How actions transcend words • Love's transformative power • Navigating life's moral mazes • The weight of destiny and choices About the author Andrzej Sapkowski is a celebrated Polish fantasy writer. His storytelling has garnered international acclaim, including the World Fantasy Award for Lifetime Achievement, and enchanted readers worldwide.
#  - Author Overview: Andrzej Sapkowski is a celebrated Polish fantasy writer. His storytelling has garnered international acclaim, including the World Fantasy Award for Lifetime Achievement, and enchanted readers worldwide.
#  - Learning items: ['How actions transcend words', "Love's transformative power", "Navigating life's moral mazes", 'The weight of destiny and choices']
#  - Categories: ['Fiction']
#  - AI Categories: ['Fiction', 'Love & Sex']
#  - AI Reasoning Steps: ["The book is titled 'The Last Wish: Introducing the Witcher', indicating it is likely a work of fiction, specifically in the fantasy genre.", 'The overview mentions themes such as magic, morality, and destiny, which are common in fantasy literature.', 'The key learning items focus on moral choices, love, and the consequences of actions, suggesting a deeper exploration of human experiences and relationships.', "Given the themes of love and moral dilemmas, the categories 'Love & Sex' and 'Society & Tech' could be relevant, but 'Society & Tech' does not fit the fantasy context.", "The book does not focus on personal growth or self-help, so categories like 'Self-Growth', 'Happiness', or 'Leadership' are not applicable.", 'The author is a celebrated fantasy writer, which reinforces the categorization towards fiction rather than any non-fiction categories.', "Overall, the primary category that fits best is 'Fiction', with a secondary focus on 'Love & Sex' due to the exploration of love's transformative power."]
#
#
# Book (idx=310)
#  - Title: "Craft in the Real World: Rethinking Fiction Writing and Workshopping"
#  - Author: Matthew Salesses
#  - Overview: What’s inside Discover how to fuse reality with fantasy to revolutionize your writing. Gain insights into creating diverse narratives that resonate with a global audience.You’ll learn • Why diversity reshapes craft • How culture molds stories • Secrets of engaging workshops • The truth behind character creation About the author Matthew Salesses is a novelist and speaker who believes that writers in the real world should be the authors of change; they need to talk about their reality and value their audience.
#  - Author Overview: Matthew Salesses is a novelist and speaker who believes that writers in the real world should be the authors of change; they need to talk about their reality and value their audience.
#  - Learning items: ['Why diversity reshapes craft', 'How culture molds stories', 'Secrets of engaging workshops', 'The truth behind character creation']
#  - Categories: ['Business & Career', 'Society & Tech']
#  - AI Categories: ['Fiction']
#  - AI Reasoning Steps: ["The book focuses on fiction writing and workshopping, which suggests a strong connection to the 'Fiction' category.", 'The author emphasizes the importance of diversity in storytelling, which aligns with societal themes, but does not fit neatly into the predefined categories.', "The book discusses how culture influences stories, which could relate to 'Society & Tech', but again, it is more about the craft of writing than societal issues directly.", "The key learning items focus on writing techniques and character creation, which are specific to the craft of writing, reinforcing the relevance of the 'Fiction' category.", "The book does not address themes related to personal growth, business, or other categories in the predefined list, making 'Fiction' the most fitting category."]
#
#
# Book (idx=327)
#  - Title: "1984"
#  - Author: George Orwell
#  - Overview: What’s inside Peek behind the curtain of a fully controlled society and grasp the essential value of individual freedom. Equip yourself with tactics to sift through the fog of propaganda and misinformation.You’ll learn • Why skepticism is your shield against tyranny • How propaganda shapes your reality • The unseen cost of total obedience • Orwell's warnings for our digital age About the author George Orwell was a novelist, essayist, and critic known for his acute awareness of social injustices. He opposed totalitarianism and supported democratic socialism. His works, like '1984' and 'Animal Farm,' remain influential.
#  - Author Overview: George Orwell was a novelist, essayist, and critic known for his acute awareness of social injustices. He opposed totalitarianism and supported democratic socialism. His works, like '1984' and 'Animal Farm,' remain influential.
#  - Learning items: ['Why skepticism is your shield against tyranny', 'How propaganda shapes your reality', 'The unseen cost of total obedience', "Orwell's warnings for our digital age"]
#  - Categories: ['Fiction']
#  - AI Categories: ['Fiction', 'Society & Tech']
#  - AI Reasoning Steps: ["The book '1984' is a work of fiction that explores themes of totalitarianism and individual freedom.", 'The author, George Orwell, is known for his critiques of social injustices and totalitarian regimes, which aligns with societal themes.', "The key learning items focus on skepticism against tyranny, the impact of propaganda, and the cost of obedience, all of which relate to societal issues and technology's role in shaping reality.", "Given the focus on societal control and the implications of technology in the modern age, the category 'Society & Tech' is highly relevant."]
#
#
# Book (idx=435)
#  - Title: "Call of the Wild"
#  - Author: Jack London
#  - Overview: What’s inside Dive into the gripping story of survival and transformation. Explore themes that resonate with your own journey of resilience and self-discovery.You’ll learn • Why loyalty is more than a human trait • About the power of instincts in life's toughest moments • What true leadership looks like in the wild • How to discover yourself against all odds About the author Jack London was an iconic American novelist, journalist, and social activist known for his captivating adventure tales. His works include "White Fang" and "The Sea-Wolf."
#  - Author Overview: Jack London was an iconic American novelist, journalist, and social activist known for his captivating adventure tales. His works include "White Fang" and "The Sea-Wolf."
#  - Learning items: ['Why loyalty is more than a human trait', "About the power of instincts in life's toughest moments", 'What true leadership looks like in the wild', 'How to discover yourself against all odds']
#  - Categories: ['Fiction']
#  - AI Categories: ['Fiction', 'Self-Growth', 'Leadership']
#  - AI Reasoning Steps: ["The book 'Call of the Wild' is a work of fiction, as it tells a story rather than presenting factual information or instructional content.", "The themes of survival and transformation suggest a focus on personal growth and resilience, which aligns with the category of 'Self-Growth'.", "The exploration of loyalty, instincts, and leadership in challenging situations indicates a strong connection to the category of 'Leadership'.", "The author's background as a novelist and the nature of the story suggest that the primary focus is on narrative and character development, reinforcing the 'Fiction' category."]
#
#
# Book (idx=559)
#  - Title: "The Wind-Up Bird Chronicle"
#  - Author: Haruki Murakami
#  - Overview: What’s inside Dive into a world where the mundane meets the mystical. Explore life’s unpredictable turns through an enigmatic tale.You’ll learn • How crises redefine us • The impact of the unseen • Secrets behind lasting bonds • The power of introspective solitude About the author Haruki Murakami stands as a cornerstone in modern literature, weaving the ordinary with the extraordinary. Globally acclaimed, his narratives navigate the complex layers of human psyche and life’s subtleties.
#  - Author Overview: Haruki Murakami stands as a cornerstone in modern literature, weaving the ordinary with the extraordinary. Globally acclaimed, his narratives navigate the complex layers of human psyche and life’s subtleties.
#  - Learning items: ['How crises redefine us', 'The impact of the unseen', 'Secrets behind lasting bonds', 'The power of introspective solitude']
#  - Categories: ['Fiction']
#  - AI Categories: ['Fiction', 'Self-Growth', 'Spirituality']
#  - AI Reasoning Steps: ["The book is a work of fiction, as indicated by its narrative style and the author's classification as a modern literature writer.", 'The themes of crises and introspection suggest a focus on personal growth and self-discovery, which aligns with the category of Self-Growth.', 'The exploration of human relationships and bonds points towards themes of Love & Sex, as well as Family, but the primary focus seems to be on the individual experience rather than family dynamics.', 'The mystical elements and the impact of the unseen suggest a connection to Spirituality, as the book delves into deeper existential themes.', "Overall, the book's primary focus is on the human experience, making Fiction the most fitting category, followed by Self-Growth and Spirituality."]
#
#
# Book (idx=615)
#  - Title: "Three Women"
#  - Author: Lisa Taddeo
#  - Overview: What’s inside Explore the heartfelt stories of three women as they navigate desire and challenges. Gain insights into overcoming life's complexities and embracing your own path.You’ll learn • How societal norms shape female desire • About the inner workings of different marriages • Ways to challenge gender stereotypes • About the impact of trauma on relationships About the author Lisa Taddeo is an acclaimed author and journalist, recognized for her in-depth and revealing narratives about human nature and relationships.
#  - Author Overview: Lisa Taddeo is an acclaimed author and journalist, recognized for her in-depth and revealing narratives about human nature and relationships.
#  - Learning items: ['How societal norms shape female desire', 'About the inner workings of different marriages', 'Ways to challenge gender stereotypes', 'About the impact of trauma on relationships']
#  - Categories: ['Personalities']
#  - AI Categories: ['Fiction', 'Love & Sex', 'Self-Growth']
#  - AI Reasoning Steps: ["The book focuses on the stories of three women, indicating a strong narrative element, which suggests it falls under 'Fiction'.", "The themes of desire, societal norms, and gender stereotypes indicate a focus on relationships and personal experiences, which aligns with 'Love & Sex'.", "The exploration of trauma and its impact on relationships suggests a deeper psychological aspect, which could also relate to 'Self-Growth'.", "The mention of societal norms and challenges faced by women indicates a broader commentary on society, which could relate to 'Society & Tech'.", "However, the primary focus seems to be on personal relationships and experiences rather than societal technology, so 'Society & Tech' may not be as relevant as the other categories."]
#
#
# Book (idx=688)
#  - Title: "How Ukrainian Fiction Teaches Courage"
#  - Author: Maria Blindiuk
#  - Overview: What’s inside Discover the secret to Ukrainian courage hidden in historical Ukrainian fiction.You’ll learn • How to persevere • Insights into Ukrainian philosophy • Fun methods of rewriting a classic • About the relevance of Ukrainian writers • Ukrainian Fiction 101 About the author Journalist and literary critic Maria Blindiuk has covered Ukrainian culture for various media outlets, including Suspilne Kultura, Chytomo, and LiRoom, since 2018.
#  - Author Overview: Journalist and literary critic Maria Blindiuk has covered Ukrainian culture for various media outlets, including Suspilne Kultura, Chytomo, and LiRoom, since 2018.
#  - Learning items: ['How to persevere', 'Insights into Ukrainian philosophy', 'Fun methods of rewriting a classic', 'About the relevance of Ukrainian writers', 'Ukrainian Fiction 101']
#  - Categories: ['Fiction']
#  - AI Categories: ['Self-Growth']
#  - AI Reasoning Steps: ['The book focuses on Ukrainian fiction and its teachings about courage, which suggests a connection to personal development and resilience.', 'The key learning items include perseverance and insights into philosophy, indicating a focus on self-growth and personal development.', 'The mention of rewriting classics and the relevance of Ukrainian writers suggests a cultural and societal context, but the primary focus remains on personal insights and growth.', "Given the emphasis on courage and perseverance, the most fitting category from the predefined list is 'Self-Growth'.", "While there are elements of society and culture, the book does not fit neatly into categories like 'Society & Tech' or 'Personalities', as it is more about individual learning and growth."]
#
#
# Book (idx=714)
#  - Title: "Як український фікшн учить сміливості"
#  - Author: Марія Бліндюк
#  - Overview: What’s inside Відкрийте для себе історію української художньої літератури, щоби дізнатися секрет сміливості українців.You’ll learn • Як навчитися не здаватися • Інсайти української філософії • Як переписати класику, щоби вона стала веселою • Актуальність українських письменників • З чого почати знайомство з українською художньою літературою About the author Журналістка й літкритикиня Марія Бліндюк із 2018 року пише про український культурний ринок для різних медіа, зокрема “Суспільне Культура”, “Читомо”, “Лірум”.
#  - Author Overview: Журналістка й літкритикиня Марія Бліндюк із 2018 року пише про український культурний ринок для різних медіа, зокрема “Суспільне Культура”, “Читомо”, “Лірум”.
#  - Learning items: ['Як навчитися не здаватися', 'Інсайти української філософії', 'Як переписати класику, щоби вона стала веселою', 'Актуальність українських письменників', 'З чого почати знайомство з українською художньою літературою']
#  - Categories: ['Fiction']
#  - AI Categories: ['Self-Growth']
#  - AI Reasoning Steps: ['The book discusses Ukrainian fiction and its role in teaching courage, which suggests a focus on personal development and resilience.', 'The key learning items include insights on not giving up and understanding Ukrainian philosophy, indicating themes of self-growth and personal empowerment.', 'The author is a journalist and literary critic, which implies a focus on cultural and societal aspects, but the primary focus of the book is on personal insights and growth through literature.', "Given the emphasis on learning to not give up and the exploration of Ukrainian literature, the most fitting category from the predefined list is 'Self-Growth'.", 'While there are elements of societal relevance in the book, the core message aligns more closely with personal development rather than broader societal or technological themes.']
#
#
# Book (idx=932)
#  - Title: "За Перекопом є земля. Кримський роман"
#  - Author: Анастасія Левкова
#  - Overview: What’s inside Відкрийте для себе багатоманіття кримської ідентичності. Дізнайтеся про традиції кримських татар та в чому унікальність контексту Криму.You’ll learn • Що особливого в кримськотатарській культурі • Які народи співіснують у Криму • Чому кримська ідентичність складна й унікальна • Як в Україні поєднуються політичне й особисте About the author Анастасія Левкова – українська письменниця, журналістка й культурна менеджерка. Кураторка літературного конкурсу “Кримський інжир / Qırım inciri”, співупорядниця та редакторка однойменних антологій. Членкиня Українського ПЕН.
#  - Author Overview: Анастасія Левкова – українська письменниця, журналістка й культурна менеджерка. Кураторка літературного конкурсу “Кримський інжир / Qırım inciri”, співупорядниця та редакторка однойменних антологій. Членкиня Українського ПЕН.
#  - Learning items: ['Що особливого в кримськотатарській культурі', 'Які народи співіснують у Криму', 'Чому кримська ідентичність складна й унікальна', 'Як в Україні поєднуються політичне й особисте']
#  - Categories: ['Fiction', 'Society & Tech']
#  - AI Categories: ['Fiction', 'Society & Tech']
#  - AI Reasoning Steps: ['The book focuses on the diverse identity of Crimea and the unique context of Crimean Tatar culture, which suggests a strong connection to societal themes.', 'It discusses the coexistence of different peoples in Crimea, indicating a focus on social dynamics and cultural identity.', 'The mention of political and personal intersections in Ukraine further emphasizes the societal aspect of the narrative.', "Given that the book is a novel, it likely falls under the category of 'Fiction', but it also has strong elements of cultural and societal exploration.", 'The author is involved in cultural management and literature, which aligns with themes of society and identity.']
#
#
# Book (idx=1232)
#  - Title: "To Kill a Mockingbird"
#  - Author: Harper Lee
#  - Overview: What’s inside Navigate the complex moral web of a small town. Learn how innocence battles prejudice, and why empathy wins.You’ll learn • Why courage can defy prejudice • How empathy unlocks understanding • To stand up against societal wrongs • The impact of innocence on justice About the author Harper Lee, born in 1926 in Alabama, captured the essence of her own upbringing in the Pulitzer Prize-winning novel. Her keen observations of racial injustice and human complexity offer lessons on empathy and integrity.
#  - Author Overview: Harper Lee, born in 1926 in Alabama, captured the essence of her own upbringing in the Pulitzer Prize-winning novel. Her keen observations of racial injustice and human complexity offer lessons on empathy and integrity.
#  - Learning items: ['Why courage can defy prejudice', 'How empathy unlocks understanding', 'To stand up against societal wrongs', 'The impact of innocence on justice']
#  - Categories: ['Fiction']
#  - AI Categories: ['Fiction', 'Society & Tech']
#  - AI Reasoning Steps: ["The book 'To Kill a Mockingbird' is a work of fiction, as it tells a story set in a fictional small town and explores complex themes through its characters.", "The themes of racial injustice, empathy, and moral courage suggest a strong connection to societal issues, which aligns with the category of 'Society & Tech'.", "The key learning points emphasize understanding, standing up against societal wrongs, and the impact of innocence on justice, which further supports the relevance of the 'Society & Tech' category.", "While the book does touch on personal growth through empathy and moral courage, it does not fit neatly into categories like 'Self-Growth' or 'Happiness' as its primary focus is on societal issues rather than individual development.", "Given that the book is a classic piece of literature that addresses significant social themes, the most fitting category is 'Fiction' alongside 'Society & Tech'."]
#
#
# Book (idx=1333)
#  - Title: "The Alchemist"
#  - Author: Paulo Coelho
#  - Overview: What’s inside Chasing dreams or seeking destiny? Follow a shepherd's remarkable odyssey to discover that the truest treasures are hidden deep within.You’ll learn • How passions shape your future • Why you should guard your dreams • Whether intuition guides your destiny • How challenges refine your purpose About the author Paulo Coelho is a celebrated author known for his profound spiritual insights. A lyrical storyteller, Coelho has touched millions worldwide, blending mysticism, wisdom, and philosophy in his works​.
#  - Author Overview: Paulo Coelho is a celebrated author known for his profound spiritual insights. A lyrical storyteller, Coelho has touched millions worldwide, blending mysticism, wisdom, and philosophy in his works​.
#  - Learning items: ['How passions shape your future', 'Why you should guard your dreams', 'Whether intuition guides your destiny', 'How challenges refine your purpose']
#  - Categories: ['Fiction']
#  - AI Categories: ['Spirituality', 'Self-Growth']
#  - AI Reasoning Steps: ["The book 'The Alchemist' focuses on a shepherd's journey to discover his personal legend, which aligns with themes of self-discovery and personal growth.", 'The key learning items emphasize the importance of passions, dreams, intuition, and challenges, all of which are central to the concept of self-growth and personal development.', 'The author, Paulo Coelho, is known for his spiritual insights, suggesting that the book also delves into spirituality and the deeper meanings of life.', "Given the themes of pursuing dreams and understanding one's purpose, 'Self-Growth' and 'Spirituality' are the most relevant categories."]
#
#
# Book (idx=1453)
#  - Title: "Walden; or, Life in the Woods"
#  - Author: Henry David Thoreau
#  - Overview: What’s inside Step into nature’s embrace that smells like a long-lost home. Find the ease and seclusion that eludes you in urban environments.You’ll learn • Why less is more in life • To find depth in solitude • How nature heals • Spring's rejuvenating power About the author Henry David Thoreau ventured into the woods to live deliberately and emerged with timeless insights. His quest for simplicity and self-reliance continues to inspire a deeper connection with the natural world.
#  - Author Overview: Henry David Thoreau ventured into the woods to live deliberately and emerged with timeless insights. His quest for simplicity and self-reliance continues to inspire a deeper connection with the natural world.
#  - Learning items: ['Why less is more in life', 'To find depth in solitude', 'How nature heals', "Spring's rejuvenating power"]
#  - Categories: ['Fiction']
#  - AI Categories: ['Home & Environment', 'Self-Growth', 'Happiness']
#  - AI Reasoning Steps: ['The book is centered around themes of nature and simplicity, which suggests a connection to the environment.', 'The author emphasizes self-reliance and personal growth through experiences in nature, indicating a focus on self-growth.', 'The key learning points highlight finding depth in solitude and the healing power of nature, which aligns with personal development and happiness.', 'The overall message of the book promotes a simpler, more deliberate way of living, which can be categorized under self-growth and happiness.']
#
#
# Book (idx=1545)
#  - Title: "The Land Behind Perekop - A Crimean Novel"
#  - Author: Anastasiia Levkova
#  - Overview: What’s inside Discover the diversity of Crimean identity. Learn about the traditions of the Crimean Tatars and the uniqueness of the Crimean context.You’ll learn • The specifics of the Crimean Tatar culture • What nations coexist in Crimea • Why Crimean identity is complex and unique • How the political and the personal combine in Ukraine About the author Anastasia Levkova is a Ukrainian writer, journalist, and cultural manager. She curated the Crimean fig / Qırım inciri literary contest and edited the anthologies of the same name.
#  - Author Overview: Anastasia Levkova is a Ukrainian writer, journalist, and cultural manager. She curated the Crimean fig / Qırım inciri literary contest and edited the anthologies of the same name.
#  - Learning items: ['The specifics of the Crimean Tatar culture', 'What nations coexist in Crimea', 'Why Crimean identity is complex and unique', 'How the political and the personal combine in Ukraine']
#  - Categories: ['Fiction', 'Society & Tech']
#  - AI Categories: ['Fiction', 'Society & Tech']
#  - AI Reasoning Steps: ["The book is titled 'The Land Behind Perekop - A Crimean Novel', indicating it is a work of fiction.", 'The overview discusses the diversity of Crimean identity and the traditions of the Crimean Tatars, which suggests a focus on cultural and societal themes.', 'Key learning items include specifics of Crimean Tatar culture and the coexistence of nations in Crimea, which aligns with societal issues and cultural identity.', 'The author, Anastasiia Levkova, is a Ukrainian writer and journalist, which further emphasizes the cultural and societal context of the book.', "Given the focus on identity, culture, and the political landscape in Ukraine, the most fitting category from the predefined list is 'Society & Tech', as it encompasses societal themes."]

# %%
import matplotlib.pyplot as plt
import numpy as np

def compute_iou(set1, set2):
    """Compute Intersection over Union (IoU) for two sets."""
    intersection = len(set1 & set2)
    union = len(set1 | set2)
    return intersection / union if union > 0 else 0

def plot_iou_distribution(df, col1, col2, title='IoU Distribution'):
    """
    Computes IoU for each row in df and plots the distribution with mean.
    
    :param df: Pandas DataFrame
    :param col1: First column (manual categories)
    :param col2: Second column (predicted categories)
    :param title: Title of the plot
    """
    # Compute IoUs for each row
    iou_scores = [
        compute_iou(set(row[col1]), set(row[col2])) 
        for _, row in df.iterrows()
    ]

    # Compute mean IoU
    mean_iou = np.mean(iou_scores)

    # Plot histogram
    plt.figure(figsize=(8, 5))
    plt.hist(iou_scores, color='skyblue', edgecolor='black', alpha=0.7, label='IoU Distribution')

    # Add vertical line for mean
    plt.axvline(mean_iou, color='red', linestyle='dashed', linewidth=2, label=f'Mean IoU: {mean_iou:.2f}')

    # Labels and formatting
    plt.xlabel('IoU Score')
    plt.ylabel('Frequency')
    plt.title(title)
    plt.xticks(np.linspace(0, 1, 11))
    plt.legend()
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.show()

# Usage
plot_iou_distribution(df_books, 'categories', 'pred_categories')

# %%
import numpy as np
from collections import Counter

def compute_conditional_probabilities(df, col1, col2):
    """
    Computes P(col2 | col1) and P(col1 | col2) along with their micro and macro averages.
    
    :param df: Pandas DataFrame
    :param col1: First column (manual categories)
    :param col2: Second column (predicted categories)
    :return: Dictionary with computed micro & macro averages
    """
    # Count occurrences for conditional probabilities
    count_col1 = Counter(cat for sublist in df[col1] for cat in sublist)
    count_col2_given_col1 = Counter(cat for sublist, sublist_col1 in zip(df[col2], df[col1]) for cat in sublist if cat in sublist_col1)

    count_col2 = Counter(cat for sublist in df[col2] for cat in sublist)
    count_col1_given_col2 = Counter(cat for sublist, sublist_col2 in zip(df[col1], df[col2]) for cat in sublist if cat in sublist_col2)

    # Compute conditional probabilities
    prob_col2_given_col1 = {cat: count_col2_given_col1[cat] / count_col1[cat] for cat in count_col1 if count_col1[cat] > 0}
    prob_col1_given_col2 = {cat: count_col1_given_col2[cat] / count_col2[cat] for cat in count_col2 if count_col2[cat] > 0}

    # Compute macro (simple mean) and micro (weighted by occurrences) averages
    macro_avg_col2_given_col1 = np.mean(list(prob_col2_given_col1.values()))
    macro_avg_col1_given_col2 = np.mean(list(prob_col1_given_col2.values()))

    micro_avg_col2_given_col1 = sum(count_col1[cat] * prob_col2_given_col1.get(cat, 0) for cat in count_col1) / sum(count_col1.values())
    micro_avg_col1_given_col2 = sum(count_col2[cat] * prob_col1_given_col2.get(cat, 0) for cat in count_col2) / sum(count_col2.values())

    # Print results
    print(f"Micro-average P(AI | Manual): {micro_avg_col2_given_col1:.4f}")
    print(f"Macro-average P(AI | Manual): {macro_avg_col2_given_col1:.4f}")
    print(f"Micro-average P(Manual | AI): {micro_avg_col1_given_col2:.4f}")
    print(f"Macro-average P(Manual | AI): {macro_avg_col1_given_col2:.4f}")

# Usage
compute_conditional_probabilities(df_books, 'categories', 'pred_categories')
# Out:
# Micro-average P(AI | Manual): 0.7274
# Macro-average P(AI | Manual): 0.6687
# Micro-average P(Manual | AI): 0.4443
# Macro-average P(Manual | AI): 0.5324

# %% [markdown]
# ## More Examples

# %%
show_books(df_books.sample(15, random_state=42))
# Out:
# Book (idx=1791)
#  - Title: "Modern Romance"
#  - Author: Aziz Ansari, Eric Klinenberg, PhD
#  - Overview: What’s inside Find out how the image of love has changed over the past century and realize that there is no universal norm for romantic relationships.You’ll learn • The secrets of grandma's happy marriage • About dating in different countries • The impact of social media on personal life • How to meet your one and only About the author Aziz Ansari is a comedian and writer included in the 2016 Time 100 list of most influential people. Eric Klinenberg is a professor of Social Science and Director of the Institute for Public Knowledge at New York University.
#  - Author Overview: Aziz Ansari is a comedian and writer included in the 2016 Time 100 list of most influential people. Eric Klinenberg is a professor of Social Science and Director of the Institute for Public Knowledge at New York University.
#  - Learning items: ["The secrets of grandma's happy marriage", 'About dating in different countries', 'The impact of social media on personal life', 'How to meet your one and only']
#  - Categories: ['Love & Sex']
#  - AI Categories: ['Love & Sex', 'Society & Tech']
#  - AI Reasoning Steps: ['The book discusses the evolution of romantic relationships over time, indicating a focus on love and relationships.', 'It includes insights into dating practices in different cultures, which aligns with themes of love and societal norms.', 'The impact of social media on personal relationships suggests a connection to society and technology, but the primary focus remains on romantic relationships.', "The key learning items emphasize aspects of love, dating, and relationships, reinforcing the relevance of the 'Love & Sex' category.", 'While there are elements of societal analysis, the core subject matter is centered around love and romance rather than broader societal issues.']
#
#
# Book (idx=322)
#  - Title: "Boundaries: When to Say Yes, How to Say No to Take Control of Your Life"
#  - Author: Dr. Henry Cloud, Dr. John Townsend
#  - Overview: What’s inside Discover the necessity and power of setting clear boundaries. Enhance your relationships by safeguarding your personal space.You’ll learn • How to keep others from crossing your boundaries • Why you should set personal limits • How to teach children to establish frontiers • That saying no is not selfish About the author Dr. Henry Cloud and Dr. John Townsend are licensed psychologists, best-selling authors, and popular speakers. Their work empowers people to develop self-awareness and cultivate fulfilling relationships.
#  - Author Overview: Dr. Henry Cloud and Dr. John Townsend are licensed psychologists, best-selling authors, and popular speakers. Their work empowers people to develop self-awareness and cultivate fulfilling relationships.
#  - Learning items: ['How to keep others from crossing your boundaries', 'Why you should set personal limits', 'How to teach children to establish frontiers', 'That saying no is not selfish']
#  - Categories: ['Self-Growth', 'Love & Sex']
#  - AI Categories: ['Self-Growth', 'Family', 'Happiness']
#  - AI Reasoning Steps: ['The book focuses on the concept of boundaries, which is primarily about personal development and self-awareness.', 'It discusses how to set limits in relationships, which aligns with themes of self-growth and personal empowerment.', 'The authors are psychologists, indicating a professional and psychological approach to the subject matter, further supporting the self-growth category.', 'The key learning items emphasize personal limits and teaching boundaries to children, which relates to family dynamics and personal development.', 'The overall theme of the book is about enhancing relationships and personal space, which can also connect to happiness and self-growth.']
#
#
# Book (idx=1033)
#  - Title: "The White Coat Investor: A Doctor’s Guide to Personal Finance and Investing"
#  - Author: James M. Dahle, MD
#  - Overview: What’s inside Struggling with the financial pressures of being a doctor? This handbook breaks down doctors' economic challenges and provides practical, actionable advice for financial success.You’ll learn • Why docs struggle financially • How to thrive on a doctor's salary • Keys to early financial stability • How to avoid common financial traps About the author James M. Dahle, MD, is an emergency physician and the founder of "The White Coat Investor," a popular personal finance website specifically helping medical professionals manage and grow their wealth more effectively.
#  - Author Overview: James M. Dahle, MD, is an emergency physician and the founder of "The White Coat Investor," a popular personal finance website specifically helping medical professionals manage and grow their wealth more effectively.
#  - Learning items: ['Why docs struggle financially', "How to thrive on a doctor's salary", 'Keys to early financial stability', 'How to avoid common financial traps']
#  - Categories: ['Money & Investments']
#  - AI Categories: ['Money & Investments', 'Business & Career']
#  - AI Reasoning Steps: ['The book is focused on personal finance, specifically tailored for doctors, which indicates a strong connection to financial management and investment strategies.', 'The author, James M. Dahle, MD, is an expert in the field of finance for medical professionals, suggesting that the content is credible and specialized.', 'The key learning items highlight financial challenges faced by doctors and provide actionable advice for financial stability and success, reinforcing the theme of money management.', "Given the focus on financial advice and investment strategies, the category 'Money & Investments' is highly relevant.", "While the book may touch on aspects of career and professional life, the primary focus remains on financial education rather than broader business concepts, making 'Business & Career' less relevant than 'Money & Investments'.", 'The book does not address themes related to fiction, spirituality, sports, happiness, self-growth, personalities, productivity, society, leadership, family, love, or health in a direct manner, which further narrows down the relevant categories.']
#
#
# Book (idx=162)
#  - Title: "Made to Stick: Why Some Ideas Survive and Others Die"
#  - Author: Chip Heath, Dan Heath
#  - Overview: What’s inside Pioneer the art of memorable idea curation. Craft messages that engage and inspire, leaving a lasting impression beyond the ordinary.You’ll learn • How simplicity powers understanding • Crafting stories that motivate action • Keys to boosting message credibility • Engaging emotions to drive care • The magic of unexpected twists About the author Chip Heath, a Stanford professor, and his brother, bestselling author, and professor, Dan Heath, have co-authored four NYT bestsellers. Their work bridges academic insight and real-world application.
#  - Author Overview: Chip Heath, a Stanford professor, and his brother, bestselling author, and professor, Dan Heath, have co-authored four NYT bestsellers. Their work bridges academic insight and real-world application.
#  - Learning items: ['How simplicity powers understanding', 'Crafting stories that motivate action', 'Keys to boosting message credibility', 'Engaging emotions to drive care', 'The magic of unexpected twists']
#  - Categories: ['Business & Career']
#  - AI Categories: ['Business & Career', 'Productivity', 'Leadership']
#  - AI Reasoning Steps: ['The book focuses on how to make ideas memorable and impactful, which relates to communication and persuasion.', 'The key learning items emphasize crafting messages, engaging emotions, and boosting credibility, all of which are essential skills in business and career contexts.', 'The authors are well-known for their work in applying academic insights to real-world situations, particularly in the realm of business and communication.', 'Given the focus on effective messaging and idea curation, the book aligns closely with themes of productivity and leadership, as these skills are crucial for effective leaders and productive individuals.']
#
#
# Book (idx=1273)
#  - Title: "The Pivot Year"
#  - Author: Brianna Wiest
#  - Overview: What’s inside Imagine this year becoming your turning point. Discover a roadmap to align your life with purpose and inner peace, challenging you to redefine happiness and success.You’ll learn • That self-compassion fuels lasting transformation • What aligns your life with authentic happiness • How inner peace shapes your outer world • Why letting go creates space for growth About the author Brianna Wiest is a prolific author and thought leader and is celebrated for her work on mindfulness and self-improvement. With a background in psychology, she inspires readers worldwide to embrace intentional living.
#  - Author Overview: Brianna Wiest is a prolific author and thought leader and is celebrated for her work on mindfulness and self-improvement. With a background in psychology, she inspires readers worldwide to embrace intentional living.
#  - Learning items: ['That self-compassion fuels lasting transformation', 'What aligns your life with authentic happiness', 'How inner peace shapes your outer world', 'Why letting go creates space for growth']
#  - Categories: ['Happiness', 'Business & Career', 'Self-Growth']
#  - AI Categories: ['Happiness', 'Self-Growth', 'Spirituality']
#  - AI Reasoning Steps: ["The book focuses on personal transformation and aligning one's life with purpose, which suggests a focus on self-improvement.", 'The key learning items emphasize self-compassion, authentic happiness, and inner peace, all of which are central themes in self-growth and happiness.', "The author's background in psychology and emphasis on mindfulness indicates a strong connection to self-growth and spirituality.", 'The overall theme of the book is about redefining happiness and success, which aligns closely with the category of Happiness.', 'Given the focus on personal development and intentional living, Self-Growth is also a fitting category.']
#
#
# Book (idx=70)
#  - Title: "168 Hours: You Have More Time Than You Think"
#  - Author: Laura Vanderkam
#  - Overview: What’s inside Learn to tackle your time in a more productive and fulfilling manner. Discover your time-wasting habits and improve your routine.You’ll learn • About things that keep you from progress • Why you’re afraid to evolve • How to plan your week to balance life and work • To achieve goals you’ve had for a while About the author Laura Vanderkam is an American journalist and writer on productivity, self-development, and time management. Her sphere of expertise also includes work-life balance for women based on her journalistic experience.
#  - Author Overview: Laura Vanderkam is an American journalist and writer on productivity, self-development, and time management. Her sphere of expertise also includes work-life balance for women based on her journalistic experience.
#  - Learning items: ['About things that keep you from progress', 'Why you’re afraid to evolve', 'How to plan your week to balance life and work', 'To achieve goals you’ve had for a while']
#  - Categories: ['Productivity']
#  - AI Categories: ['Self-Growth', 'Productivity']
#  - AI Reasoning Steps: ['The book focuses on time management and productivity, which are key themes in self-development.', 'The author, Laura Vanderkam, specializes in productivity and self-growth, indicating that the book aligns with these areas.', 'The key learning items emphasize improving routines, achieving goals, and balancing life and work, all of which are aspects of self-growth and productivity.', "Given the content and focus on personal improvement and effective time management, the categories of 'Self-Growth' and 'Productivity' are the most relevant."]
#
#
# Book (idx=247)
#  - Title: "The First 20 Hours: How to Learn Anything . . . Fast!"
#  - Author: Josh Kaufman
#  - Overview: What’s inside Dive deep into rapid skill acquisition, transforming the way you approach learning. Reveal methods that will elevate you from novice to knowledgeable in record time.You’ll learn • Why curiosity is your best learning asset • How microtasks lead to macro mastery • A mystic connection between yoga and mindfulness • The art behind rapid touch typing About the author Josh Kaufman is a self-made business expert and author of several personal development and entrepreneurship books.
#  - Author Overview: Josh Kaufman is a self-made business expert and author of several personal development and entrepreneurship books.
#  - Learning items: ['Why curiosity is your best learning asset', 'How microtasks lead to macro mastery', 'A mystic connection between yoga and mindfulness', 'The art behind rapid touch typing']
#  - Categories: ['Productivity']
#  - AI Categories: ['Self-Growth', 'Productivity']
#  - AI Reasoning Steps: ['The book focuses on rapid skill acquisition, which suggests a focus on personal development and learning strategies.', 'The author, Josh Kaufman, is known for writing about personal development and entrepreneurship, indicating that the book likely falls into the self-growth category.', 'Key learning items include curiosity as a learning asset and microtasks leading to mastery, which are concepts related to self-improvement and productivity.', 'The mention of yoga and mindfulness connects to personal well-being, but it is more about learning techniques than spirituality in a traditional sense.', 'Overall, the themes of learning quickly and effectively align closely with self-growth and productivity.']
#
#
# Book (idx=736)
#  - Title: "Win Every Argument: The Art of Debating, Persuading, and Public Speaking"
#  - Author: Mehdi Hasan
#  - Overview: What’s inside Learn to win every argument with intelligence, confidence, and grace — whether it's a casual conversation turned into heated discussion or an impromptu debate in front of colleagues.You’ll learn • The value of arguments • Winning strategies for any dispute • Techniques to trap your opponent • How to prepare for your victory About the author Mehdi Hasan is an award-winning journalist, broadcaster, and host of The Mehdi Hasan Show. Formerly a columnist and podcaster at the Intercept, he also served as a presenter at Al Jazeera English.
#  - Author Overview: Mehdi Hasan is an award-winning journalist, broadcaster, and host of The Mehdi Hasan Show. Formerly a columnist and podcaster at the Intercept, he also served as a presenter at Al Jazeera English.
#  - Learning items: ['The value of arguments', 'Winning strategies for any dispute', 'Techniques to trap your opponent', 'How to prepare for your victory']
#  - Categories: ['Negotiation']
#  - AI Categories: ['Self-Growth', 'Negotiation']
#  - AI Reasoning Steps: ['The book focuses on debating, persuading, and public speaking, which are skills related to communication and argumentation.', 'The key learning items emphasize strategies for winning arguments and preparing for discussions, indicating a focus on personal development in communication.', 'The author, Mehdi Hasan, is a journalist and broadcaster, suggesting that the book may also touch on aspects of media and public discourse.', "Given the emphasis on winning arguments and techniques for effective communication, the categories of 'Self-Growth' and 'Negotiation' are particularly relevant."]
#
#
# Book (idx=1518)
#  - Title: "The Wisdom of Sundays: Life-Changing Insights from Super Soul Conversations"
#  - Author: Oprah Winfrey
#  - Overview: What’s inside Did you ever feel stuck in your personal growth? Water your inner blossom with this collection of profound dialogues that illuminate pathways to a more fulfilled life.You’ll learn • How beliefs shape the truth • Why reflect on spirituality • What's the power of gratitude? • The true power of intentions • Why you should trust your intuition About the author Oprah Winfrey is a celebrated media mogul and philanthropist who has profoundly impacted global media with her distinctive blend of empathic broadcasting and transformative discourse.
#  - Author Overview: Oprah Winfrey is a celebrated media mogul and philanthropist who has profoundly impacted global media with her distinctive blend of empathic broadcasting and transformative discourse.
#  - Learning items: ['How beliefs shape the truth', 'Why reflect on spirituality', "What's the power of gratitude?", 'The true power of intentions', 'Why you should trust your intuition']
#  - Categories: ['Spirituality']
#  - AI Categories: ['Spirituality', 'Self-Growth']
#  - AI Reasoning Steps: ['The book focuses on personal growth and insights from conversations that aim to help individuals lead more fulfilled lives.', 'Key learning items include spirituality, gratitude, intentions, and intuition, which are all closely related to self-exploration and personal development.', "The author, Oprah Winfrey, is known for her work in media that often revolves around themes of self-improvement and spirituality, further emphasizing the book's focus on these areas.", "Given the content and themes presented in the overview and key learning items, the categories of 'Spirituality' and 'Self-Growth' are the most relevant."]
#
#
# Book (idx=1006)
#  - Title: "The Parenting Map: Step-by-Step Solutions to Consciously Create the Ultimate Parent-Child Relationship"
#  - Author: Shefali Tsabary, PhD
#  - Overview: What’s inside Overcome limiting beliefs to evolve beyond ego-driven parenting, enabling your child to grow confidently and joyfully, true to their essence, free from external expectations.You’ll learn • The danger of the rescue complex • How to deal with a teenager • What's good about naughty children • Mistakes and their solutions in parenting About the author Shefali Tsabary, PhD, integrates Western psychology and Eastern philosophy as an acclaimed author, clinical psychologist, family coach, consultant, and speaker.
#  - Author Overview: Shefali Tsabary, PhD, integrates Western psychology and Eastern philosophy as an acclaimed author, clinical psychologist, family coach, consultant, and speaker.
#  - Learning items: ['The danger of the rescue complex', 'How to deal with a teenager', "What's good about naughty children", 'Mistakes and their solutions in parenting']
#  - Categories: ['Family']
#  - AI Categories: ['Family', 'Self-Growth']
#  - AI Reasoning Steps: ['The book focuses on parenting techniques and improving parent-child relationships, which suggests a strong connection to family dynamics.', 'The author discusses overcoming limiting beliefs and ego-driven parenting, indicating a focus on personal development and self-awareness in the context of parenting.', 'Key learning items include dealing with teenagers and understanding the nature of children, which further emphasizes the family aspect of the book.', 'The integration of psychology and philosophy in parenting suggests a deeper exploration of personal growth and self-awareness, aligning with self-growth themes.', "Overall, the primary focus of the book is on family relationships and parenting strategies, making 'Family' the most relevant category."]
#
#
# Book (idx=1664)
#  - Title: "Sane New World: Taming the Mind"
#  - Author: Ruby Wax
#  - Overview: What’s inside Ever feel overwhelmed by life? Arm yourself with mindfulness to oppose the stress and chaos of the modern world.You’ll learn • Why your brain resists happiness • How can mindfulness reshape your thoughts • About the mental health myths • Whether self-awareness impacts health About the author Ruby Wax is celebrated for talking honestly and with a sense of humor about her mental health battles. She uses comedy and profound psychological insight to promote mental health awareness.
#  - Author Overview: Ruby Wax is celebrated for talking honestly and with a sense of humor about her mental health battles. She uses comedy and profound psychological insight to promote mental health awareness.
#  - Learning items: ['Why your brain resists happiness', 'How can mindfulness reshape your thoughts', 'About the mental health myths', 'Whether self-awareness impacts health']
#  - Categories: ['Health', 'Spirituality']
#  - AI Categories: ['Happiness', 'Self-Growth', 'Health']
#  - AI Reasoning Steps: ['The book focuses on mental health and mindfulness, which are closely related to personal well-being.', 'The author discusses how to manage stress and chaos in life, indicating a focus on happiness and self-awareness.', "Key learning points include understanding the brain's resistance to happiness and the impact of mindfulness, which aligns with self-growth and happiness themes.", "The author's background in mental health and comedy suggests a light-hearted yet insightful approach to serious topics, reinforcing the relevance of happiness and self-growth categories."]
#
#
# Book (idx=752)
#  - Title: "Find Your Artistic Voice: The Essential Guide to Working Your Creative Magic"
#  - Author: Lisa Congdon
#  - Overview: What’s inside Crystallize your creative identity using influences from other artists. Overcome the fear of experimentation and realize the value of your original self-expression.You’ll learn • What hides the fear of a blank slate • How to transform pain into art • When inspiration turns into imitation • Why it's cool not to fit in • Ways to spark creativity About the author Lisa Congdon is a remarkable artist and illustrator who works for MoMA, Harvard University, and Chronicle Books. She blogs about daily inspiration, “Today is Going to be Awesome.”
#  - Author Overview: Lisa Congdon is a remarkable artist and illustrator who works for MoMA, Harvard University, and Chronicle Books. She blogs about daily inspiration, “Today is Going to be Awesome.”
#  - Learning items: ['What hides the fear of a blank slate', 'How to transform pain into art', 'When inspiration turns into imitation', "Why it's cool not to fit in", 'Ways to spark creativity']
#  - Categories: ['Society & Tech', 'Self-Growth', 'Sports & Fitness']
#  - AI Categories: ['Self-Growth', 'Happiness']
#  - AI Reasoning Steps: ["The book focuses on finding one's artistic voice, which suggests a strong emphasis on self-expression and creativity.", 'The key learning items include overcoming fear, transforming pain into art, and sparking creativity, all of which relate to personal development and self-discovery.', 'The author, Lisa Congdon, is an artist and illustrator, indicating that the book is likely aimed at individuals interested in art and creativity, rather than a specific genre like fiction or business.', "Given the themes of self-expression, creativity, and personal growth, the most fitting category from the predefined list is 'Self-Growth'.", "The book also touches on aspects of happiness through the encouragement of original self-expression and overcoming fears, which could also align with the 'Happiness' category."]
#
#
# Book (idx=1296)
#  - Title: "Outliers: The Story of Success"
#  - Author: Malcolm Gladwell
#  - Overview: What’s inside Go on an intellectual journey through the world of outliers! Learn why IQ is as important as social connections and cultural influence in achieving success.You’ll learn • How your birth date affects your success as a child • Why the Ivy League should accept students by lottery • About The Matthew Effect • Five ways to develop practical intelligence About the author Malcolm Gladwell, a Canadian journalist and public speaker, is the author of seven books on sociological and psychological research and a Revisionist History podcast host.
#  - Author Overview: Malcolm Gladwell, a Canadian journalist and public speaker, is the author of seven books on sociological and psychological research and a Revisionist History podcast host.
#  - Learning items: ['How your birth date affects your success as a child', 'Why the Ivy League should accept students by lottery', 'About The Matthew Effect', 'Five ways to develop practical intelligence']
#  - Categories: ['Society & Tech']
#  - AI Categories: ['Self-Growth', 'Society & Tech']
#  - AI Reasoning Steps: ['The book discusses the concept of success and the factors that contribute to it, which aligns with themes of personal development and societal influences.', 'It emphasizes the importance of social connections and cultural influences, indicating a focus on societal aspects of success.', 'The key learning items include practical intelligence and the impact of birth dates on success, which suggests a blend of personal growth and societal context.', "Given the author's background in sociological and psychological research, the book likely explores themes related to society and personal development.", "The predefined categories include 'Self-Growth' and 'Society & Tech', both of which are relevant to the themes presented in the book."]
#
#
# Book (idx=903)
#  - Title: "Happier Hour: How to Beat Distraction, Expand Your Time, and Focus on What Matters Most"
#  - Author: Cassie Holmes, PhD
#  - Overview: What’s inside Create an abundance of free time by prioritizing things that matter, protecting your concentration, being present, and savoring every moment to make your life worthwhile and fulfilled.You’ll learn • How time poverty affects your life • About delegating and enjoying your duties • The art of “stretching” your free hours through presence • Why focusing on a task is critical to enjoying it About the author Cassie Holmes, PhD, is a professor at UCLA’s Anderson School of Management, teacher, and researcher. Her work has been featured in the Economist, the Wall Street Journal, the Atlantic, and the Washington Post.
#  - Author Overview: Cassie Holmes, PhD, is a professor at UCLA’s Anderson School of Management, teacher, and researcher. Her work has been featured in the Economist, the Wall Street Journal, the Atlantic, and the Washington Post.
#  - Learning items: ['How time poverty affects your life', 'About delegating and enjoying your duties', 'The art of “stretching” your free hours through presence', 'Why focusing on a task is critical to enjoying it']
#  - Categories: ['Productivity']
#  - AI Categories: ['Happiness', 'Self-Growth', 'Productivity']
#  - AI Reasoning Steps: ['The book focuses on how to manage time effectively and prioritize what matters, which aligns with themes of productivity and self-growth.', 'It discusses concepts like time poverty and the importance of being present, which are closely related to happiness and personal fulfillment.', 'The author, Cassie Holmes, is a professor and researcher, indicating a scholarly approach to the subject matter, which often intersects with business and career development.', 'The key learning items emphasize practical strategies for improving focus and enjoyment in life, further supporting the categories of productivity and happiness.']
#
#
# Book (idx=869)
#  - Title: "Life in Five Senses: How Exploring the Senses Got Me Out of My Head and Into the World"
#  - Author: Gretchen Rubin
#  - Overview: What’s inside Reconnect with your body to fully experience life rather than drifting through it in a haze of thought. Engage your five senses to infuse every moment with joy.You’ll learn • The value of arranging days of silence • How touch heals us • Where to look for new sensations • Barriers that keep you from feeling alive About the author Gretchen Rubin is a bestselling author and researcher on happiness who hosts the award-winning podcast, Happier with Gretchen Rubin.
#  - Author Overview: Gretchen Rubin is a bestselling author and researcher on happiness who hosts the award-winning podcast, Happier with Gretchen Rubin.
#  - Learning items: ['The value of arranging days of silence', 'How touch heals us', 'Where to look for new sensations', 'Barriers that keep you from feeling alive']
#  - Categories: ['Happiness', 'Spirituality']
#  - AI Categories: ['Happiness', 'Self-Growth']
#  - AI Reasoning Steps: ['The book focuses on reconnecting with the body and experiencing life through the five senses, which suggests a focus on personal well-being and self-awareness.', 'The author, Gretchen Rubin, is known for her work on happiness, indicating that the book likely explores themes related to joy and fulfillment.', 'Key learning items emphasize healing through touch, the importance of silence, and overcoming barriers to feeling alive, all of which align with personal development and self-growth.', "Given the emphasis on happiness and personal experiences, the categories of 'Happiness' and 'Self-Growth' are particularly relevant."]
